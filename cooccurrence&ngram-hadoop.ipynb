# %% [markdown]
# # **Prepare - Data collection.**
#
# ---

# %%
# Create a folder only when it does not exist.
# %mkdir -p wikipedia-ml-raw

# %%
# Create a script
# %%file main.sh
#!/bin/bash

# Give the path of the file as first argument to the script:
input="$1" 

while IFS= read -r var 
do
  # Get each id
  id=`echo $var` 
  link="https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=$id"
  downloadname="index.php?title=Machine_learning&oldid=$id.html"
  filename="wikipedia-ml-raw/machine-learning-$id.html"
  echo $filename
  # Download the file from wikipedia
  wget -E $link
  # Move the downloaded file to the specific directory and rename it
  mv $downloadname $filename
done <"$input"
# Out:
# Writing main.sh

# %%
# Run the script
# !bash main.sh article-ids.txt
# Out:
# wikipedia-ml-raw/machine-learning-530966344.html
# --2023-04-30 09:57:25--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=530966344
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=530966344.html’
#
# index.php?title=Mac     [ <=>                ] 127.78K  --.-KB/s    in 0.1s
#
# 2023-04-30 09:57:26 (1.19 MB/s) - ‘index.php?title=Machine_learning&oldid=530966344.html’ saved [130843]
#
# wikipedia-ml-raw/machine-learning-561799120.html
# --2023-04-30 09:57:26--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=561799120
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=561799120.html’
#
# index.php?title=Mac     [ <=>                ] 127.36K  --.-KB/s    in 0.1s
#
# 2023-04-30 09:57:27 (1.20 MB/s) - ‘index.php?title=Machine_learning&oldid=561799120.html’ saved [130419]
#
# wikipedia-ml-raw/machine-learning-589188932.html
# --2023-04-30 09:57:27--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=589188932
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=589188932.html’
#
# index.php?title=Mac     [ <=>                ] 155.04K  --.-KB/s    in 0.1s
#
# 2023-04-30 09:57:28 (1.31 MB/s) - ‘index.php?title=Machine_learning&oldid=589188932.html’ saved [158757]
#
# wikipedia-ml-raw/machine-learning-611596476.html
# --2023-04-30 09:57:28--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=611596476
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=611596476.html’
#
# index.php?title=Mac     [ <=>                ] 157.98K  --.-KB/s    in 0.1s
#
# 2023-04-30 09:57:29 (1.33 MB/s) - ‘index.php?title=Machine_learning&oldid=611596476.html’ saved [161771]
#
# wikipedia-ml-raw/machine-learning-640893447.html
# --2023-04-30 09:57:29--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=640893447
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=640893447.html’
#
# index.php?title=Mac     [ <=>                ] 174.92K  --.-KB/s    in 0.1s
#
# 2023-04-30 09:57:30 (1.41 MB/s) - ‘index.php?title=Machine_learning&oldid=640893447.html’ saved [179120]
#
# wikipedia-ml-raw/machine-learning-669305018.html
# --2023-04-30 09:57:30--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=669305018
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=669305018.html’
#
# index.php?title=Mac     [ <=>                ] 181.99K  --.-KB/s    in 0.1s
#
# 2023-04-30 09:57:31 (1.44 MB/s) - ‘index.php?title=Machine_learning&oldid=669305018.html’ saved [186355]
#
# wikipedia-ml-raw/machine-learning-697788566.html
# --2023-04-30 09:57:31--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=697788566
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=697788566.html’
#
# index.php?title=Mac     [ <=>                ] 186.01K  --.-KB/s    in 0.1s
#
# 2023-04-30 09:57:32 (1.46 MB/s) - ‘index.php?title=Machine_learning&oldid=697788566.html’ saved [190475]
#
# wikipedia-ml-raw/machine-learning-727649049.html
# --2023-04-30 09:57:32--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=727649049
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=727649049.html’
#
# index.php?title=Mac     [ <=>                ] 192.04K  --.-KB/s    in 0.1s
#
# 2023-04-30 09:57:33 (1.49 MB/s) - ‘index.php?title=Machine_learning&oldid=727649049.html’ saved [196646]
#
# wikipedia-ml-raw/machine-learning-757727579.html
# --2023-04-30 09:57:33--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=757727579
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=757727579.html’
#
# index.php?title=Mac     [ <=>                ] 205.29K  --.-KB/s    in 0.1s
#
# 2023-04-30 09:57:34 (1.55 MB/s) - ‘index.php?title=Machine_learning&oldid=757727579.html’ saved [210212]
#
# wikipedia-ml-raw/machine-learning-788095566.html
# --2023-04-30 09:57:34--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=788095566
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=788095566.html’
#
# index.php?title=Mac     [ <=>                ] 212.05K  --.-KB/s    in 0.1s
#
# 2023-04-30 09:57:35 (1.58 MB/s) - ‘index.php?title=Machine_learning&oldid=788095566.html’ saved [217139]
#
# wikipedia-ml-raw/machine-learning-818847631.html
# --2023-04-30 09:57:35--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=818847631
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=818847631.html’
#
# index.php?title=Mac     [ <=>                ] 220.86K  --.-KB/s    in 0.1s
#
# 2023-04-30 09:57:37 (1.59 MB/s) - ‘index.php?title=Machine_learning&oldid=818847631.html’ saved [226161]
#
# wikipedia-ml-raw/machine-learning-848001726.html
# --2023-04-30 09:57:37--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=848001726
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=848001726.html’
#
# index.php?title=Mac     [ <=>                ] 268.73K  --.-KB/s    in 0.1s
#
# 2023-04-30 09:57:38 (1.82 MB/s) - ‘index.php?title=Machine_learning&oldid=848001726.html’ saved [275178]
#
# wikipedia-ml-raw/machine-learning-876474031.html
# --2023-04-30 09:57:38--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=876474031
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=876474031.html’
#
# index.php?title=Mac     [ <=>                ] 323.52K  2.03MB/s    in 0.2s
#
# 2023-04-30 09:57:40 (2.03 MB/s) - ‘index.php?title=Machine_learning&oldid=876474031.html’ saved [331280]
#
# wikipedia-ml-raw/machine-learning-903232737.html
# --2023-04-30 09:57:40--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=903232737
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=903232737.html’
#
# index.php?title=Mac     [ <=>                ] 321.00K  1.96MB/s    in 0.2s
#
# 2023-04-30 09:57:42 (1.96 MB/s) - ‘index.php?title=Machine_learning&oldid=903232737.html’ saved [328700]
#
# wikipedia-ml-raw/machine-learning-934837523.html
# --2023-04-30 09:57:42--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=934837523
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=934837523.html’
#
# index.php?title=Mac     [ <=>                ] 331.70K  2.05MB/s    in 0.2s
#
# 2023-04-30 09:57:43 (2.05 MB/s) - ‘index.php?title=Machine_learning&oldid=934837523.html’ saved [339657]
#
# wikipedia-ml-raw/machine-learning-965344897.html
# --2023-04-30 09:57:43--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=965344897
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=965344897.html’
#
# index.php?title=Mac     [ <=>                ] 347.62K  2.11MB/s    in 0.2s
#
# 2023-04-30 09:57:45 (2.11 MB/s) - ‘index.php?title=Machine_learning&oldid=965344897.html’ saved [355968]
#
# wikipedia-ml-raw/machine-learning-999142720.html
# --2023-04-30 09:57:45--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=999142720
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=999142720.html’
#
# index.php?title=Mac     [ <=>                ] 399.79K  2.23MB/s    in 0.2s
#
# 2023-04-30 09:57:47 (2.23 MB/s) - ‘index.php?title=Machine_learning&oldid=999142720.html’ saved [409388]
#
# wikipedia-ml-raw/machine-learning-1029354622.html
# --2023-04-30 09:57:47--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=1029354622
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=1029354622.html’
#
# index.php?title=Mac     [ <=>                ] 418.74K  2.40MB/s    in 0.2s
#
# 2023-04-30 09:57:49 (2.40 MB/s) - ‘index.php?title=Machine_learning&oldid=1029354622.html’ saved [428785]
#
# wikipedia-ml-raw/machine-learning-1063409105.html
# --2023-04-30 09:57:50--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=1063409105
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=1063409105.html’
#
# index.php?title=Mac     [ <=>                ] 429.82K  2.42MB/s    in 0.2s
#
# 2023-04-30 09:57:52 (2.42 MB/s) - ‘index.php?title=Machine_learning&oldid=1063409105.html’ saved [440139]
#
# wikipedia-ml-raw/machine-learning-1095436080.html
# --2023-04-30 09:57:52--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=1095436080
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=1095436080.html’
#
# index.php?title=Mac     [ <=>                ] 458.28K  2.54MB/s    in 0.2s
#
# 2023-04-30 09:57:54 (2.54 MB/s) - ‘index.php?title=Machine_learning&oldid=1095436080.html’ saved [469279]
#
# wikipedia-ml-raw/machine-learning-1130883349.html
# --2023-04-30 09:57:54--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=1130883349
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:860:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=1130883349.html’
#
# index.php?title=Mac     [ <=>                ] 467.09K  2.58MB/s    in 0.2s
#
# 2023-04-30 09:57:56 (2.58 MB/s) - ‘index.php?title=Machine_learning&oldid=1130883349.html’ saved [478298]
#
# wikipedia-ml-raw/machine-learning-.html
# --2023-04-30 09:57:56--  https://en.wikipedia.org/w/index.php?title=Machine_learning&oldid=
# Resolving en.wikipedia.org (en.wikipedia.org)... 208.80.153.224, 2620:0:861:ed1a::1
# Connecting to en.wikipedia.org (en.wikipedia.org)|208.80.153.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.php?title=Machine_learning&oldid=.html’
#
# index.php?title=Mac     [ <=>                ] 499.05K  2.70MB/s    in 0.2s
#
# 2023-04-30 09:57:57 (2.70 MB/s) - ‘index.php?title=Machine_learning&oldid=.html’ saved [511024]

# %%
# Run the parse_article script
# !bash parse_article.sh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)

# %% [markdown]
# # **Installing and Configuring Hadoop**

# %%
import os
# Installing Hadoop and configuring JAVA_HOME: 
# Downloading Hadoop
# Upzipping 
# Copying hadoop into our /usr/local folder
# Removing the unused original copy
# Remove the compressed (zip) file, we're not using it anymore. 
# Adding a variable called "JAVA_HOME" to hadoop's environment script which tells it where Java is on our system. 

# !if [ ! -d /usr/local/hadoop-3.3.3/ ]; then \
wget https://dlcdn.apache.org/hadoop/common/hadoop-3.3.3/hadoop-3.3.3.tar.gz; \
tar -xzf hadoop-3.3.3.tar.gz; \
cp -r hadoop-3.3.3/ /usr/local/; \
rm -rf hadoop-3.3.3/; \
rm hadoop-3.3.3.tar.gz; \
echo "export JAVA_HOME=$(dirname $(dirname $(realpath $(which java))))" >> /usr/local/hadoop-3.3.3/etc/hadoop/hadoop-env.sh; \
fi
# Out:
# --2023-04-30 09:58:40--  https://dlcdn.apache.org/hadoop/common/hadoop-3.3.3/hadoop-3.3.3.tar.gz
# Resolving dlcdn.apache.org (dlcdn.apache.org)... 151.101.2.132, 2a04:4e42::644
# Connecting to dlcdn.apache.org (dlcdn.apache.org)|151.101.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 645040598 (615M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.3.tar.gz’
#
# hadoop-3.3.3.tar.gz 100%[===================>] 615.16M   201MB/s    in 3.1s
#
# 2023-04-30 09:58:44 (201 MB/s) - ‘hadoop-3.3.3.tar.gz’ saved [645040598/645040598]

# %%
# Setting up some of our environmental variables: 
# Here we add Hadoop's location to our path (in Python) and tell our system where hadoop is located. 
os.environ['PATH'] = "/usr/local/hadoop-3.3.3/bin/:" + os.environ['PATH']
os.environ["HADOOP_HOME"] = "/usr/local/hadoop-3.3.3"

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# !cp /content/drive/MyDrive/COMP47470_lab4/lab4_config.sh /content/
# !cat lab4_config.sh
# # Running our config script
# # Note: remember to check you have the correct filepath
# !bash lab4_config.sh

# %%
# !$HADOOP_HOME/bin/hdfs namenode -format
# Creating our HDFS environment variables: 
os.environ["HDFS_NAMENODE_USER"] = "root"
os.environ["HDFS_DATANODE_USER"] = "root"
os.environ["HDFS_SECONDARYNAMENODE_USER"] = "root"
os.environ["YARN_RESOURCEMANAGER_USER"] = "root"
os.environ["YARN_NODEMANAGER_USER"] = "root"
# Out:
# WARNING: /usr/local/hadoop-3.3.3/logs does not exist. Creating.
# 2023-04-30 09:59:23,183 INFO namenode.NameNode: STARTUP_MSG:
# /************************************************************
# STARTUP_MSG: Starting NameNode
# STARTUP_MSG:   host = 6d8454f771e3/172.28.0.12
# STARTUP_MSG:   args = [-format]
# STARTUP_MSG:   version = 3.3.3
# STARTUP_MSG:   classpath = /usr/local/hadoop-3.3.3/etc/hadoop:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jettison-1.1.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/hadoop-auth-3.3.3.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jsch-0.1.55.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/kerb-simplekdc-1.0.1.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jakarta.activation-api-1.2.1.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/commons-beanutils-1.9.4.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/curator-framework-4.2.0.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jackson-core-asl-1.9.13.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jsr305-3.0.2.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/token-provider-1.0.1.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/audience-annotations-0.5.0.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jackson-core-2.13.2.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jul-to-slf4j-1.7.36.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jetty-util-9.4.43.v20210629.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/dnsjava-2.1.7.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/kerby-xdr-1.0.1.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/accessors-smart-2.4.7.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jetty-xml-9.4.43.v20210629.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jetty-io-9.4.43.v20210629.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jackson-xc-1.9.13.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jetty-webapp-9.4.43.v20210629.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/kerb-identity-1.0.1.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/guava-27.0-jre.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/hadoop-shaded-guava-1.1.1.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/nimbus-jose-jwt-9.8.1.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/failureaccess-1.0.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/woodstox-core-5.3.0.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/httpclient-4.5.13.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jetty-util-ajax-9.4.43.v20210629.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/reload4j-1.2.18.3.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/listenablefuture-9999.0-empty-to-avoid-conflict-with-guava.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/commons-codec-1.15.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/commons-cli-1.2.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/re2j-1.1.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/commons-daemon-1.0.13.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/gson-2.8.9.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/checker-qual-2.5.2.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jackson-databind-2.13.2.2.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jaxb-api-2.2.11.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/animal-sniffer-annotations-1.17.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/metrics-core-3.2.4.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jackson-jaxrs-1.9.13.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/kerb-common-1.0.1.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jersey-server-1.19.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/json-smart-2.4.7.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/kerb-client-1.0.1.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jersey-core-1.19.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/commons-io-2.8.0.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jackson-annotations-2.13.2.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/commons-logging-1.1.3.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/jetty-servlet-9.4.43.v20210629.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/kerb-server-1.0.1.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/kerb-crypto-1.0.1.jar:/usr/local/hadoop-3.3.3/share/hadoop/common/lib/asm-5. ...
# STARTUP_MSG:   build = https://github.com/apache/hadoop.git -r d37586cbda38c338d9fe481addda5a05fb516f71; compiled by 'stevel' on 2022-05-09T16:36Z
# STARTUP_MSG:   java = 11.0.18
# ************************************************************/
# 2023-04-30 09:59:23,262 INFO namenode.NameNode: registered UNIX signal handlers for [TERM, HUP, INT]
# 2023-04-30 09:59:23,600 INFO namenode.NameNode: createNameNode [-format]
# 2023-04-30 09:59:24,702 INFO namenode.NameNode: Formatting using clusterid: CID-bd33f573-a41a-46ee-b607-b80aeb4e4aac
# 2023-04-30 09:59:24,755 INFO namenode.FSEditLog: Edit logging is async:true
# 2023-04-30 09:59:24,809 INFO namenode.FSNamesystem: KeyProvider: null
# 2023-04-30 09:59:24,811 INFO namenode.FSNamesystem: fsLock is fair: true
# 2023-04-30 09:59:24,811 INFO namenode.FSNamesystem: Detailed lock hold time metrics enabled: false
# 2023-04-30 09:59:24,865 INFO namenode.FSNamesystem: fsOwner                = root (auth:SIMPLE)
# 2023-04-30 09:59:24,865 INFO namenode.FSNamesystem: supergroup             = supergroup
# 2023-04-30 09:59:24,865 INFO namenode.FSNamesystem: isPermissionEnabled    = true
# 2023-04-30 09:59:24,865 INFO namenode.FSNamesystem: isStoragePolicyEnabled = true
# 2023-04-30 09:59:24,866 INFO namenode.FSNamesystem: HA Enabled: false
# 2023-04-30 09:59:24,937 INFO common.Util: dfs.datanode.fileio.profiling.sampling.percentage set to 0. Disabling file IO profiling
# 2023-04-30 09:59:24,950 INFO blockmanagement.DatanodeManager: dfs.block.invalidate.limit: configured=1000, counted=60, effected=1000
# 2023-04-30 09:59:24,950 INFO blockmanagement.DatanodeManager: dfs.namenode.datanode.registration.ip-hostname-check=true
# 2023-04-30 09:59:24,953 INFO blockmanagement.BlockManager: dfs.namenode.startup.delay.block.deletion.sec is set to 000:00:00:00.000
# 2023-04-30 09:59:24,954 INFO blockmanagement.BlockManager: The block deletion will start around 2023 Apr 30 09:59:24
# 2023-04-30 09:59:24,956 INFO util.GSet: Computing capacity for map BlocksMap
# 2023-04-30 09:59:24,956 INFO util.GSet: VM type       = 64-bit
# 2023-04-30 09:59:24,959 INFO util.GSet: 2.0% max memory 3.2 GB = 65.0 MB
# 2023-04-30 09:59:24,959 INFO util.GSet: capacity      = 2^23 = 8388608 entries
# 2023-04-30 09:59:24,990 INFO blockmanagement.BlockManager: Storage policy satisfier is disabled
# 2023-04-30 09:59:24,990 INFO blockmanagement.BlockManager: dfs.block.access.token.enable = false
# 2023-04-30 09:59:24,996 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.threshold-pct = 0.999
# 2023-04-30 09:59:24,996 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.min.datanodes = 0
# 2023-04-30 09:59:24,997 INFO blockmanagement.BlockManagerSafeMode: dfs.namenode.safemode.extension = 30000
# 2023-04-30 09:59:24,997 INFO blockmanagement.BlockManager: defaultReplication         = 3
# 2023-04-30 09:59:24,998 INFO blockmanagement.BlockManager: maxReplication             = 512
# 2023-04-30 09:59:24,998 INFO blockmanagement.BlockManager: minReplication             = 1
# 2023-04-30 09:59:24,998 INFO blockmanagement.BlockManager: maxReplicationStreams      = 2
# 2023-04-30 09:59:24,998 INFO blockmanagement.BlockManager: redundancyRecheckInterval  = 3000ms
# 2023-04-30 09:59:24,998 INFO blockmanagement.BlockManager: encryptDataTransfer        = false
# 2023-04-30 09:59:24,998 INFO blockmanagement.BlockManager: maxNumBlocksToLog          = 1000
# 2023-04-30 09:59:25,032 INFO namenode.FSDirectory: GLOBAL serial map: bits=29 maxEntries=536870911
# 2023-04-30 09:59:25,032 INFO namenode.FSDirectory: USER serial map: bits=24 maxEntries=16777215
# 2023-04-30 09:59:25,032 INFO namenode.FSDirectory: GROUP serial map: bits=24 maxEntries=16777215
# 2023-04-30 09:59:25,032 INFO namenode.FSDirectory: XATTR serial map: bits=24 maxEntries=16777215
# 2023-04-30 09:59:25,049 INFO util.GSet: Computing capacity for map INodeMap
# 2023-04-30 09:59:25,050 INFO util.GSet: VM type       = 64-bit
# 2023-04-30 09:59:25,050 INFO util.GSet: 1.0% max memory 3.2 GB = 32.5 MB
# 2023-04-30 09:59:25,050 INFO util.GSet: capacity      = 2^22 = 4194304 entries
# 2023-04-30 09:59:25,062 INFO namenode.FSDirectory: ACLs enabled? true
# 2023-04-30 09:59:25,062 INFO namenode.FSDirectory: POSIX ACL inheritance enabled? true
# 2023-04-30 09:59:25,062 INFO namenode.FSDirectory: XAttrs enabled? true
# 2023-04-30 09:59:25,062 INFO namenode.NameNode: Caching file names occurring more than 10 times
# 2023-04-30 09:59:25,071 INFO snapshot.SnapshotManager: Loaded config captureOpenFiles: false, skipCaptureAccessTimeOnlyChange: false, snapshotDiffAllowSnapRootDescendant: true, maxSnapshotLimit: 65536
# 2023-04-30 09:59:25,073 INFO snapshot.SnapshotManager: SkipList is disabled
# 2023-04-30 09:59:25,080 INFO util.GSet: Computing capacity for map cachedBlocks
# 2023-04-30 09:59:25,080 INFO util.GSet: VM type       = 64-bit
# 2023-04-30 09:59:25,081 INFO util.GSet: 0.25% max memory 3.2 GB = 8.1 MB
# 2023-04-30 09:59:25,081 INFO util.GSet: capacity      = 2^20 = 1048576 entries
# 2023-04-30 09:59:25,118 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.window.num.buckets = 10
# 2023-04-30 09:59:25,118 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.num.users = 10
# 2023-04-30 09:59:25,118 INFO metrics.TopMetrics: NNTop conf: dfs.namenode.top.windows.minutes = 1,5,25
# 2023-04-30 09:59:25,124 INFO namenode.FSNamesystem: Retry cache on namenode is enabled
# 2023-04-30 09:59:25,124 INFO namenode.FSNamesystem: Retry cache will use 0.03 of total heap and retry cache entry expiry time is 600000 millis
# 2023-04-30 09:59:25,127 INFO util.GSet: Computing capacity for map NameNodeRetryCache
# 2023-04-30 09:59:25,127 INFO util.GSet: VM type       = 64-bit
# 2023-04-30 09:59:25,127 INFO util.GSet: 0.029999999329447746% max memory 3.2 GB = 997.8 KB
# 2023-04-30 09:59:25,127 INFO util.GSet: capacity      = 2^17 = 131072 entries
# 2023-04-30 09:59:25,161 INFO namenode.FSImage: Allocated new BlockPoolId: BP-31818752-172.28.0.12-1682848765150
# 2023-04-30 09:59:25,212 INFO common.Storage: Storage directory /tmp/hadoop-root/dfs/name has been successfully formatted.
# 2023-04-30 09:59:25,288 INFO namenode.FSImageFormatProtobuf: Saving image file /tmp/hadoop-root/dfs/name/current/fsimage.ckpt_0000000000000000000 using no compression
# 2023-04-30 09:59:25,435 INFO namenode.FSImageFormatProtobuf: Image file /tmp/hadoop-root/dfs/name/current/fsimage.ckpt_0000000000000000000 of size 396 bytes saved in 0 seconds .
# 2023-04-30 09:59:25,466 INFO namenode.NNStorageRetentionManager: Going to retain 1 images with txid >= 0
# 2023-04-30 09:59:25,514 INFO namenode.FSNamesystem: Stopping services started for active state
# 2023-04-30 09:59:25,514 INFO namenode.FSNamesystem: Stopping services started for standby state
# 2023-04-30 09:59:25,524 INFO namenode.FSImage: FSImageSaver clean checkpoint: txid=0 when meet shutdown.
# 2023-04-30 09:59:25,525 INFO namenode.NameNode: SHUTDOWN_MSG:
# /************************************************************
# SHUTDOWN_MSG: Shutting down NameNode at 6d8454f771e3/172.28.0.12
# ************************************************************/

# %%
# Launching hdfs daemons
# !$HADOOP_HOME/sbin/start-dfs.sh
# Launching our yarn daemons
# nohup causes a process to ignore a "hang-up" signal
# !nohup $HADOOP_HOME/sbin/start-yarn.sh
# Out:
# Starting namenodes on [6d8454f771e3]
# 6d8454f771e3: ssh: connect to host 6d8454f771e3 port 22: Connection refused
# Starting datanodes
# localhost: ssh: connect to host localhost port 22: Cannot assign requested address
# Starting secondary namenodes [6d8454f771e3]
# 6d8454f771e3: ssh: connect to host 6d8454f771e3 port 22: Connection refused
# nohup: ignoring input and appending output to 'nohup.out'

# %% [markdown]
# # **Data Processing with Hadoop**

# %% [markdown]
# **Move all article files (from all years) from wikipedia-ml into the HDFS.**

# %%
# Make a new directory in HDFS
# !$HADOOP_HOME/bin/hdfs dfs -mkdir /wikipedia-ml

# %%
# Create a script to upload the articles onto Hadoop
# %%file upload.sh
#!/bin/bash
input="/content/wikipedia-ml"
for file in $input/*; do
  hdfs dfs -put "$file" /wikipedia-ml
done
# Out:
# Writing upload.sh

# %%
# !bash upload.sh

# %%
# !$HADOOP_HOME/bin/hdfs dfs -ls /wikipedia-ml
# Out:
# Found 44 items
# -rw-r--r--   1 root root      12305 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2013_1_2.txt
# -rw-r--r--   1 root root      12048 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2013_6_27.txt
# -rw-r--r--   1 root root      12391 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2014_1_4.txt
# -rw-r--r--   1 root root      12396 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2014_6_4.txt
# -rw-r--r--   1 root root      16236 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2015_1_4.txt
# -rw-r--r--   1 root root      17678 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2015_6_30.txt
# -rw-r--r--   1 root root      17526 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2016_1_1.txt
# -rw-r--r--   1 root root      19147 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2016_6_30.txt
# -rw-r--r--   1 root root      22051 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2017_1_1.txt
# -rw-r--r--   1 root root      22289 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2017_6_29.txt
# -rw-r--r--   1 root root      22407 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2018_1_5.txt
# -rw-r--r--   1 root root      23485 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2018_6_29.txt
# -rw-r--r--   1 root root      36562 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2019_1_2.txt
# -rw-r--r--   1 root root      37840 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2019_6_24.txt
# -rw-r--r--   1 root root      41178 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2020_1_8.txt
# -rw-r--r--   1 root root      40438 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2020_6_30.txt
# -rw-r--r--   1 root root      42489 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2021_1_8.txt
# -rw-r--r--   1 root root      43410 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2021_6_19.txt
# -rw-r--r--   1 root root      45577 2023-04-30 10:00 /wikipedia-ml/article_Machine learning - Wikipedia_2022_1_2.txt
# -rw-r--r--   1 root root      47622 2023-04-30 10:01 /wikipedia-ml/article_Machine learning - Wikipedia_2022_6_28.txt
# -rw-r--r--   1 root root      49228 2023-04-30 10:01 /wikipedia-ml/article_Machine learning - Wikipedia_2023_1_1.txt
# -rw-r--r--   1 root root      48519 2023-04-30 10:01 /wikipedia-ml/article_Machine learning - Wikipedia_2023_4_29.txt
# -rw-r--r--   1 root root       1079 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2013_1_2.txt
# -rw-r--r--   1 root root       1443 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2013_6_27.txt
# -rw-r--r--   1 root root       1773 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2014_1_4.txt
# -rw-r--r--   1 root root       1915 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2014_6_4.txt
# -rw-r--r--   1 root root       3529 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2015_1_4.txt
# -rw-r--r--   1 root root       4136 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2015_6_30.txt
# -rw-r--r--   1 root root       4231 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2016_1_1.txt
# -rw-r--r--   1 root root       4823 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2016_6_30.txt
# -rw-r--r--   1 root root       5538 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2017_1_1.txt
# -rw-r--r--   1 root root       5990 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2017_6_29.txt
# -rw-r--r--   1 root root       7487 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2018_1_5.txt
# -rw-r--r--   1 root root       8341 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2018_6_29.txt
# -rw-r--r--   1 root root      13911 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2019_1_2.txt
# -rw-r--r--   1 root root      13693 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2019_6_24.txt
# -rw-r--r--   1 root root      14792 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2020_1_8.txt
# -rw-r--r--   1 root root      16415 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2020_6_30.txt
# -rw-r--r--   1 root root      19922 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2021_1_8.txt
# -rw-r--r--   1 root root      20323 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2021_6_19.txt
# -rw-r--r--   1 root root      20290 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2022_1_2.txt
# -rw-r--r--   1 root root      23569 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2022_6_28.txt
# -rw-r--r--   1 root root      24216 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2023_1_1.txt
# -rw-r--r--   1 root root      28366 2023-04-30 10:01 /wikipedia-ml/refs_Machine learning - Wikipedia_2023_4_29.txt

# %% [markdown]
# **Co-occurance MapReduce**

# %%
# Create the mapper script
# %%writefile mapper_co_occur.py

#!/usr/bin/env python
import sys,string

# Read the stopwords and store them in a list
stopwords = open("stopwords.txt", "r")
stopwords_list = []
for stopword in stopwords:
  stopwords_list.append(stopword.strip())

# Read articles
for line in sys.stdin:
  line = line.strip()  # removes whitespace either side of each line
  words = line.split()  # splitting each line into a list of words
  n = len(words)
  # Create co-occurance
  for i in range(n):
    for j in range(i+1, n):
      word_i = words[i].strip(string.punctuation.replace("\'","")) # removes punctuations
      word_j = words[j].strip(string.punctuation.replace("\'","")) # removes punctuations
      if not(word_i.lower() in stopwords_list) and not(word_j.lower() in stopwords_list):
        print('%s,%s\t%s' % (word_i,word_j, 1))  # writing our results to STDOUT (this is the input for reducer.py)
# Out:
# Writing mapper_co_occur.py

# %%
# Writing reducer script: 
# Reference: lab04_solution

# %%writefile reducer_co_occur.py

#!/usr/bin/env python
  
import sys
from operator import itemgetter
  
current_word = None
current_count = 0
word = None
  
for line in sys.stdin:
  line = line.strip()
  word, count = line.split('\t', 1)  # splitting the data on the basis of tab (see mapper.py)
  
  try:
    count = int(count)  # convert count (currently a string) to int
  except ValueError:
    continue  # silently ignore line if count is not a number
  
  # this IF-switch only works because Hadoop sorts map output
  # by key (here: word) before it is passed to the reducer
  if current_word == word:
    current_count += count
  else:
    if current_word: # to avoid None values
      print('%s\t%s' % (current_word, current_count))
    current_count = count
    current_word = word
  
# do not forget to output the last word if needed!
if current_word == word:
  print('%s\t%s' % (current_word, current_count))
# Out:
# Writing reducer_co_occur.py

# %%
# Giving these mapper&reducer permissions:
# !chmod u+x /content/mapper_co_occur.py /content/reducer_co_occur.py

# %%
#Running MapReduce programs
# !$HADOOP_HOME/bin/hadoop jar $HADOOP_HOME/share/hadoop/tools/lib/hadoop-streaming-3.3.3.jar \
  -input /wikipedia-ml/article*.txt \
  -output /cooccur-outputs \
  -mapper "python /content/mapper_co_occur.py" \
  -reducer "python /content/reducer_co_occur.py"
# Out:
# 2023-04-30 10:03:06,783 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2023-04-30 10:03:07,203 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2023-04-30 10:03:07,203 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2023-04-30 10:03:07,252 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2023-04-30 10:03:07,677 INFO mapred.FileInputFormat: Total input files to process : 22
# 2023-04-30 10:03:07,765 INFO mapreduce.JobSubmitter: number of splits:22
# 2023-04-30 10:03:08,175 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1265541845_0001
# 2023-04-30 10:03:08,175 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2023-04-30 10:03:08,400 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2023-04-30 10:03:08,403 INFO mapreduce.Job: Running job: job_local1265541845_0001
# 2023-04-30 10:03:08,423 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2023-04-30 10:03:08,427 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2023-04-30 10:03:08,434 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:08,434 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:08,568 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2023-04-30 10:03:08,581 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000000_0
# 2023-04-30 10:03:08,619 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:08,621 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:08,653 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:08,663 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2023_1_1.txt:0+49228
# 2023-04-30 10:03:08,696 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:08,783 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:08,783 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:08,783 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:08,783 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:08,783 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:08,787 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:08,799 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:08,808 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2023-04-30 10:03:08,810 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2023-04-30 10:03:08,812 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2023-04-30 10:03:08,813 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2023-04-30 10:03:08,814 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2023-04-30 10:03:08,814 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2023-04-30 10:03:08,818 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2023-04-30 10:03:08,820 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2023-04-30 10:03:08,820 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2023-04-30 10:03:08,820 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2023-04-30 10:03:08,821 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2023-04-30 10:03:08,822 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2023-04-30 10:03:08,879 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:08,880 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:08,941 INFO streaming.PipeMapRed: Records R/W=93/1
# 2023-04-30 10:03:09,415 INFO mapreduce.Job: Job job_local1265541845_0001 running in uber mode : false
# 2023-04-30 10:03:09,416 INFO mapreduce.Job:  map 0% reduce 0%
# 2023-04-30 10:03:10,594 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:10,595 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:10,599 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:10,600 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:10,600 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:10,600 INFO mapred.MapTask: bufstart = 0; bufend = 2780278; bufvoid = 104857600
# 2023-04-30 10:03:10,600 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25611192(102444768); length = 603205/6553600
# 2023-04-30 10:03:11,119 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:03:11,134 INFO mapred.Task: Task:attempt_local1265541845_0001_m_000000_0 is done. And is in the process of committing
# 2023-04-30 10:03:11,142 INFO mapred.LocalJobRunner: Records R/W=93/1
# 2023-04-30 10:03:11,142 INFO mapred.Task: Task 'attempt_local1265541845_0001_m_000000_0' done.
# 2023-04-30 10:03:11,151 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=193950
# 		FILE: Number of bytes written=3870408
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=93
# 		Map output records=150802
# 		Map output bytes=2780278
# 		Map output materialized bytes=3081888
# 		Input split bytes=120
# 		Combine input records=0
# 		Spilled Records=150802
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=347078656
# 	File Input Format Counters
# 		Bytes Read=49632
# 2023-04-30 10:03:11,151 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_m_000000_0
# 2023-04-30 10:03:11,153 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000001_0
# 2023-04-30 10:03:11,155 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:11,155 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:11,155 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:11,157 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2023_4_29.txt:0+48519
# 2023-04-30 10:03:11,162 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:11,261 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:11,261 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:11,261 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:11,261 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:11,261 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:11,265 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:11,279 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:11,309 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:11,310 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:11,376 INFO streaming.PipeMapRed: Records R/W=90/1
# 2023-04-30 10:03:11,426 INFO mapreduce.Job:  map 100% reduce 0%
# 2023-04-30 10:03:12,899 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:12,900 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:12,901 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:12,901 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:12,901 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:12,901 INFO mapred.MapTask: bufstart = 0; bufend = 2769788; bufvoid = 104857600
# 2023-04-30 10:03:12,901 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25613668(102454672); length = 600729/6553600
# 2023-04-30 10:03:13,223 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:03:13,227 INFO mapred.Task: Task:attempt_local1265541845_0001_m_000001_0 is done. And is in the process of committing
# 2023-04-30 10:03:13,228 INFO mapred.LocalJobRunner: Records R/W=90/1
# 2023-04-30 10:03:13,229 INFO mapred.Task: Task 'attempt_local1265541845_0001_m_000001_0' done.
# 2023-04-30 10:03:13,229 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_m_000001_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=245554
# 		FILE: Number of bytes written=6940600
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=90
# 		Map output records=150183
# 		Map output bytes=2769788
# 		Map output materialized bytes=3070160
# 		Input split bytes=121
# 		Combine input records=0
# 		Spilled Records=150183
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=19
# 		Total committed heap usage (bytes)=347078656
# 	File Input Format Counters
# 		Bytes Read=48915
# 2023-04-30 10:03:13,230 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_m_000001_0
# 2023-04-30 10:03:13,230 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000002_0
# 2023-04-30 10:03:13,231 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:13,232 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:13,232 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:13,234 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2022_6_28.txt:0+47622
# 2023-04-30 10:03:13,238 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:13,302 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:13,305 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:13,305 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:13,305 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:13,305 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:13,321 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:13,341 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:13,383 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:13,384 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:13,474 INFO streaming.PipeMapRed: Records R/W=86/1
# 2023-04-30 10:03:14,960 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:14,961 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:14,962 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:14,962 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:14,962 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:14,962 INFO mapred.MapTask: bufstart = 0; bufend = 2772323; bufvoid = 104857600
# 2023-04-30 10:03:14,962 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25612292(102449168); length = 602105/6553600
# 2023-04-30 10:03:15,202 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:03:15,207 INFO mapred.Task: Task:attempt_local1265541845_0001_m_000002_0 is done. And is in the process of committing
# 2023-04-30 10:03:15,209 INFO mapred.LocalJobRunner: Records R/W=86/1
# 2023-04-30 10:03:15,210 INFO mapred.Task: Task 'attempt_local1265541845_0001_m_000002_0' done.
# 2023-04-30 10:03:15,212 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_m_000002_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=296257
# 		FILE: Number of bytes written=10014015
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=86
# 		Map output records=150527
# 		Map output bytes=2772323
# 		Map output materialized bytes=3073383
# 		Input split bytes=121
# 		Combine input records=0
# 		Spilled Records=150527
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=14
# 		Total committed heap usage (bytes)=447741952
# 	File Input Format Counters
# 		Bytes Read=48014
# 2023-04-30 10:03:15,212 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_m_000002_0
# 2023-04-30 10:03:15,212 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000003_0
# 2023-04-30 10:03:15,215 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:15,216 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:15,217 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:15,219 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2022_1_2.txt:0+45577
# 2023-04-30 10:03:15,227 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:15,277 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:15,284 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:15,284 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:15,284 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:15,284 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:15,298 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:15,308 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:15,349 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:15,350 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:15,425 INFO streaming.PipeMapRed: Records R/W=83/1
# 2023-04-30 10:03:16,840 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:16,841 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:16,841 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:16,841 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:16,842 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:16,842 INFO mapred.MapTask: bufstart = 0; bufend = 2625439; bufvoid = 104857600
# 2023-04-30 10:03:16,842 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25642948(102571792); length = 571449/6553600
# 2023-04-30 10:03:17,001 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:03:17,004 INFO mapred.Task: Task:attempt_local1265541845_0001_m_000003_0 is done. And is in the process of committing
# 2023-04-30 10:03:17,007 INFO mapred.LocalJobRunner: Records R/W=83/1
# 2023-04-30 10:03:17,007 INFO mapred.Task: Task 'attempt_local1265541845_0001_m_000003_0' done.
# 2023-04-30 10:03:17,011 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_m_000003_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=344899
# 		FILE: Number of bytes written=12925218
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=83
# 		Map output records=142863
# 		Map output bytes=2625439
# 		Map output materialized bytes=2911171
# 		Input split bytes=120
# 		Combine input records=0
# 		Spilled Records=142863
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=3
# 		Total committed heap usage (bytes)=447741952
# 	File Input Format Counters
# 		Bytes Read=45953
# 2023-04-30 10:03:17,011 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_m_000003_0
# 2023-04-30 10:03:17,012 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000004_0
# 2023-04-30 10:03:17,014 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:17,014 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:17,014 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:17,021 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2021_6_19.txt:0+43410
# 2023-04-30 10:03:17,028 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:17,071 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:17,072 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:17,072 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:17,072 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:17,072 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:17,080 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:17,092 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:17,114 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:17,115 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:17,212 INFO streaming.PipeMapRed: Records R/W=78/1
# 2023-04-30 10:03:19,386 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:19,388 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:19,388 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:19,388 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:19,388 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:19,388 INFO mapred.MapTask: bufstart = 0; bufend = 2492839; bufvoid = 104857600
# 2023-04-30 10:03:19,388 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25671628(102686512); length = 542769/6553600
# 2023-04-30 10:03:19,432 INFO mapreduce.Job:  map 18% reduce 0%
# 2023-04-30 10:03:19,642 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:03:19,647 INFO mapred.Task: Task:attempt_local1265541845_0001_m_000004_0 is done. And is in the process of committing
# 2023-04-30 10:03:19,649 INFO mapred.LocalJobRunner: Records R/W=78/1
# 2023-04-30 10:03:19,650 INFO mapred.Task: Task 'attempt_local1265541845_0001_m_000004_0' done.
# 2023-04-30 10:03:19,650 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_m_000004_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=391354
# 		FILE: Number of bytes written=15689481
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=78
# 		Map output records=135693
# 		Map output bytes=2492839
# 		Map output materialized bytes=2764231
# 		Input split bytes=121
# 		Combine input records=0
# 		Spilled Records=135693
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=4
# 		Total committed heap usage (bytes)=447741952
# 	File Input Format Counters
# 		Bytes Read=43766
# 2023-04-30 10:03:19,650 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_m_000004_0
# 2023-04-30 10:03:19,650 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000005_0
# 2023-04-30 10:03:19,655 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:19,655 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:19,655 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:19,667 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2021_1_8.txt:0+42489
# 2023-04-30 10:03:19,672 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:19,718 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:19,719 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:19,719 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:19,720 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:19,720 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:19,724 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:19,735 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:19,792 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:19,792 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:19,930 INFO streaming.PipeMapRed: Records R/W=79/1
# 2023-04-30 10:03:20,432 INFO mapreduce.Job:  map 100% reduce 0%
# 2023-04-30 10:03:22,440 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:22,442 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:22,442 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:22,442 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:22,442 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:22,443 INFO mapred.MapTask: bufstart = 0; bufend = 2352821; bufvoid = 104857600
# 2023-04-30 10:03:22,443 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25702316(102809264); length = 512081/6553600
# 2023-04-30 10:03:22,601 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:03:22,604 INFO mapred.Task: Task:attempt_local1265541845_0001_m_000005_0 is done. And is in the process of committing
# 2023-04-30 10:03:22,606 INFO mapred.LocalJobRunner: Records R/W=79/1
# 2023-04-30 10:03:22,607 INFO mapred.Task: Task 'attempt_local1265541845_0001_m_000005_0' done.
# 2023-04-30 10:03:22,612 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_m_000005_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=436368
# 		FILE: Number of bytes written=18298382
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=79
# 		Map output records=128021
# 		Map output bytes=2352821
# 		Map output materialized bytes=2608869
# 		Input split bytes=120
# 		Combine input records=0
# 		Spilled Records=128021
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=4
# 		Total committed heap usage (bytes)=447741952
# 	File Input Format Counters
# 		Bytes Read=42837
# 2023-04-30 10:03:22,612 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_m_000005_0
# 2023-04-30 10:03:22,612 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000006_0
# 2023-04-30 10:03:22,615 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:22,615 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:22,615 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:22,617 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2020_1_8.txt:0+41178
# 2023-04-30 10:03:22,624 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:22,654 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:22,654 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:22,654 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:22,654 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:22,654 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:22,656 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:22,662 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:22,720 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:22,721 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:22,800 INFO streaming.PipeMapRed: Records R/W=69/1
# 2023-04-30 10:03:24,144 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:24,145 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:24,146 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:24,146 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:24,146 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:24,146 INFO mapred.MapTask: bufstart = 0; bufend = 2523643; bufvoid = 104857600
# 2023-04-30 10:03:24,146 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25666492(102665968); length = 547905/6553600
# 2023-04-30 10:03:24,289 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:03:24,292 INFO mapred.Task: Task:attempt_local1265541845_0001_m_000006_0 is done. And is in the process of committing
# 2023-04-30 10:03:24,294 INFO mapred.LocalJobRunner: Records R/W=69/1
# 2023-04-30 10:03:24,294 INFO mapred.Task: Task 'attempt_local1265541845_0001_m_000006_0' done.
# 2023-04-30 10:03:24,295 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_m_000006_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=480063
# 		FILE: Number of bytes written=21096017
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=69
# 		Map output records=136977
# 		Map output bytes=2523643
# 		Map output materialized bytes=2797603
# 		Input split bytes=120
# 		Combine input records=0
# 		Spilled Records=136977
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=4
# 		Total committed heap usage (bytes)=447741952
# 	File Input Format Counters
# 		Bytes Read=41518
# 2023-04-30 10:03:24,295 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_m_000006_0
# 2023-04-30 10:03:24,295 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000007_0
# 2023-04-30 10:03:24,297 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:24,297 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:24,297 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:24,300 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2020_6_30.txt:0+40438
# 2023-04-30 10:03:24,309 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:24,347 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:24,348 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:24,348 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:24,348 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:24,348 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:24,349 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:24,353 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:24,383 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:24,383 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:24,453 INFO streaming.PipeMapRed: Records R/W=72/1
# 2023-04-30 10:03:25,713 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:25,713 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:25,714 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:25,714 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:25,714 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:25,714 INFO mapred.MapTask: bufstart = 0; bufend = 2308461; bufvoid = 104857600
# 2023-04-30 10:03:25,714 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25712104(102848416); length = 502293/6553600
# 2023-04-30 10:03:25,850 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:03:25,853 INFO mapred.Task: Task:attempt_local1265541845_0001_m_000007_0 is done. And is in the process of committing
# 2023-04-30 10:03:25,855 INFO mapred.LocalJobRunner: Records R/W=72/1
# 2023-04-30 10:03:25,856 INFO mapred.Task: Task 'attempt_local1265541845_0001_m_000007_0' done.
# 2023-04-30 10:03:25,859 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_m_000007_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=523010
# 		FILE: Number of bytes written=23655664
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=72
# 		Map output records=125574
# 		Map output bytes=2308461
# 		Map output materialized bytes=2559615
# 		Input split bytes=121
# 		Combine input records=0
# 		Spilled Records=125574
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=9
# 		Total committed heap usage (bytes)=447741952
# 	File Input Format Counters
# 		Bytes Read=40770
# 2023-04-30 10:03:25,859 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_m_000007_0
# 2023-04-30 10:03:25,859 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000008_0
# 2023-04-30 10:03:25,861 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:25,861 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:25,862 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:25,864 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2019_6_24.txt:0+37840
# 2023-04-30 10:03:25,868 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:25,904 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:25,904 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:25,904 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:25,904 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:25,904 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:25,919 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:25,930 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:25,956 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:25,957 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:26,041 INFO streaming.PipeMapRed: Records R/W=63/1
# 2023-04-30 10:03:27,281 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:27,282 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:27,282 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:27,282 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:27,283 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:27,283 INFO mapred.MapTask: bufstart = 0; bufend = 2353185; bufvoid = 104857600
# 2023-04-30 10:03:27,283 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25702888(102811552); length = 511509/6553600
# 2023-04-30 10:03:27,422 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:03:27,424 INFO mapred.Task: Task:attempt_local1265541845_0001_m_000008_0 is done. And is in the process of committing
# 2023-04-30 10:03:27,425 INFO mapred.LocalJobRunner: Records R/W=63/1
# 2023-04-30 10:03:27,426 INFO mapred.Task: Task 'attempt_local1265541845_0001_m_000008_0' done.
# 2023-04-30 10:03:27,426 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_m_000008_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=563339
# 		FILE: Number of bytes written=26264643
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=63
# 		Map output records=127878
# 		Map output bytes=2353185
# 		Map output materialized bytes=2608947
# 		Input split bytes=121
# 		Combine input records=0
# 		Spilled Records=127878
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=4
# 		Total committed heap usage (bytes)=447741952
# 	File Input Format Counters
# 		Bytes Read=38152
# 2023-04-30 10:03:27,426 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_m_000008_0
# 2023-04-30 10:03:27,426 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000009_0
# 2023-04-30 10:03:27,428 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:27,428 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:27,428 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:27,430 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2019_1_2.txt:0+36562
# 2023-04-30 10:03:27,434 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:27,482 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:27,482 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:27,482 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:27,482 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:27,482 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:27,503 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:27,509 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:27,528 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:27,529 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:27,602 INFO streaming.PipeMapRed: Records R/W=60/1
# 2023-04-30 10:03:28,796 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:28,797 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:28,797 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:28,797 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:28,797 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:28,797 INFO mapred.MapTask: bufstart = 0; bufend = 2229929; bufvoid = 104857600
# 2023-04-30 10:03:28,797 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25730152(102920608); length = 484245/6553600
# 2023-04-30 10:03:28,925 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:03:28,927 INFO mapred.Task: Task:attempt_local1265541845_0001_m_000009_0 is done. And is in the process of committing
# 2023-04-30 10:03:28,930 INFO mapred.LocalJobRunner: Records R/W=60/1
# 2023-04-30 10:03:28,930 INFO mapred.Task: Task 'attempt_local1265541845_0001_m_000009_0' done.
# 2023-04-30 10:03:28,931 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_m_000009_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=601870
# 		FILE: Number of bytes written=28736734
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=60
# 		Map output records=121062
# 		Map output bytes=2229929
# 		Map output materialized bytes=2472059
# 		Input split bytes=120
# 		Combine input records=0
# 		Spilled Records=121062
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=4
# 		Total committed heap usage (bytes)=447741952
# 	File Input Format Counters
# 		Bytes Read=36866
# 2023-04-30 10:03:28,931 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_m_000009_0
# 2023-04-30 10:03:28,931 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000010_0
# 2023-04-30 10:03:28,935 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:28,935 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:28,936 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:28,937 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2018_6_29.txt:0+23485
# 2023-04-30 10:03:28,940 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:28,965 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:28,966 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:28,966 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:28,966 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:28,966 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:28,967 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:28,974 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:29,001 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:29,001 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:29,105 INFO streaming.PipeMapRed: Records R/W=52/1
# 2023-04-30 10:03:29,686 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:29,686 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:29,687 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:29,687 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:29,687 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:29,687 INFO mapred.MapTask: bufstart = 0; bufend = 1092478; bufvoid = 104857600
# 2023-04-30 10:03:29,687 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25979856(103919424); length = 234541/6553600
# 2023-04-30 10:03:29,758 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:03:29,760 INFO mapred.Task: Task:attempt_local1265541845_0001_m_000010_0 is done. And is in the process of committing
# 2023-04-30 10:03:29,762 INFO mapred.LocalJobRunner: Records R/W=52/1
# 2023-04-30 10:03:29,762 INFO mapred.Task: Task 'attempt_local1265541845_0001_m_000010_0' done.
# 2023-04-30 10:03:29,763 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_m_000010_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=627220
# 		FILE: Number of bytes written=29946522
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=52
# 		Map output records=58636
# 		Map output bytes=1092478
# 		Map output materialized bytes=1209756
# 		Input split bytes=121
# 		Combine input records=0
# 		Spilled Records=58636
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=4
# 		Total committed heap usage (bytes)=447741952
# 	File Input Format Counters
# 		Bytes Read=23685
# 2023-04-30 10:03:29,763 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_m_000010_0
# 2023-04-30 10:03:29,763 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000011_0
# 2023-04-30 10:03:29,765 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:29,765 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:29,765 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:29,766 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2018_1_5.txt:0+22407
# 2023-04-30 10:03:29,771 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:29,805 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:29,805 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:29,805 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:29,805 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:29,805 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:29,806 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:29,811 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:29,833 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:29,833 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:29,904 INFO streaming.PipeMapRed: Records R/W=51/1
# 2023-04-30 10:03:30,445 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:30,446 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:30,446 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:30,446 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:30,446 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:30,446 INFO mapred.MapTask: bufstart = 0; bufend = 1032862; bufvoid = 104857600
# 2023-04-30 10:03:30,446 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25993560(103974240); length = 220837/6553600
# 2023-04-30 10:03:30,505 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:03:30,508 INFO mapred.Task: Task:attempt_local1265541845_0001_m_000011_0 is done. And is in the process of committing
# 2023-04-30 10:03:30,511 INFO mapred.LocalJobRunner: Records R/W=51/1
# 2023-04-30 10:03:30,511 INFO mapred.Task: Task 'attempt_local1265541845_0001_m_000011_0' done.
# 2023-04-30 10:03:30,512 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_m_000011_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=651484
# 		FILE: Number of bytes written=31089842
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=51
# 		Map output records=55210
# 		Map output bytes=1032862
# 		Map output materialized bytes=1143288
# 		Input split bytes=120
# 		Combine input records=0
# 		Spilled Records=55210
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=3
# 		Total committed heap usage (bytes)=447741952
# 	File Input Format Counters
# 		Bytes Read=22599
# 2023-04-30 10:03:30,513 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_m_000011_0
# 2023-04-30 10:03:30,513 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000012_0
# 2023-04-30 10:03:30,514 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:30,514 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:30,515 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:30,516 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2017_6_29.txt:0+22289
# 2023-04-30 10:03:30,520 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:30,549 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:30,549 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:30,549 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:30,550 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:30,550 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:30,552 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:30,557 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:30,589 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:30,589 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:30,650 INFO streaming.PipeMapRed: Records R/W=51/1
# 2023-04-30 10:03:31,214 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:31,215 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:31,215 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:31,215 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:31,215 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:31,215 INFO mapred.MapTask: bufstart = 0; bufend = 1020404; bufvoid = 104857600
# 2023-04-30 10:03:31,215 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25996348(103985392); length = 218049/6553600
# 2023-04-30 10:03:31,274 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:03:31,276 INFO mapred.Task: Task:attempt_local1265541845_0001_m_000012_0 is done. And is in the process of committing
# 2023-04-30 10:03:31,278 INFO mapred.LocalJobRunner: Records R/W=51/1
# 2023-04-30 10:03:31,278 INFO mapred.Task: Task 'attempt_local1265541845_0001_m_000012_0' done.
# 2023-04-30 10:03:31,279 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_m_000012_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=675630
# 		FILE: Number of bytes written=32219310
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=51
# 		Map output records=54513
# 		Map output bytes=1020404
# 		Map output materialized bytes=1129436
# 		Input split bytes=121
# 		Combine input records=0
# 		Spilled Records=54513
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=4
# 		Total committed heap usage (bytes)=447741952
# 	File Input Format Counters
# 		Bytes Read=22481
# 2023-04-30 10:03:31,279 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_m_000012_0
# 2023-04-30 10:03:31,279 INFO mapred.LocalJobRunner: Starting task: attempt_local1265541845_0001_m_000013_0
# 2023-04-30 10:03:31,280 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:03:31,280 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:03:31,281 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:03:31,282 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2017_1_1.txt:0+22051
# 2023-04-30 10:03:31,285 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:03:31,313 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:03:31,313 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:03:31,313 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:03:31,313 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:03:31,313 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:03:31,314 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:03:31,325 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_co_occur.py]
# 2023-04-30 10:03:31,342 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:31,356 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:31,423 INFO streaming.PipeMapRed: Records R/W=51/1
# 2023-04-30 10:03:31,973 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:31,974 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:31,975 INFO mapred.LocalJobRunner:
# 2023-04-30 10:03:31,975 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:03:31,975 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:03:31,975 INFO mapred.MapTask: bufstart = 0; bufend = 1045690; bufvoid = 104857600
# 2023-04-30 10:03:31,975 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25989976(103959904); length = 224421/6553600
# ...
# 2023-04-30 10:03:38,596 INFO reduce.InMemoryMapOutput: Read 3073379 bytes from map-output for attempt_local1265541845_0001_m_000002_0
# 2023-04-30 10:03:38,596 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 3073379, inMemoryMapOutputs.size() -> 5, commitMemory -> 6998406, usedMemory ->10071785
# 2023-04-30 10:03:38,599 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000005_0 decomp: 2608865 len: 2608869 to MEMORY
# 2023-04-30 10:03:38,602 INFO reduce.InMemoryMapOutput: Read 2608865 bytes from map-output for attempt_local1265541845_0001_m_000005_0
# 2023-04-30 10:03:38,602 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2608865, inMemoryMapOutputs.size() -> 6, commitMemory -> 10071785, usedMemory ->12680650
# 2023-04-30 10:03:38,606 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000011_0 decomp: 1143284 len: 1143288 to MEMORY
# 2023-04-30 10:03:38,608 INFO reduce.InMemoryMapOutput: Read 1143284 bytes from map-output for attempt_local1265541845_0001_m_000011_0
# 2023-04-30 10:03:38,608 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 1143284, inMemoryMapOutputs.size() -> 7, commitMemory -> 12680650, usedMemory ->13823934
# 2023-04-30 10:03:38,610 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000017_0 decomp: 725292 len: 725296 to MEMORY
# 2023-04-30 10:03:38,611 INFO reduce.InMemoryMapOutput: Read 725292 bytes from map-output for attempt_local1265541845_0001_m_000017_0
# 2023-04-30 10:03:38,611 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 725292, inMemoryMapOutputs.size() -> 8, commitMemory -> 13823934, usedMemory ->14549226
# 2023-04-30 10:03:38,613 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000004_0 decomp: 2764227 len: 2764231 to MEMORY
# 2023-04-30 10:03:38,616 INFO reduce.InMemoryMapOutput: Read 2764227 bytes from map-output for attempt_local1265541845_0001_m_000004_0
# 2023-04-30 10:03:38,616 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2764227, inMemoryMapOutputs.size() -> 9, commitMemory -> 14549226, usedMemory ->17313453
# 2023-04-30 10:03:38,618 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000010_0 decomp: 1209752 len: 1209756 to MEMORY
# 2023-04-30 10:03:38,621 INFO reduce.InMemoryMapOutput: Read 1209752 bytes from map-output for attempt_local1265541845_0001_m_000010_0
# 2023-04-30 10:03:38,621 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 1209752, inMemoryMapOutputs.size() -> 10, commitMemory -> 17313453, usedMemory ->18523205
# 2023-04-30 10:03:38,623 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000013_0 decomp: 1157904 len: 1157908 to MEMORY
# 2023-04-30 10:03:38,624 INFO reduce.InMemoryMapOutput: Read 1157904 bytes from map-output for attempt_local1265541845_0001_m_000013_0
# 2023-04-30 10:03:38,624 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 1157904, inMemoryMapOutputs.size() -> 11, commitMemory -> 18523205, usedMemory ->19681109
# 2023-04-30 10:03:38,627 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000000_0 decomp: 3081884 len: 3081888 to MEMORY
# 2023-04-30 10:03:38,634 INFO reduce.InMemoryMapOutput: Read 3081884 bytes from map-output for attempt_local1265541845_0001_m_000000_0
# 2023-04-30 10:03:38,634 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 3081884, inMemoryMapOutputs.size() -> 12, commitMemory -> 19681109, usedMemory ->22762993
# 2023-04-30 10:03:38,637 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000019_0 decomp: 623906 len: 623910 to MEMORY
# 2023-04-30 10:03:38,638 INFO reduce.InMemoryMapOutput: Read 623906 bytes from map-output for attempt_local1265541845_0001_m_000019_0
# 2023-04-30 10:03:38,638 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 623906, inMemoryMapOutputs.size() -> 13, commitMemory -> 22762993, usedMemory ->23386899
# 2023-04-30 10:03:38,641 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000006_0 decomp: 2797599 len: 2797603 to MEMORY
# 2023-04-30 10:03:38,644 INFO reduce.InMemoryMapOutput: Read 2797599 bytes from map-output for attempt_local1265541845_0001_m_000006_0
# 2023-04-30 10:03:38,644 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2797599, inMemoryMapOutputs.size() -> 14, commitMemory -> 23386899, usedMemory ->26184498
# 2023-04-30 10:03:38,649 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000012_0 decomp: 1129432 len: 1129436 to MEMORY
# 2023-04-30 10:03:38,650 INFO reduce.InMemoryMapOutput: Read 1129432 bytes from map-output for attempt_local1265541845_0001_m_000012_0
# 2023-04-30 10:03:38,650 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 1129432, inMemoryMapOutputs.size() -> 15, commitMemory -> 26184498, usedMemory ->27313930
# 2023-04-30 10:03:38,652 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000018_0 decomp: 538396 len: 538400 to MEMORY
# 2023-04-30 10:03:38,652 INFO reduce.InMemoryMapOutput: Read 538396 bytes from map-output for attempt_local1265541845_0001_m_000018_0
# 2023-04-30 10:03:38,653 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 538396, inMemoryMapOutputs.size() -> 16, commitMemory -> 27313930, usedMemory ->27852326
# 2023-04-30 10:03:38,654 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000021_0 decomp: 609470 len: 609474 to MEMORY
# 2023-04-30 10:03:38,655 INFO reduce.InMemoryMapOutput: Read 609470 bytes from map-output for attempt_local1265541845_0001_m_000021_0
# 2023-04-30 10:03:38,655 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 609470, inMemoryMapOutputs.size() -> 17, commitMemory -> 27852326, usedMemory ->28461796
# 2023-04-30 10:03:38,662 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000008_0 decomp: 2608943 len: 2608947 to MEMORY
# 2023-04-30 10:03:38,665 INFO reduce.InMemoryMapOutput: Read 2608943 bytes from map-output for attempt_local1265541845_0001_m_000008_0
# 2023-04-30 10:03:38,665 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2608943, inMemoryMapOutputs.size() -> 18, commitMemory -> 28461796, usedMemory ->31070739
# 2023-04-30 10:03:38,667 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000014_0 decomp: 878796 len: 878800 to MEMORY
# 2023-04-30 10:03:38,668 INFO reduce.InMemoryMapOutput: Read 878796 bytes from map-output for attempt_local1265541845_0001_m_000014_0
# 2023-04-30 10:03:38,668 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 878796, inMemoryMapOutputs.size() -> 19, commitMemory -> 31070739, usedMemory ->31949535
# 2023-04-30 10:03:38,682 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000001_0 decomp: 3070156 len: 3070160 to MEMORY
# 2023-04-30 10:03:38,686 INFO reduce.InMemoryMapOutput: Read 3070156 bytes from map-output for attempt_local1265541845_0001_m_000001_0
# 2023-04-30 10:03:38,686 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 3070156, inMemoryMapOutputs.size() -> 20, commitMemory -> 31949535, usedMemory ->35019691
# 2023-04-30 10:03:38,688 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000020_0 decomp: 581255 len: 581259 to MEMORY
# 2023-04-30 10:03:38,689 INFO reduce.InMemoryMapOutput: Read 581255 bytes from map-output for attempt_local1265541845_0001_m_000020_0
# 2023-04-30 10:03:38,689 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 581255, inMemoryMapOutputs.size() -> 21, commitMemory -> 35019691, usedMemory ->35600946
# 2023-04-30 10:03:38,692 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1265541845_0001_m_000007_0 decomp: 2559611 len: 2559615 to MEMORY
# 2023-04-30 10:03:38,697 INFO reduce.InMemoryMapOutput: Read 2559611 bytes from map-output for attempt_local1265541845_0001_m_000007_0
# 2023-04-30 10:03:38,697 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2559611, inMemoryMapOutputs.size() -> 22, commitMemory -> 35600946, usedMemory ->38160557
# 2023-04-30 10:03:38,698 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2023-04-30 10:03:38,699 INFO mapred.LocalJobRunner: 22 / 22 copied.
# 2023-04-30 10:03:38,699 INFO reduce.MergeManagerImpl: finalMerge called with 22 in-memory map-outputs and 0 on-disk map-outputs
# 2023-04-30 10:03:38,708 INFO mapred.Merger: Merging 22 sorted segments
# 2023-04-30 10:03:38,708 INFO mapred.Merger: Down to the last merge-pass, with 22 segments left of total size: 38160206 bytes
# 2023-04-30 10:03:39,848 INFO reduce.MergeManagerImpl: Merged 22 segments, 38160557 bytes to disk to satisfy reduce memory limit
# 2023-04-30 10:03:39,849 INFO reduce.MergeManagerImpl: Merging 1 files, 38160519 bytes from disk
# 2023-04-30 10:03:39,850 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2023-04-30 10:03:39,850 INFO mapred.Merger: Merging 1 sorted segments
# 2023-04-30 10:03:39,850 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 38160493 bytes
# 2023-04-30 10:03:39,851 INFO mapred.LocalJobRunner: 22 / 22 copied.
# 2023-04-30 10:03:39,856 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/reducer_co_occur.py]
# 2023-04-30 10:03:39,858 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-04-30 10:03:39,860 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2023-04-30 10:03:39,881 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:39,882 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:39,883 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:39,903 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:40,004 INFO streaming.PipeMapRed: Records R/W=9382/1
# 2023-04-30 10:03:40,008 INFO streaming.PipeMapRed: R/W/S=10000/596/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:40,321 INFO streaming.PipeMapRed: R/W/S=100000/10545/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:40,701 INFO streaming.PipeMapRed: R/W/S=200000/19605/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:03:41,109 INFO streaming.PipeMapRed: R/W/S=300000/26841/0 in:300000=300000/1 [rec/s] out:26841=26841/1 [rec/s]
# 2023-04-30 10:03:41,390 INFO streaming.PipeMapRed: R/W/S=400000/34074/0 in:400000=400000/1 [rec/s] out:34074=34074/1 [rec/s]
# 2023-04-30 10:03:41,646 INFO streaming.PipeMapRed: R/W/S=500000/42158/0 in:500000=500000/1 [rec/s] out:42158=42158/1 [rec/s]
# 2023-04-30 10:03:41,851 INFO streaming.PipeMapRed: R/W/S=600000/48881/0 in:600000=600000/1 [rec/s] out:48881=48881/1 [rec/s]
# 2023-04-30 10:03:41,988 INFO streaming.PipeMapRed: R/W/S=700000/57553/0 in:350000=700000/2 [rec/s] out:28776=57553/2 [rec/s]
# 2023-04-30 10:03:42,126 INFO streaming.PipeMapRed: R/W/S=800000/66526/0 in:400000=800000/2 [rec/s] out:33263=66526/2 [rec/s]
# 2023-04-30 10:03:42,257 INFO streaming.PipeMapRed: R/W/S=900000/75258/0 in:450000=900000/2 [rec/s] out:37629=75258/2 [rec/s]
# 2023-04-30 10:03:42,383 INFO streaming.PipeMapRed: R/W/S=1000000/81993/0 in:500000=1000000/2 [rec/s] out:40996=81993/2 [rec/s]
# 2023-04-30 10:03:42,506 INFO streaming.PipeMapRed: R/W/S=1100000/86315/0 in:550000=1100000/2 [rec/s] out:43157=86315/2 [rec/s]
# 2023-04-30 10:03:42,638 INFO streaming.PipeMapRed: R/W/S=1200000/92327/0 in:600000=1200000/2 [rec/s] out:46163=92327/2 [rec/s]
# 2023-04-30 10:03:42,761 INFO streaming.PipeMapRed: R/W/S=1300000/98966/0 in:650000=1300000/2 [rec/s] out:49483=98966/2 [rec/s]
# 2023-04-30 10:03:42,970 INFO streaming.PipeMapRed: R/W/S=1400000/108593/0 in:466666=1400000/3 [rec/s] out:36197=108593/3 [rec/s]
# 2023-04-30 10:03:43,093 INFO streaming.PipeMapRed: R/W/S=1500000/117438/0 in:500000=1500000/3 [rec/s] out:39146=117438/3 [rec/s]
# 2023-04-30 10:03:43,214 INFO streaming.PipeMapRed: R/W/S=1600000/124130/0 in:533333=1600000/3 [rec/s] out:41376=124130/3 [rec/s]
# 2023-04-30 10:03:43,342 INFO streaming.PipeMapRed: R/W/S=1700000/133493/0 in:566666=1700000/3 [rec/s] out:44497=133493/3 [rec/s]
# 2023-04-30 10:03:43,462 INFO streaming.PipeMapRed: R/W/S=1800000/139923/0 in:600000=1800000/3 [rec/s] out:46641=139923/3 [rec/s]
# 2023-04-30 10:03:43,568 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:03:43,569 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:03:43,570 INFO mapred.Task: Task:attempt_local1265541845_0001_r_000000_0 is done. And is in the process of committing
# 2023-04-30 10:03:43,572 INFO mapred.LocalJobRunner: 22 / 22 copied.
# 2023-04-30 10:03:43,572 INFO mapred.Task: Task attempt_local1265541845_0001_r_000000_0 is allowed to commit now
# 2023-04-30 10:03:43,578 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1265541845_0001_r_000000_0' to file:/cooccur-outputs
# 2023-04-30 10:03:43,580 INFO mapred.LocalJobRunner: Records R/W=9382/1 > reduce
# 2023-04-30 10:03:43,580 INFO mapred.Task: Task 'attempt_local1265541845_0001_r_000000_0' done.
# 2023-04-30 10:03:43,580 INFO mapred.Task: Final Counters for attempt_local1265541845_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=77148369
# 		FILE: Number of bytes written=79940956
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=146579
# 		Reduce shuffle bytes=38160645
# 		Reduce input records=1861911
# 		Reduce output records=146579
# 		Spilled Records=1861911
# 		Shuffled Maps =22
# 		Failed Shuffles=0
# 		Merged Map outputs=22
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=447741952
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=2830600
# 2023-04-30 10:03:43,580 INFO mapred.LocalJobRunner: Finishing task: attempt_local1265541845_0001_r_000000_0
# 2023-04-30 10:03:43,580 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2023-04-30 10:03:44,450 INFO mapreduce.Job:  map 100% reduce 100%
# 2023-04-30 10:03:44,451 INFO mapreduce.Job: Job job_local1265541845_0001 completed successfully
# 2023-04-30 10:03:44,490 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=90096350
# 		FILE: Number of bytes written=668036757
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1278
# 		Map output records=1861911
# 		Map output bytes=34436691
# 		Map output materialized bytes=38160645
# 		Input split bytes=2650
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=146579
# 		Reduce shuffle bytes=38160645
# 		Reduce input records=1861911
# 		Reduce output records=146579
# 		Spilled Records=3723822
# 		Shuffled Maps =22
# 		Failed Shuffles=0
# 		Merged Map outputs=22
# 		GC time elapsed (ms)=121
# 		Total committed heap usage (bytes)=10096738304
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=648242
# 	File Output Format Counters
# 		Bytes Written=2830600
# 2023-04-30 10:03:44,490 INFO streaming.StreamJob: Output directory: /cooccur-outputs

# %%
# Checking output:
# !$HADOOP_HOME/bin/hdfs dfs -ls /cooccur-outputs
# !$HADOOP_HOME/bin/hdfs dfs -cat /cooccur-outputs/part-00000
# Out:
# Streaming output truncated to the last 5000 lines.
# system,10	1
# system,2009	1
# system,2015	10
# system,2016	10
# system,2018	10
# system,3	8
# system,AI...It's	2
# system,AI...Its	7
# system,ATT	1
# system,BellKor	1
# system,CAA	16
# system,Chaos	1
# system,Concern	9
# system,Fei-Fei	9
# system,Google	20
# system,Inductive	19
# system,Language	10
# system,Li	9
# system,MNIST	7
# system,Machine	10
# system,Microsoft	10
# system,Pragmatic	1
# system,Research	1
# system,Responsible	12
# system,Rule-based	14
# system,Similar	10
# system,Team	1
# system,Theres	7
# system,Twitter	10
# system,W	8
# system,able	20
# system,action	8
# system,adopted	10
# system,advice	8
# system,algorithm	8
# system,algorithmic	12
# system,algorithms	10
# system,already	10
# system,andmost	9
# system,applicants	24
# system,applied	14
# system,approaches	14
# system,artificial	32
# system,assessment	10
# system,association	14
# system,backpropagated	8
# system,beat	1
# system,beginning	9
# system,behaves	8
# system,behavior	16
# system,behavioral	16
# system,bias	21
# system,biased	10
# system,biases	20
# system,billions	10
# system,black	20
# system,can	22
# system,challenges	10
# system,character	7
# system,chatbot	10
# system,classifier	14
# system,classify	4
# system,cognition	8
# system,collection	12
# system,commonly	14
# system,competition	1
# system,computational	4
# system,conditions	4
# system,consequence	8
# system,considers	19
# system,constitutional	10
# system,contain	10
# system,contains	8
# system,contrast	14
# system,created	9
# system,criminal	10
# system,critical	24
# system,current	10
# system,customer	10
# system,customers	10
# system,data	56
# system,dataset	7
# system,deliver	10
# system,derive	22
# system,desirable	8
# system,digital	7
# system,digits	6
# system,dimensionality	2
# system,distinguish	4
# system,documentation	12
# system,dollars	6
# system,domains	10
# system,driven	8
# system,duplicating	12
# system,effective	10
# system,email	8
# system,emotion	16
# system,emotions	8
# system,encountered	8
# system,engineers	9
# system,entails	22
# system,environment	48
# system,environments	8
# system,even	10
# system,example	7
# system,examples	22
# system,executes	8
# system,exists	8
# system,expressed	9
# system,failed	10
# system,fairness	8
# system,field	19
# system,folders	4
# system,following	8
# system,found	20
# system,functional	19
# system,genetic	16
# system,genome	8
# system,goal	2
# system,goal-seeking	6
# system,good	9
# system,gorilla	2
# system,gorillas	28
# system,grand	1
# system,groups	10
# system,guaranteed	4
# system,handwritten	6
# system,human	9
# system,human-like	10
# system,human-made	1
# system,hypotheses	19
# system,hypothesized	22
# system,identify	14
# system,immune	14
# system,impacts	9
# system,importantlyit	9
# system,include	14
# system,including	9
# system,increasingly	9
# system,initial	8
# system,initially	8
# system,input	24
# system,inspired	9
# system,instance	14
# system,instances	4
# system,intelligence	9
# system,interaction	8
# system,invested	6
# system,investment	4
# system,issues	10
# system,iteration	8
# system,job	12
# system,just	9
# system,key	4
# system,kind	19
# system,language	16
# system,languages	13
# system,learn	4
# system,learned	20
# system,learners	4
# system,learning	145
# system,learns	8
# system,least	1
# system,likely	10
# system,logic	41
# system,longer	10
# system,machine	98
# system,make	14
# system,man-made	9
# system,many	10
# system,matrix	8
# system,may	20
# system,memory	8
# system,messages	12
# system,meta	5
# system,meta-learning	2
# system,million	1
# system,minor	1
# system,misclassifies	4
# system,model	14
# system,modeling	7
# system,models	10
# system,needs	10
# system,negative	22
# system,neither	8
# system,new	14
# system,non-spam	8
# system,non-white	10
# system,none	4
# system,nothing	9
# system,object	4
# system,often	17
# system,one	24
# system,order	14
# system,output	8
# system,part	24
# system,people	57
# system,perform	4
# system,photos	10
# system,pick	10
# system,picked	10
# system,positive	22
# system,powerful	9
# system,predict	10
# system,prediction	14
# system,present	10
# system,previous	12
# system,prize	1
# system,prizes	1
# system,profound	9
# system,program	23
# system,programming	57
# system,programs	19
# system,propelling	9
# system,quickly	10
# system,racist	10
# system,real	10
# system,receives	8
# system,receiving	8
# system,recognition	7
# system,recognize	10
# system,recognizing	10
# system,reducing	9
# system,reduction	2
# system,reinforcement	16
# system,related	19
# system,reminds	9
# system,remove	10
# system,reportedly	10
# system,represented	10
# system,representing	19
# system,resolved	10
# system,responsibility	9
# system,risk	10
# system,routine	8
# system,rule	14
# system,rules	12
# system,s	6
# system,scientists	9
# system,scoring	12
# system,secondary	8
# system,seeking	2
# system,self-learning	8
# system,separate	8
# system,several	2
# system,sexist	10
# system,shown	10
# system,similarity	12
# system,singular	14
# system,situation	16
# system,situations	16
# system,society	10
# system,spam	8
# system,species	8
# system,specifically	5
# system,still	20
# system,study	4
# system,subfield	4
# system,successful	12
# system,system	12
# system,systems	48
# system,tag	10
# system,take	10
# system,task	7
# system,teams	1
# system,tested	10
# system,theory	4
# system,thus	34
# system,time	10
# system,tool	9
# system,topic	7
# system,toward	8
# system,trained	24
# system,training	20
# system,two	8
# system,unconscious	10
# system,understand	9
# system,undesirable	8
# system,universally	14
# system,unseen	4
# system,updates	8
# system,use	19
# system,used	33
# system,using	10
# system,value	8
# system,vector	8
# system,wa,s	8
# system,well	14
# system,wherefrom	8
# system,will	26
# system,winning	1
# system,won	1
# system,workaround	10
# system,years	10
# systematic,biomedical	6
# systematic,burden	12
# systematic,developed	6
# systematic,findings	6
# systematic,growth	6
# systematic,improved	6
# systematic,increased	6
# systematic,limiting	6
# systematic,literature	6
# systematic,necessary	6
# systematic,reduce	6
# systematic,related	6
# systematic,research	6
# systematic,review	6
# systematic,reviewer	6
# systematic,sensitivity	6
# systematic,sets	6
# systematic,sufficiently	6
# systematic,training	6
# systematic,without	6
# systematic,workload	6
# systematic,yet	6
# systems,	10
# systems,1980	18
# systems,2	3
# systems,2015	10
# systems,2016	20
# systems,2018	10
# systems,25	36
# systems,488	18
# systems,708710	36
# systems,755	34
# systems,AI	145
# systems,AI...It's	4
# systems,AI...Its	14
# systems,AI/CS	36
# systems,Concern	18
# systems,Data	2
# systems,Decision	4
# systems,Embedded	3
# systems,English	1
# systems,Fei-Fei	18
# systems,Generalization	4
# systems,Google	20
# systems,Hinton	36
# systems,Hopfield	36
# systems,Human	4
# systems,LCS	14
# systems,Learning	3
# systems,Li	18
# systems,MDP	20
# systems,Machine	17
# systems,Many	10
# systems,Markov	10
# systems,Microsoft	20
# systems,Neural	36
# systems,Process	4
# systems,Reinforcement	20
# systems,Rightarrow	10
# systems,Rumelhart	36
# systems,Running	3
# systems,Similar	10
# systems,States	11
# systems,Statistical	2
# systems,Theres	14
# systems,Twitter	20
# systems,United	11
# systems,Web	10
# systems,Work	36
# systems,XAI	4
# systems,abandoned	36
# systems,able	10
# systems,acceleration	3
# systems,accordance	8
# systems,acquisition	18
# systems,across	12
# systems,activities	10
# systems,addition	10
# systems,additional	5
# systems,addressed	6
# systems,adopt	4
# systems,adopted	20
# systems,adversarial	14
# systems,algorithm	19
# systems,algorithm's	11
# systems,algorithms	73
# systems,also	27
# systems,analysis	16
# systems,analytics	2
# systems,analyze	2
# systems,and/or	6
# systems,andmost	18
# systems,animal	20
# systems,application	14
# systems,applications	5
# systems,applied	3
# systems,apply	14
# systems,approach	4
# systems,approximate	3
# systems,area	2
# systems,areas	10
# systems,around	36
# systems,artificial	52
# systems,assessment	10
# systems,association	34
# systems,assume	10
# systems,attempt	8
# systems,autonomous	10
# systems,b	10
# systems,backpropagation	36
# systems,based	2
# systems,basis	10
# systems,basket	10
# systems,beginning	18
# systems,bias	18
# systems,biased	10
# systems,biases	19
# systems,bioinformatics	10
# systems,biological	20
# systems,black	20
# systems,brains	20
# systems,breaches	3
# systems,brittle	8
# systems,build	3
# systems,burger	10
# systems,business	5
# systems,buy	10
# systems,buys	10
# systems,came	36
# systems,can	26
# systems,care	22
# systems,certain	1
# systems,challenges	20
# systems,changing	8
# systems,characterization	4
# systems,chatbot	20
# systems,classify	4
# systems,closely	2
# systems,cloud	3
# systems,collaborative	4
# systems,collectively	14
# systems,combine	14
# systems,come	36
# systems,complex	6
# systems,component	28
# systems,computational	6
# systems,computer	39
# systems,computers	5
# systems,computing	16
# systems,conditions	4
# systems,connectionism	36
# systems,consider	10
# systems,considering	30
# systems,constitute	20
# systems,contain	1
# systems,context-dependent	14
# systems,continue	36
# systems,continued	36
# systems,continuous	10
# systems,contrast	10
# systems,conventional	1
# systems,corpora	1
# systems,created	18
# systems,criminal	10
# systems,customer	10
# systems,data	83
# systems,data.citation	1
# systems,datacitation	1
# systems,decision	6
# systems,decisions	15
# systems,deep	2
# systems,delivers	2
# systems,designed	22
# systems,designer	4
# systems,detection	11
# systems,develop	3
# systems,devices	6
# systems,diagnose	11
# systems,diagnostics	2
# systems,different	2
# systems,difficult	1
# systems,dilemma	11
# systems,discarding	1
# systems,disciplines	36
# systems,discovery	14
# systems,dismantling	2
# systems,displaystyle	10
# systems,distinguish	4
# systems,domains	22
# systems,dominate	36
# systems,dynamic	10
# systems,e	20
# systems,e.g	6
# systems,edge	3
# systems,effective	20
# systems,effectively	4
# systems,either	24
# systems,eliminate	4
# systems,eliminated	4
# systems,email	13
# systems,embedded	3
# systems,employed	10
# systems,engineers	18
# systems,entirely	4
# systems,environment	10
# systems,equipped	1
# systems,especially	11
# systems,ethical	11
# systems,ethics	1
# systems,evasion	6
# systems,even	6
# systems,exact	20
# systems,example	27
# systems,examples	30
# systems,expert	18
# systems,explanation	2
# systems,explicit	2
# systems,explicitly	3
# systems,exploratory	2
# systems,expressed	18
# systems,extended	2
# systems,face	10
# systems,fairness	16
# systems,family	14
# systems,favor	36
# systems,field	76
# systems,fields	1
# systems,filtering	3
# systems,finding	2
# systems,fits	4
# systems,focuses	4
# systems,folders	4
# systems,found	30
# systems,framework	2
# systems,g	10
# systems,game	10
# systems,generally	30
# systems,generating	3
# systems,genetic	24
# systems,good	18
# systems,gorilla	2
# systems,gorillas	28
# systems,great	6
# systems,greed	6
# systems,guaranteed	4
# systems,hamburger	10
# systems,happen	6
# systems,happening	3
# systems,hardware	3
# systems,health	22
# systems,heavily	1
# systems,help	2
# systems,henceforth	3
# systems,historical	1
# systems,hold	11
# systems,however	4
# systems,huge	6
# systems,human	37
# systems,identify	14
# systems,identity	10
# systems,immune	14
# systems,impacts	18
# systems,implementation	2
# systems,importantlyit	18
# systems,improve	1
# systems,improving	11
# systems,including	69
# systems,income	3
# systems,income-generating	8
# systems,increase	4
# systems,increasing	7
# systems,increasingly	18
# systems,indicate	10
# systems,induces	8
# systems,inductive	36
# systems,infeasible	13
# systems,inference	2
# systems,information	47
# systems,inputs	2
# systems,inspired	38
# systems,instances	4
# systems,instead	2
# systems,instructions	4
# systems,intellectual	3
# systems,intelligence	30
# systems,interest	11
# systems,intruders	1
# systems,intrusion	10
# systems,intuition	8
# systems,issues	10
# systems,items	10
# systems,just	18
# systems,key	4
# systems,knowledge	24
# systems,known	3
# systems,language	21
# systems,languages	1
# systems,large-scale	2
# systems,leading	36
# systems,leaks	3
# systems,learn	39
# systems,learned	20
# systems,learning	295
# systems,likely	10
# systems,limited	3
# systems,line	72
# systems,logic	36
# systems,logical	1
# systems,long-standing	7
# systems,longer	20
# systems,lot	1
# systems,machine	119
# systems,machines	12
# systems,main	36
# systems,make	17
# systems,making	3
# systems,manipulation	6
# systems,manner	14
# systems,many	15
# systems,market	10
# systems,marketing	10
# systems,mathematical	15
# systems,mathrm	20
# systems,may	22
# systems,meat	10
# systems,mechanisms	4
# systems,medical	2
# systems,medicate	11
# systems,medication	11
# systems,mentioned	6
# systems,message	1
# systems,messages	12
# systems,methods	2
# systems,microcontrollers	3
# systems,mid-1980s	36
# systems,might	11
# systems,minimizes	3
# systems,mining	22
# systems,misclassification	2
# systems,misclassification.citation	6
# systems,misconceptions	2
# systems,mitigated	5
# systems,model	16
# systems,models	19
# systems,morality	1
# systems,must	4
# systems,n	20
# systems,necessarily	1
# systems,need	7
# systems,needed	8
# systems,network	3
# systems,networks	58
# systems,neural	24
# systems,new	4
# systems,non-pattern	4
# systems,non-spam	8
# systems,non-white	10
# systems,nothing	18
# systems,now	36
# systems,o	40
# systems,object	4
# systems,objectivity	1
# systems,often	16
# systems,onions	10
# systems,onions,potatoes	10
# systems,opponent	10
# systems,optimization	5
# systems,order	29
# systems,others	4
# systems,outside	72
# systems,overfitting	4
# systems,owners	11
# systems,p	10
# systems,paths	11
# systems,patients	22
# systems,pattern	36
# systems,patterns	2
# systems,penalizing	4
# systems,people	84
# systems,perform	41
# systems,performance	1
# systems,performing	17
# systems,perpetual	4
# systems,personal	9
# systems,perturbations	4
# systems,photos	10
# systems,physics	2
# systems,picked	20
# systems,piecewise	14
# systems,pixel	8
# systems,placements	10
# systems,plagued	18
# systems,plan	11
# systems,play	10
# systems,potatoes	10
# systems,potential	11
# systems,powerful	18
# systems,practical	18
# systems,predictably	8
# systems,predictions	19
# systems,predictive	2
# systems,previously	6
# systems,pricing	10
# systems,privacy	3
# systems,problems	22
# systems,process	8
# systems,processing	3
# systems,product	10
# systems,production	10
# systems,professionals	11
# systems,profits	11
# systems,profound	18
# systems,programmed	33
# systems,programming	46
# systems,progressively	1
# systems,promises	2
# systems,promotional	10
# systems,propelling	18
# systems,proper	36
# systems,properties	3
# systems,property	4
# systems,proprietary	11
# systems,provide	22
# systems,public's	11
# systems,questions	1
# systems,quickly	20
# systems,r	20
# systems,racist	20
# systems,raises	1
# systems,rather	2
# systems,real	10
# systems,realm	1
# systems,reasoning	1
# systems,recognition	36
# systems,recognize	10
# systems,recognizing	10
# systems,recovery	11
# systems,reduce	4
# systems,reducing	21
# systems,referred	2
# systems,reinforcement	23
# systems,reinforcements	1
# systems,reinvention	36
# systems,related	2
# systems,rely	2
# systems,relying	2
# systems,reminds	18
# systems,remove	10
# systems,removes	3
# systems,reportedly	10
# systems,represent	1
# systems,representation	18
# systems,represented	14
# systems,requires	5
# systems,research	72
# systems,researchers	36
# systems,resolved	10
# systems,resources	3
# systems,responsibility	18
# systems,retrieval	36
# systems,rewarding	4
# systems,right	2
# systems,risk	10
# systems,rule	34
# systems,rule-based	14
# systems,rules	54
# systems,s	20
# systems,sales	10
# systems,sample	3
# systems,science	36
# systems,scientific	1
# systems,scientists	18
# systems,search	4
# systems,secrets	3
# systems,seek	14
# systems,seen	2
# systems,sequence	10
# systems,servers	3
# systems,set	15
# systems,several	3
# systems,sexist	20
# systems,simply	1
# systems,since	4
# systems,single	8
# systems,social	2
# systems,space	2
# systems,spam	8
# systems,speaker	10
# systems,specific	5
# systems,specify	4
# systems,stakes	11
# systems,statistical	36
# systems,statistics	48
# systems,still	20
# systems,store	14
# systems,storing	3
# systems,study	8
# systems,subfield	4
# systems,subset	2
# systems,success	36
# systems,supermarket	10
# systems,supermarkets	10
# systems,supervised	14
# systems,swarm	10
# systems,symbolic/knowledge-based	36
# systems,system	8
# systems,system's	4
# systems,systems	76
# systems,t	20
# systems,tag	10
# systems,take	20
# systems,task	9
# systems,task-specific	30
# systems,tasks	30
# systems,technical	1
# systems,techniques	13
# systems,tested	20
# systems,tests	11
# systems,theft	3
# systems,theoretical	18
# systems,theory	18
# systems,thus	12
# systems,time	36
# systems,today	10
# systems,together	12
# systems,tool	29
# systems,tracking	10
# systems,trained	5
# systems,training	13
# systems,transaction	10
# systems,transactions	10
# systems,transferring	6
# systems,true	11
# systems,typically	34
# systems,u	10
# systems,understand	18
# systems,unnecessary	11
# systems,unseen	4
# systems,unsupervised	16
# systems,usage	10
# systems,use	51
# systems,used	51
# systems,users	2
# systems,using	17
# systems,vaguely	20
# systems,variety	2
# systems,vehicles	10
# systems,verification	20
# systems,via	6
# systems,vision	3
# systems,visual	10
# systems,vulnerable	6
# systems,wearable	3
# systems,weight	2
# systems,well	19
# systems,wide	2
# systems,will	15
# systems,within	48
# systems,without	35
# systems,word	1
# systems,words	1
# systems,work	2
# systems,workaround	10
# t,Rightarrow	20
# t,Web	20
# t,across	20
# t,activities	20
# t,addition	20
# t,also	20
# t,analysis	20
# t,application	20
# t,areas	20
# t,association	40
# t,b	20
# t,basis	20
# t,basket	20
# t,bioinformatics	20
# t,burger	20
# t,buy	20
# t,buys	20
# t,can	20
# t,consider	20
# t,continuous	20
# t,contrast	20
# t,customer	20
# t,data	20
# t,decisions	20
# t,detection	20
# t,displaystyle	20
# t,e	40
# t,either	20
# t,employed	20
# t,found	20
# t,g	20
# t,hamburger	20
# t,including	20
# t,indicate	20
# t,information	20
# t,intrusion	20
# t,items	20
# t,learning	20
# t,likely	20
# t,market	20
# t,marketing	20
# t,mathrm	40
# t,meat	20
# t,mining	40
# t,o	20
# t,onions	20
# t,onions,potatoes	20
# t,order	20
# t,placements	20
# t,potatoes	20
# t,pricing	20
# t,product	20
# t,production	20
# t,promotional	20
# t,r	40
# t,rule	20
# t,rules	20
# t,s	20
# t,sales	20
# t,sequence	20
# t,supermarket	20
# t,t	10
# t,today	20
# t,together	20
# t,transaction	20
# t,transactions	20
# t,typically	20
# t,u	20
# t,usage	20
# t,used	20
# t,within	20
# tackling,2019	1
# tackling,AI	21
# tackling,Daniel	1
# tackling,Dr	1
# tackling,Hulme	1
# tackling,Internet	8
# tackling,Yet	1
# tackling,ability	4
# tackling,also	11
# tackling,approaches	18
# tackling,argues	1
# tackling,assert	1
# tackling,availability	11
# tackling,away	18
# tackling,benefited	11
# tackling,borrowed	18
# tackling,company	1
# tackling,continue	1
# tackling,digitized	11
# tackling,distribute	11
# tackling,example	1
# tackling,field	2
# tackling,focus	18
# tackling,fuzzy	3
# tackling,increasing	11
# tackling,information	11
# tackling,inherited	18
# tackling,internet	3
# tackling,learning	2
# tackling,logic	3
# tackling,machine	2
# tackling,many	1
# tackling,methods	18
# tackling,models	18
# tackling,nature	18
# tackling,operating	1
# tackling,possibility	7
# tackling,practical	18
# tackling,practitioners	1
# tackling,probability	18
# tackling,problems	18
# tackling,remains	1
# tackling,runs	1
# tackling,separate	1
# tackling,shifted	18
# tackling,solvable	18
# tackling,sources	1
# tackling,statistics	18
# tackling,sub	1
# tackling,symbolic	18
# tackling,teaches	1
# tackling,theory	18
# tackling,toward	18
# tackling,via	11
# tag,2016	10
# tag,2018	10
# tag,AI...It's	2
# tag,AI...Its	7
# tag,Concern	9
# tag,Fei-Fei	9
# tag,Google	10
# tag,Li	9
# tag,Microsoft	10
# tag,Similar	10
# tag,Theres	7
# tag,Twitter	10
# tag,URL	1
# tag,able	10
# tag,address	1
# tag,adopted	10
# tag,andmost	9
# tag,artificial	18
# tag,beginning	9
# tag,bias	9
# tag,black	10
# tag,challenges	10
# tag,chatbot	10
# tag,created	9
# tag,current	1
# tag,data	10
# tag,differ	1
# tag,display	1
# tag,domains	10
# tag,effective	10
# tag,engineers	9
# tag,expressed	9
# tag,fairness	8
# tag,fix	1
# tag,found	10
# tag,good	9
# tag,gorilla	2
# tag,gorillas	28
# tag,human	9
# tag,impacts	9
# tag,importantlyit	9
# tag,including	9
# tag,increasingly	9
# tag,inspired	9
# tag,intelligence	9
# tag,issues	11
# tag,just	9
# tag,language	10
# tag,learned	10
# tag,learning	27
# tag,link	1
# tag,longer	10
# tag,machine	27
# tag,many	10
# tag,may	11
# tag,non-white	10
# tag,nothing	9
# tag,people	47
# tag,permanent	1
# tag,picked	10
# tag,powerful	9
# tag,present	1
# tag,profound	9
# tag,propelling	9
# tag,quickly	10
# tag,racist	10
# tag,real	10
# tag,recognize	10
# tag,recognizing	10
# tag,reducing	9
# tag,reminds	9
# tag,remove	10
# tag,reportedly	10
# tag,resolved	10
# tag,responsibility	9
# tag,revision	2
# tag,scientists	9
# tag,sexist	10
# tag,significantly	1
# tag,still	20
# tag,systems	10
# tag,take	10
# tag,tested	10
# tag,thus	10
# tag,tool	9
# tag,training	10
# tag,understand	9
# tag,use	19
# tag,using	10
# tag,well	10
# tag,workaround	10
# take,AI...It's	2
# take,AI...Its	7
# take,Concern	9
# take,Decision	14
# take,Due	10
# take,Fei-Fei	9
# take,Instead	10
# take,Li	9
# take,MDP	20
# take,Many	10
# take,Markov	10
# take,Process	4
# take,Reinforcement	56
# take,Theres	7
# take,Though	7
# take,absence	10
# take,achieving	5
# take,actions	63
# take,adopted	10
# take,agent	12
# take,algorithms	72
# take,analysis	20
# take,andmost	9
# take,application	10
# take,artificial	18
# take,assume	10
# take,attempt	12
# take,autonomous	10
# take,based	10
# take,beginning	9
# take,bias	9
# take,branches	10
# take,called	30
# take,can	50
# take,categorized	10
# take,central	10
# take,chance	5
# take,class	20
# take,classification	30
# take,classified	10
# take,clustering	10
# take,commonalities	20
# take,conjunctions	10
# take,contains	10
# take,continuous	20
# take,control	10
# take,correct	24
# take,corrected	24
# take,created	9
# take,cumulative	10
# take,data	110
# take,decision	102
# take,decision-making	4
# take,decisions	20
# take,density	17
# take,describes	20
# take,differs	24
# take,disciplines	10
# take,discrete	10
# take,domains	20
# take,dynamic	10
# take,encompasses	10
# take,engineers	9
# take,environment	32
# take,estimation	10
# take,exact	20
# take,explaining	10
# take,explicitly	44
# take,expressed	9
# take,fairness	8
# take,features	20
# take,feedback	10
# take,field	20
# take,find	22
# take,finding	7
# take,function	7
# take,game	20
# take,generality	10
# take,genetic	10
# take,goals	5
# take,good	9
# take,grouping	10
# take,human	19
# take,identify	10
# take,impacts	9
# take,importantlyit	9
# take,including	9
# take,increasingly	9
# take,infeasible	10
# take,information	10
# take,input	20
# take,input/output	24
# take,inputs	10
# take,inspired	9
# take,intelligence	19
# take,involving	10
# take,just	9
# take,knowledge	10
# take,labeled	10
# take,labels	20
# take,lead	10
# take,learn	10
# take,learning	157
# take,leaves	10
# take,like	10
# take,long-term	12
# take,longer	10
# take,machine	27
# take,making	36
# take,many	10
# take,maps	12
# take,mathematical	10
# take,maximize	27
# take,mining	20
# take,model	10
# take,models	10
# take,multi-agent	10
# take,never	24
# take,new	10
# take,nothing	9
# take,notion	22
# take,numbers	20
# take,operations	10
# take,opponent	10
# take,optimization	10
# take,pairs	24
# take,people	27
# take,piece	10
# take,play	10
# take,points	10
# take,policy	12
# take,powerful	9
# take,presence	10
# take,presented	24
# take,probability	7
# take,problem	24
# take,process	6
# take,profound	9
# take,programming	10
# take,propelling	9
# take,react	10
# take,real	20
# take,reducing	9
# take,regression	20
# take,reinforcement	9
# take,reinforcements	1
# take,reminds	9
# take,represent	40
# take,represented	10
# take,research	10
# take,responding	10
# take,responsibility	9
# take,resulting	20
# take,reward	22
# take,scientists	9
# take,set	20
# take,simulation-based	10
# take,states	36
# take,statistics	20
# take,structure	10
# take,structures	10
# take,studied	10
# take,sub-optimal	24
# take,successfully	5
# take,summarizing	10
# take,supervised	24
# take,swarm	10
# take,systems	10
# take,take	22
# take,target	10
# take,techniques	10
# take,test	10
# take,theory	30
# take,therefore	10
# take,though	3
# take,tool	9
# take,tree	70
# take,trees	40
# take,typically	30
# take,understand	9
# take,unsupervised	30
# take,use	19
# take,used	40
# take,values	30
# take,variable	10
# take,vehicles	10
# take,visually	20
# take,world	12
# taking,advantage	8
# taking,dimensional	2
# taking,higher	2
# taking,higher-dimensional	6
# taking,implicitly	8
# taking,input	8
# taking,kernel	8
# taking,map	8
# taking,space	8
# taking,trick	8
# taking,variables	8
# talk,	2
# talk,03:25	1
# talk,05:27	1
# talk,08:38	1
# talk,09:35	1
# talk,1	4
# talk,103.206.105.70	1
# talk,10:19	1
# talk,10:25	1
# talk,11:15	1
# talk,12:27	1
# talk,12:32	1
# talk,13:05	1
# talk,13:14	1
# talk,14.98.185.26	1
# talk,146.201.25.75	2
# talk,15:11	1
# talk,18:12	1
# talk,19	1
# talk,19:50	1
# talk,19:55	1
# talk,2	3
# talk,2013	2
# talk,2014	2
# talk,2015	2
# talk,2016	2
# talk,2017	2
# talk,2018	2
# talk,2019	2
# talk,2020	2
# talk,2021	2
# talk,2022	2
# talk,2023	1
# talk,20:02	1
# talk,20:46	1
# talk,22:56	1
# talk,22:57	1
# talk,23:06	1
# talk,23:10	1
# talk,24	1
# talk,27	1
# talk,28	1
# talk,29	2
# talk,3	1
# talk,30	3
# talk,4	3
# talk,5	1
# talk,8	2
# talk,Adding	1
# talk,Approaches	1
# talk,Artificial	1
# talk,Azure	2
# talk,Change	1
# talk,Commercial	1
# talk,External	1
# talk,Fixed	1
# talk,Free	1
# talk,Genetic	1
# talk,HPE	1
# talk,History	1
# talk,IB-Learning	1
# talk,Improve	1
# talk,January	11
# talk,Journals	1
# talk,June	10
# talk,Learning	2
# talk,Limitations	1
# talk,Machine	2
# talk,Microsoft	1
# talk,Proprietary	1
# talk,Removed	1
# talk,Replace	1
# talk,Reverted	2
# talk,TW	4
# talk,Theory	1
# talk,URL	24
# talk,WP:LINKSPAM	1
# talk,WP:MOS	2
# talk,add	1
# talk,address	23
# talk,already	1
# talk,anchorGeneralization	1
# talk,applications	1
# talk,bold	2
# talk,columns	1
# talk,commercial	1
# talk,conferences	1
# talk,contribs	14
# talk,copyeditor	1
# talk,correct	1
# talk,current	23
# talk,destination	1
# talk,differ	23
# talk,display	2
# talk,duplicate	1
# talk,edit	1
# talk,edits	1
# talk,external	1
# talk,faith	1
# talk,fields	1
# talk,fix	1
# talk,formatting	1
# talk,good	1
# talk,got	1
# talk,grammar	1
# talk,importantly	1
# talk,intelligence	1
# talk,issues	1
# talk,killed	2
# talk,last	2
# talk,link	23
# talk,links	2
# talk,list	1
# talk,may	23
# talk,open-source	1
# talk,per	1
# talk,period	1
# talk,permanent	23
# talk,present	23
# talk,products	1
# talk,programming	1
# talk,promoted	1
# talk,rather	1
# talk,reading	1
# talk,refend	1
# talk,references	1
# talk,relationships	1
# talk,revision	48
# talk,rv	1
# talk,see	2
# talk,semi-colon	1
# talk,significantly	23
# talk,software	3
# talk,softwareanchorOpen-sourcesoftware	1
# talk,spam	1
# talk,tag	1
# talk,talk	2
# talk,text	1
# talk,titles	2
# talk,typo	1
# talk,variety	1
# talk,wasnt	1
# talk,websites	1
# talks,Rebellion	3
# talks,Research's	3
# talks,crisis	3
# talks,economic	3
# talks,financial	3
# talks,prediction	3
# talks,recovery	3
# tape,10	3
# tape,1960s	3
# tape,1970s	3
# tape,1973	3
# tape,1981	3
# tape,26	3
# tape,4	3
# tape,40	3
# tape,Company	3
# tape,CyberTron	1
# tape,Cybertron	2
# tape,Duda	3
# tape,Hart	3
# tape,Interest	3
# tape,Learning	3
# tape,Machines	3
# tape,Nilsson's	3
# tape,Raytheon	3
# tape,analyze	3
# tape,book	6
# tape,button	3
# tape,called	3
# tape,cause	3
# tape,characters	3
# tape,classification	3
# tape,computer	3
# tape,continued	3
# tape,dealing	3
# tape,decisions	3
# tape,described	3
# tape,developed	3
# tape,digits	3
# tape,electrocardiograms	3
# tape,equipped	3
# tape,given	3
# tape,goof	3
# tape,human	3
# tape,incorrect	3
# tape,learning	9
# tape,learns	3
# tape,letters	3
# tape,machine	6
# tape,memory	3
# tape,mostly	3
# tape,network	3
# tape,neural	3
# tape,operator/teacher	3
# tape,pattern	6
# tape,patterns	6
# tape,re-evaluate	3
# tape,recognition	3
# tape,recognize	6
# tape,reinforcement	3
# tape,related	3
# tape,repetitively	3
# tape,report	3
# tape,representative	3
# tape,research	3
# tape,rudimentary	3
# tape,signals	3
# tape,sonar	3
# tape,special	3
# tape,speech	3
# tape,strategies	3
# tape,symbols	3
# tape,teaching	3
# tape,terminal	3
# tape,trained	3
# tape,using	6
# target,Algorithmic	3
# target,Bias	3
# target,Data	3
# target,Decision	20
# target,Machine	3
# target,Overfitting	3
# target,Trained	3
# target,Transduction	6
# target,Tree	10
# target,analysis	30
# target,approaches	10
# target,becoming	3
# target,bias	3
# target,biased	3
# target,branches	20
# target,called	50
# target,can	116
# target,case	6
# target,class	40
# target,classification	50
# target,collect	3
# target,collected	3
# target,collection	3
# target,conjunctions	20
# target,continuous	30
# target,corpus	3
# target,data	85
# target,decision	144
# target,decision-making	6
# target,decisions	30
# target,derived	3
# target,describes	30
# target,detrimental	3
# target,discrete	20
# target,engineering	3
# target,entire	6
# target,ethics	3
# target,except	6
# target,explicitly	30
# target,features	20
# target,field	3
# target,fully	3
# target,furthering	3
# target,images	3
# target,impacts	3
# target,individual	3
# target,input	30
# target,instances	6
# target,integrated	3
# target,known	6
# target,labels	40
# target,large	3
# target,lead	20
# target,learning	25
# target,leaves	30
# target,machine	16
# target,making	54
# target,may	3
# target,mining	40
# target,missing	12
# target,model	3
# target,modeling	10
# target,models	16
# target,negative	3
# target,non-evaluated	3
# target,notably	3
# target,numbers	30
# target,objectives	3
# target,one	10
# target,outcomes	3
# target,outputs	6
# target,part	6
# target,potential	3
# target,predictions	3
# target,predictive	10
# target,prepared	3
# target,principle	6
# target,problem	6
# target,real	30
# target,regression	30
# target,represent	70
# target,representative	3
# target,represented	10
# target,result	9
# target,resulting	30
# target,sample	3
# target,sensor	3
# target,service	3
# target,set	29
# target,skewed	3
# target,society	3
# target,something	3
# target,special	6
# target,statistics	10
# target,structures	20
# target,study	3
# target,take	50
# target,target	30
# target,targets	6
# target,teams	3
# target,text	3
# target,thereby	3
# target,time	6
# target,training	9
# target,tree	110
# target,trees	70
# target,typically	30
# target,undesired	3
# target,used	40
# target,users	3
# target,value	22
# target,values	50
# target,variable	50
# target,varied	3
# target,visually	30
# target,watch	3
# target,within	3
# targets,missing	6
# task,2	6
# task,Data	6
# task,Evaluated	22
# task,GA	1
# task,KDD	22
# task,MNIST	7
# task,Machine	15
# task,Semi-supervised	3
# task,ability	1
# task,according	1
# task,across	6
# task,algorithm	9
# task,algorithms	13
# task,also	6
# task,analysis	6
# task,analytics	6
# task,application	12
# task,applications	6
# task,artificial	2
# task,available	3
# task,based	2
# task,build	3
# task,business	6
# task,cases	3
# task,certain	3
# task,character	7
# task,closely	6
# task,computational	7
# task,computer	8
# task,computers	6
# task,contained	6
# task,conventional	2
# task,data	63
# task,dataset	7
# task,decisions	3
# task,delivers	6
# task,designating	3
# task,desired	1
# task,detection	2
# task,determined	1
# task,determining	3
# task,develop	9
# task,difficult	2
# task,digital	7
# task,digits	6
# task,discovery	22
# task,domains	6
# task,due	44
# task,easily	22
# task,effectively	3
# task,email	6
# task,explicit	2
# task,explicitly	4
# task,exploratory	6
# task,feedback.clarification	3
# task,field	12
# task,filtering	6
# task,fitness	1
# task,focuses	12
# task,genetic	1
# task,given	1
# task,handwritten	6
# task,image	6
# task,images	3
# task,include	3
# task,incomplete	3
# task,individual	1
# task,infeasible	6
# task,inference	2
# task,input	8
# task,inputs	1
# task,instead	2
# task,instructions	6
# task,intelligence	2
# task,intended	5
# task,intruders	2
# task,knowledge	44
# task,known	25
# task,label	3
# task,labels	2
# task,landscape	1
# task,learning	46
# task,machine	19
# task,make	3
# task,making	6
# task,mathematical	12
# task,may	3
# task,method	22
# task,methods	72
# task,mining	6
# task,missing	1
# task,model	3
# task,models	3
# task,needed	3
# task,network	2
# task,object	9
# task,often	7
# task,optimization	6
# task,optimize	1
# task,order	3
# task,outperformed	22
# task,output	4
# task,partially	3
# task,patterns	2
# task,perform	4
# task,performing	6
# task,population	1
# task,portion	3
# task,predictions	9
# task,predictive	6
# task,previously	22
# task,problem	5
# task,problems	6
# task,program	1
# task,program's	1
# task,programmed	4
# task,programs	1
# task,recognition	7
# task,referred	6
# task,related	6
# task,relying	2
# task,respect	22
# task,restricted	3
# task,sample	6
# task,seen	2
# task,solve	5
# task,special	6
# task,specialization	1
# task,specific	4
# task,statistics	6
# task,study	12
# task,subset	2
# task,supervised	69
# task,task	32
# task,technique	1
# task,theory	6
# task,training	53
# task,typical	22
# task,unavailability	44
# task,uninformed	22
# task,unknown	22
# task,unsupervised	28
# task,used	58
# task,using	8
# task,variety	4
# task,vision	6
# task,whether	6
# task,wide	4
# task,will	22
# task,within	6
# task,without	9
# task-specific,rules	10
# tasks,3	8
# tasks,Alan	56
# tasks,Artificial	10
# tasks,Can	112
# tasks,Computing	56
# tasks,E	44
# tasks,Example	4
# tasks,However	10
# tasks,Intelligence	56
# tasks,MNIST	7
# tasks,Machine	9
# tasks,Machinery	56
# tasks,OCR	8
# tasks,Optical	4
# tasks,P	66
# tasks,Semi-supervised	3
# tasks,T	66
# tasks,Turing's	81
# tasks,advanced	21
# tasks,algorithm	41
# tasks,algorithmically	10
# tasks,algorithms	90
# tasks,alternative	10
# tasks,although	3
# tasks,analysis	4
# tasks,answers	21
# tasks,applications	13
# tasks,approach	7
# tasks,arises	8
# tasks,artificial	2
# tasks,assigned	21
# tasks,attempts	10
# tasks,automatically	4
# tasks,available	18
# tasks,based	5
# tasks,biology	10
# tasks,board	20
# tasks,breach	4
# tasks,broad	11
# tasks,build	1
# tasks,builds	3
# tasks,can	122
# tasks,carry	7
# tasks,cases	10
# tasks,categories	11
# tasks,certain	10
# tasks,challenging	28
# tasks,character	19
# tasks,characteristics	19
# tasks,characters	4
# tasks,classic	4
# tasks,classification	10
# tasks,classified	11
# tasks,cognitive	56
# tasks,computationally	10
# tasks,computer	36
# tasks,computer's	21
# tasks,computers	28
# tasks,concerned	36
# tasks,conflated	4
# tasks,considering	10
# tasks,considers	8
# tasks,constructing	19
# tasks,contained	6
# tasks,contains	3
# tasks,convenient	10
# tasks,conventional	1
# tasks,correct	14
# tasks,create	28
# tasks,data	57
# tasks,dataset	7
# tasks,decisions	1
# tasks,define	10
# tasks,defining	56
# tasks,definition	80
# tasks,depending	8
# tasks,designating	3
# tasks,designing	8
# tasks,desired	12
# tasks,detection	4
# tasks,determine	7
# tasks,determining	3
# tasks,develop	32
# tasks,deviations	10
# tasks,diagnosis	20
# tasks,difficult	4
# tasks,digital	7
# tasks,digits	6
# tasks,discover	10
# tasks,effective	28
# tasks,email	4
# tasks,engineering	1
# tasks,engines	5
# tasks,entities	56
# tasks,evaluation	10
# tasks,every	28
# tasks,examination	10
# tasks,example	18
# tasks,examples	14
# tasks,execute	21
# tasks,exist	7
# tasks,experience	44
# tasks,explicit	18
# tasks,explicitly	8
# tasks,exploratory	4
# tasks,explores	4
# tasks,exposed	15
# tasks,facets	3
# tasks,features	20
# tasks,feedback	8
# tasks,feedback.clarification	3
# tasks,field	39
# tasks,filtering	29
# tasks,focuses	4
# tasks,following	20
# tasks,follows	36
# tasks,fully	7
# tasks,fundamentally	56
# tasks,games	20
# tasks,generally	10
# tasks,good	3
# tasks,hand	21
# tasks,handwritten	6
# tasks,help	28
# tasks,human	56
# tasks,image	6
# tasks,images	13
# tasks,implications	19
# tasks,improve	7
# tasks,improves	44
# tasks,include	11
# tasks,including	20
# tasks,incomplete	3
# tasks,infeasible	7
# tasks,input	18
# tasks,inputs	4
# tasks,insiders	4
# tasks,intelligence	2
# tasks,intruders	4
# tasks,involves	7
# tasks,known	2
# tasks,label	10
# tasks,labels	2
# tasks,lack	10
# tasks,latter	1
# tasks,leading	10
# tasks,learning	126
# tasks,machine	148
# tasks,machine-learned	8
# tasks,machines	112
# tasks,make	1
# tasks,malicious	4
# tasks,manually	28
# tasks,mathematical	6
# tasks,mathematically	10
# tasks,may	3
# tasks,measure	22
# tasks,measured	44
# tasks,medical	20
# tasks,medicine	1
# tasks,mining	4
# tasks,missing	1
# tasks,model	4
# tasks,models	3
# tasks,nature	6
# tasks,needed	81
# tasks,network	24
# tasks,networks	10
# tasks,neural	10
# tasks,notable	20
# tasks,numbers	7
# tasks,object	9
# tasks,offers	36
# tasks,often	17
# tasks,one	34
# tasks,operational	56
# tasks,optical	8
# tasks,order	1
# tasks,output	12
# tasks,outputs	3
# tasks,paper	56
# tasks,part	23
# tasks,partially	3
# tasks,pattern	3
# tasks,people	10
# tasks,perform	1
# tasks,performance	47
# tasks,playing	20
# tasks,portion	3
# tasks,possessed	19
# tasks,possible	21
# tasks,potential	7
# tasks,practice	28
# tasks,predictions	1
# tasks,previous	4
# tasks,printed	4
# tasks,problem	21
# tasks,problems	10
# tasks,process	10
# tasks,program	21
# tasks,programmed	18
# tasks,programmers	28
# tasks,programming	8
# tasks,proposal	75
# tasks,provided	7
# tasks,question	112
# tasks,rank	3
# tasks,rather	84
# tasks,real-world	10
# tasks,recognition	43
# tasks,recognized	4
# tasks,relying	10
# tasks,replaced	56
# tasks,representations	10
# tasks,require	10
# tasks,required	21
# tasks,resources	10
# tasks,restricted	3
# tasks,rule-based	1
# tasks,rules	10
# tasks,sample	4
# tasks,satisfactory	7
# tasks,search	5
# tasks,seen	2
# tasks,sensory	10
# tasks,set	3
# tasks,several	3
# tasks,signal	8
# tasks,simple	14
# tasks,social	20
# tasks,solve	21
# tasks,sometimes	4
# tasks,spam	5
# tasks,special	6
# tasks,specific	10
# tasks,specify	28
# tasks,speech	21
# tasks,step	28
# tasks,steps	21
# tasks,sub-field	1
# tasks,successful	4
# tasks,supervised	6
# tasks,system	23
# tasks,task	10
# tasks,task-specific	10
# tasks,tasks	99
# tasks,telling	21
# tasks,terms	56
# tasks,think	56
# tasks,thinking	75
# tasks,thorough	1
# tasks,three	6
# tasks,thus	20
# tasks,tools	10
# tasks,towards	4
# tasks,train	7
# tasks,training	14
# tasks,translation	20
# tasks,turn	28
# tasks,two	5
# tasks,typically	8
# tasks,unfeasible	2
# tasks,unsupervised	1
# tasks,used	25
# tasks,uses	7
# tasks,valid	7
# tasks,variety	11
# tasks,various	38
# tasks,vast	7
# tasks,video	30
# tasks,viewed	3
# tasks,vii	4
# tasks,vision	29
# tasks,whether	8
# tasks,wide	1
# tasks,without	31
# tasks,working	4
# tasks,wrong	10
# tasks,yielded	10
# taxonomy,algorithm	4
# taxonomy,available	4
# taxonomy,based	4
# taxonomy,citation	1
# taxonomy,desired	4
# taxonomy,input	4
# taxonomy,machine	2
# taxonomy,machinecitation	2
# taxonomy,needed	3
# taxonomy,outcome	4
# taxonomy,training	4
# taxonomy,type	4
# teach,MNIST	7
# teach,accomplish	7
# teach,algorithm	7
# teach,algorithms	7
# teach,answers	21
# teach,approach	7
# teach,available	7
# teach,can	7
# teach,cases	7
# teach,character	7
# teach,computer	7
# teach,computers	7
# teach,correct	14
# teach,data	7
# teach,dataset	7
# teach,determine	7
# teach,digital	7
# teach,digits	6
# teach,example	7
# teach,exist	7
# teach,fully	7
# teach,handwritten	6
# teach,improve	7
# teach,label	7
# teach,learn	1
# teach,numbers	7
# teach,often	7
# teach,one	7
# teach,potential	7
# teach,recognition	7
# teach,satisfactory	7
# teach,system	7
# teach,task	7
# teach,tasks	7
# teach,train	7
# teach,training	7
# teach,used	14
# teach,uses	7
# teach,valid	7
# teach,vast	7
# teacher,CAA	8
# teacher,Transduction	6
# teacher,W	8
# teacher,actions	8
# teacher,advice	6
# teacher,advices	2
# teacher,algorithm	16
# teacher,case	6
# teacher,cognition	8
# teacher,computes	8
# teacher,consequence	8
# teacher,crossbar	8
# teacher,decisions	8
# teacher,driven	8
# teacher,emotion	8
# teacher,emotions	8
# teacher,entire	6
# teacher,except	6
# teacher,executes	8
# teacher,fashion	8
# teacher,feelings	8
# teacher,following	8
# teacher,gives	6
# teacher,incomplete	6
# teacher,instances	6
# teacher,interaction	8
# teacher,iteration	8
# teacher,known	6
# teacher,learning	14
# teacher,machine	8
# teacher,many	6
# teacher,matrix	8
# teacher,memory	8
# teacher,missing	12
# teacher,often	6
# teacher,outputs	6
# teacher,part	6
# teacher,principle	6
# teacher,problem	6
# teacher,routine	8
# teacher,self-learning	16
# teacher,set	12
# teacher,signal	6
# teacher,situations	8
# teacher,special	6
# teacher,system	8
# teacher,target	6
# teacher,targets	6
# teacher,time	6
# teacher,training	12
# teacher,updates	8
# teacher,wa,s	8
# teachers,active	8
# teachers,guidance	8
# teachers,imitation	8
# teachers,learning	8
# teachers,maturation	8
# teachers,mechanisms	8
# teachers,motor	8
# teachers,synergies	8
# teachers,using	8
# teaches,AI	2
# teaches,argues	1
# teaches,company	1
# teaches,field	1
# teaches,learning	1
# teaches,machine	1
# teaches,operating	1
# teaches,runs	1
# teaches,separate	1
# teaching,10	8
# teaching,26	8
# teaching,4	8
# teaching,40	8
# teaching,488	1
# teaching,AI	1
# teaching,Already	1
# teaching,Probabilistic	1
# teaching,academic	1
# teaching,also	1
# teaching,approach	1
# teaching,artificial	1
# teaching,attempted	1
# teaching,automated	1
# teaching,characters	8
# teaching,computer	8
# teaching,data	1
# teaching,days	1
# teaching,diagnosis	1
# teaching,digits	8
# teaching,discipline	1
# teaching,early	1
# teaching,employed	1
# teaching,endeavor	1
# teaching,especially	1
# teaching,found	1
# teaching,generalized	1
# teaching,grew	1
# teaching,intelligence	1
# teaching,interested	1
# teaching,later	1
# teaching,learn	1
# teaching,learning	1
# teaching,learns	8
# teaching,letters	8
# teaching,linear	1
# teaching,machine	1
# teaching,machines	1
# teaching,medical	1
# teaching,methods	1
# teaching,models	2
# teaching,mostly	1
# teaching,network	8
# teaching,networks	1
# teaching,neural	9
# teaching,perceptrons	1
# teaching,problem	1
# teaching,quest	1
# teaching,reasoning	1
# teaching,recognize	8
# teaching,reinventions	1
# teaching,researchers	1
# teaching,scientific	1
# teaching,special	8
# teaching,statistics	1
# teaching,strategies	8
# teaching,symbolic	1
# teaching,symbols	8
# teaching,termed	1
# teaching,terminal	8
# teaching,various	1
# teaching,well	1
# team,1	21
# team,2009	21
# team,2010	10
# team,2012	10
# team,2014	10
# team,2019	9
# team,2020	5
# team,80	10
# team,ATT	21
# team,Big	21
# team,COVID-19	5
# team,Chaos	21
# team,Grand	21
# team,Journal	10
# team,Khosla	10
# team,Labs-Research	21
# team,Machine	5
# team,Microsystems	10
# team,Nature	9
# team,Netflix	17
# team,Pragmatic	21
# team,Prize	21
# team,Rebellion	10
# team,Recently	5
# team,Research	10
# team,Shortly	17
# team,Springer	9
# team,Street	10
# team,Sun	10
# team,Theory	21
# team,Vinod	10
# team,Wall	10
# team,accordingly	17
# team,aid	5
# team,algorithm	10
# team,also	5
# team,among	9
# team,applied	20
# team,art	20
# team,artists	9
# team,artists.In	1
# team,automated	10
# team,awarded	17
# team,based	5
# team,behavior	6
# team,behaviour	4
# team,best	17
# team,book	9
# team,built	21
# team,changed	17
# team,co-founder	10
# team,collaboration	21
# team,created	9
# team,crisis	10
# team,cure	5
# team,decades	10
# team,developing	5
# team,diagnoses	5
# team,diagnostic	10
# team,doctors	3
# team,doctors'	7
# team,engine	17
# team,ensemble	21
# team,everything	17
# team,field	10
# team,financial	10
# team,fine	10
# team,firm	10
# team,first	9
# team,green	3
# team,help	5
# team,history	10
# team,human-being	3
# team,indicators	17
# team,influences	10
# team,interaction	5
# team,jobs	10
# team,learning	54
# team,lost	10
# team,machine	49
# team,made	21
# team,make	5
# team,may	10
# team,medical	20
# team,million	21
# team,model	21
# team,next	10
# team,optimise	4
# team,optimize	1
# team,paintings	10
# team,patterns	17
# team,performance	5
# team,phone	5
# team,predict	15
# team,predicted	10
# team,previously	10
# team,prize	17
# team,pro-environmental	2
# team,published	9
# team,ratings	17
# team,realized	17
# team,recently	5
# team,recommendation	34
# team,reported	10
# team,research	9
# team,researchers	26
# team,revealed	10
# team,smartphone's	5
# team,software	10
# team,study	10
# team,teams	21
# team,technology	10
# team,thermal	5
# team,travelers	2
# team,two	10
# team,unrecognized	10
# team,use	10
# team,used	5
# team,user's	5
# team,using	9
# team,viewers'	17
# team,viewing	17
# team,win	21
# team,wrote	10
# teams,1	22
# teams,2009	22
# teams,2010	10
# teams,2012	10
# teams,2014	10
# teams,2019	9
# teams,2020	5
# teams,80	10
# teams,Big	21
# teams,COVID-19	5
# teams,Chaos	22
# teams,Grand	21
# teams,Journal	10
# teams,Khosla	10
# teams,Machine	5
# teams,Microsystems	10
# teams,Nature	9
# teams,Netflix	17
# teams,Pragmatic	22
# teams,Prize	21
# teams,Rebellion	10
# teams,Recently	5
# teams,Research	10
# teams,Shortly	17
# teams,Springer	9
# teams,Street	10
# teams,Sun	10
# teams,Theory	21
# teams,Vinod	10
# teams,Wall	10
# teams,accordingly	17
# teams,aid	5
# teams,algorithm	10
# teams,also	5
# teams,among	9
# teams,applied	20
# teams,art	20
# teams,artists	9
# teams,artists.In	1
# teams,automated	10
# teams,awarded	17
# teams,based	5
# teams,behavior	6
# teams,behaviour	4
# teams,best	17
# teams,book	9
# teams,built	21
# teams,changed	17
# teams,co-founder	10
# teams,competition	1
# teams,created	9
# teams,crisis	10
# teams,cure	5
# teams,decades	10
# teams,developing	5
# teams,diagnoses	5
# teams,diagnostic	10
# teams,doctors	3
# teams,doctors'	7
# teams,engine	17
# teams,ensemble	21
# teams,everything	17
# teams,field	10
# teams,financial	10
# teams,fine	10
# teams,firm	10
# teams,first	9
# teams,grand	1
# teams,green	3
# teams,help	5
# teams,history	10
# teams,human-being	3
# teams,indicators	17
# teams,influences	10
# teams,interaction	5
# teams,jobs	10
# teams,learning	55
# teams,lost	10
# teams,machine	50
# teams,make	5
# teams,may	10
# teams,medical	20
# teams,million	22
# teams,minor	1
# teams,model	21
# teams,next	10
# teams,optimise	4
# teams,optimize	1
# teams,paintings	10
# teams,patterns	17
# teams,performance	5
# teams,phone	5
# teams,predict	15
# teams,predicted	10
# teams,previously	10
# teams,prize	18
# teams,prizes	1
# teams,pro-environmental	2
# teams,program	1
# teams,published	9
# teams,ratings	17
# teams,realized	17
# teams,recently	5
# teams,recommendation	34
# teams,reported	10
# teams,research	9
# teams,researchers	5
# teams,revealed	10
# teams,several	1
# teams,smartphone's	5
# teams,software	10
# teams,study	10
# teams,technology	10
# teams,thermal	5
# teams,travelers	2
# teams,two	10
# teams,unrecognized	10
# teams,use	10
# teams,used	5
# teams,user's	5
# teams,using	9
# teams,viewers'	17
# teams,viewing	17
# teams,win	21
# teams,winning	1
# teams,won	1
# teams,wrote	10
# technical,also	6
# technical,biases	12
# technical,contain	6
# technical,corpora	6
# technical,data	6
# technical,decisions	6
# technical,fields	5
# technical,heavily	6
# technical,historical	6
# technical,human	6
# technical,information	6
# technical,language	6
# technical,languages	6
# technical,learn	6
# technical,logical	6
# technical,machines	6
# technical,necessarily	6
# technical,objectivity	6
# technical,reasoning	6
# technical,rely	12
# technical,scientific	1
# technical,trained	6
# technical,will	6
# technique,1980s	10
# technique,1990s	10
# technique,Conversely	10
# technique,ability	1
# technique,according	1
# technique,algorithms	20
# technique,allows	20
# technique,analysis	12
# technique,coming	10
# technique,computational	1
# technique,computer	1
# technique,configurations	10
# technique,crossover	10
# technique,data	12
# technique,data-generating	10
# technique,determined	1
# technique,distribution	20
# technique,engineering	10
# technique,evolutionary	10
# technique,faithful	10
# technique,feature	10
# technique,features	10
# technique,finding	10
# technique,fitness	1
# technique,generate	10
# technique,genetic	20
# technique,genotypes	10
# technique,given	11
# technique,good	10
# technique,hope	10
# technique,implausible	10
# technique,improve	10
# technique,inputs	10
# technique,landscape	1
# technique,learn	10
# technique,learning	20
# technique,machine	30
# technique,manual	10
# technique,methods	10
# technique,mimics	10
# technique,mutation	10
# technique,natural	10
# technique,necessarily	10
# technique,new	10
# technique,optimize	1
# technique,perform	11
# technique,performance	10
# technique,population	1
# technique,problem	10
# technique,process	10
# technique,program's	1
# technique,programs	1
# technique,reconstruction	10
# technique,replaces	10
# technique,selection	10
# technique,solutions	10
# technique,specific	10
# technique,statistical	12
# technique,task	11
# technique,techniques	10
# technique,unknown	10
# technique,use	10
# technique,used	21
# technique,using	10
# techniques,	1
# techniques,1	10
# techniques,1/3	14
# techniques,2/3	14
# techniques,2D	8
# techniques,3D	8
# techniques,AUC	2
# techniques,Area	1
# techniques,Clustering	12
# techniques,Curve	1
# techniques,FNR	1
# techniques,FPR	1
# techniques,False	2
# techniques,Higher	1
# techniques,Holdout	8
# techniques,K	18
# techniques,K-1	9
# techniques,K-fold-cross-validation	9
# techniques,MDP	10
# techniques,N-fold-cross-validation	4
# techniques,Negative	2
# techniques,One	5
# techniques,PCA	8
# techniques,Positive	2
# techniques,ROC	2
# techniques,Rate	4
# techniques,Receiver	1
# techniques,Reinforcement	20
# techniques,Semi-supervised	30
# techniques,Similarly	1
# techniques,Statistical	2
# techniques,Supervised	20
# techniques,TNR	1
# techniques,TPR	1
# techniques,True	2
# techniques,Unsupervised	10
# techniques,ability	6
# techniques,abnormal	30
# techniques,acceleration	3
# techniques,accompanying	1
# techniques,accuracy	15
# techniques,addition	15
# techniques,additional	1
# techniques,algorithms	38
# techniques,along	5
# techniques,analysis	17
# techniques,analyze	2
# techniques,anomalies	20
# techniques,anomaly	60
# techniques,applications	2
# techniques,applied	1
# techniques,approximate	3
# techniques,area	10
# techniques,assess	14
# techniques,assessment	2
# techniques,associated	1
# techniques,assume	10
# techniques,assumption	28
# techniques,assumptions	22
# techniques,autonomous	10
# techniques,based	22
# techniques,behavior	40
# techniques,better	1
# techniques,bootstrap	14
# techniques,called	1
# techniques,can	24
# techniques,changing	8
# techniques,characteristic	1
# techniques,classification	31
# techniques,classifier	30
# techniques,cluster	22
# techniques,clusters	22
# techniques,common	12
# techniques,compactness	22
# techniques,comparison	14
# techniques,component	5
# techniques,computed	1
# techniques,computers	1
# techniques,computing	3
# techniques,connectivity	22
# techniques,considered	5
# techniques,considering	9
# techniques,construct	40
# techniques,conventionally	14
# techniques,cross-validation	14
# techniques,data	214
# techniques,dataset	14
# techniques,deep	2
# techniques,deep-rooted	1
# techniques,defined	22
# techniques,density	22
# techniques,derived	2
# techniques,designation	14
# techniques,detect	20
# techniques,detection	90
# techniques,diagnostics	2
# techniques,difference	40
# techniques,different	34
# techniques,dimension	4
# techniques,dimensionality	9
# techniques,disordered	2
# techniques,e.g	10
# techniques,either	5
# techniques,elimination	5
# techniques,enhance	1
# techniques,estimated	22
# techniques,evaluated	22
# techniques,evaluates	14
# techniques,evaluation	9
# techniques,evolutionary	17
# techniques,exact	20
# techniques,example	22
# techniques,exist	10
# techniques,experiments	9
# techniques,explicitly	1
# techniques,extended	2
# techniques,extraction	5
# techniques,feature	5
# techniques,finding	2
# techniques,fit	20
# techniques,game	10
# techniques,generated	40
# techniques,genetic	17
# techniques,give	1
# techniques,given	40
# techniques,graph	22
# techniques,hardware	3
# techniques,high-dimensional	4
# techniques,higher-dimensional	4
# techniques,holdout	20
# techniques,human	10
# techniques,hypothesis	4
# techniques,i.e	1
# techniques,improve	18
# techniques,including	5
# techniques,infeasible	10
# techniques,inherent	6
# techniques,inherently	24
# techniques,instance	45
# techniques,instances	59
# techniques,instead	4
# techniques,internal	22
# techniques,involves	34
# techniques,k	6
# techniques,k-1	4
# techniques,k-fold-cross-validation	1
# techniques,keeping	4
# techniques,key	30
# techniques,knowledge	10
# techniques,kth	5
# techniques,labeled	30
# techniques,large-scale	2
# techniques,leading	8
# techniques,learn	1
# techniques,learning	56
# techniques,least	20
# techniques,lie	4
# techniques,like	14
# ...
# thereby,learning	6
# thereby,machine	3
# thereby,negative	3
# thereby,notably	3
# thereby,objectives	3
# thereby,potential	3
# thereby,prepared	3
# thereby,result	3
# thereby,society	3
# thereby,study	3
# thereby,teams	3
# thereby,training	3
# thereby,within	3
# therefore,Instead	10
# therefore,Though	7
# therefore,absence	10
# therefore,algorithms	10
# therefore,application	10
# therefore,based	10
# therefore,categorized	10
# therefore,central	10
# therefore,classified	10
# therefore,commonalities	20
# therefore,data	40
# therefore,density	17
# therefore,domains	10
# therefore,encompasses	10
# therefore,estimation	10
# therefore,explaining	10
# therefore,features	10
# therefore,feedback	10
# therefore,field	10
# therefore,finding	7
# therefore,function	7
# therefore,identify	10
# therefore,involving	10
# therefore,labeled	10
# therefore,learn	10
# therefore,learning	30
# therefore,new	10
# therefore,piece	10
# therefore,presence	10
# therefore,probability	7
# therefore,react	10
# therefore,responding	10
# therefore,statistics	10
# therefore,summarizing	10
# therefore,test	10
# therefore,though	3
# therefore,unsupervised	30
# thermal,based	5
# thermal,behavior	1
# thermal,behaviour	4
# thermal,interaction	5
# thermal,phone	5
# thermal,user's	5
# think,Can	22
# think,Turing's	5
# think,can	22
# think,characteristics	7
# think,constructing	7
# think,entities	22
# think,explores	2
# think,exposed	5
# think,implications	7
# think,machine	7
# think,machines	22
# think,one	7
# think,possessed	7
# think,proposal	7
# think,question	22
# think,replaced	22
# think,thinking	29
# think,various	14
# thinking,Turing's	5
# thinking,can	22
# thinking,characteristics	7
# thinking,constructing	14
# thinking,entities	22
# thinking,explores	2
# thinking,exposed	10
# thinking,implications	14
# thinking,machine	14
# thinking,one	14
# thinking,possessed	7
# thinking,proposal	7
# thinking,thinking	7
# thinking,various	21
# third,Parties	3
# third,access	3
# third,can	3
# third,cases	3
# third,change	3
# third,classification	3
# third,data/software	3
# third,including	6
# third,input	3
# third,parties	3
# third,possibly	3
# third,provided	3
# third,transparency	3
# third,type	3
# third,white-box	3
# thorough,algorithms	1
# thorough,examination	1
# thorough,explicit	1
# thorough,relying	1
# thorough,without	1
# though,data	3
# though,domains	3
# though,encompasses	3
# though,explaining	3
# though,features	3
# though,involving	3
# though,learning	3
# though,summarizing	3
# though,unsupervised	3
# three,available	13
# three,broad	13
# three,categories	13
# three,correspond	2
# three,depending	13
# three,feedback	13
# three,learning	21
# three,nature	13
# three,paradigms	2
# three,signal	13
# three,system	13
# three-fold,categorisation	5
# three-fold,categorization	2
# three-fold,dimensionality	2
# three-fold,example	7
# three-fold,learning	12
# three-fold,machine	7
# three-fold,meta	5
# three-fold,meta-learning	2
# three-fold,modeling	7
# three-fold,one	7
# three-fold,reduction	2
# three-fold,sometimes	7
# three-fold,system	7
# three-fold,topic	7
# three-fold,used	7
# threshold,Different	20
# threshold,Signals	20
# threshold,Typically	20
# threshold,aggregate	10
# threshold,aggregated	20
# threshold,artificial	20
# threshold,crosses	10
# threshold,different	20
# threshold,first	20
# threshold,input	20
# threshold,inputs	20
# threshold,kinds	20
# threshold,last	20
# threshold,layer	80
# threshold,layers	60
# threshold,may	20
# threshold,multiple	20
# threshold,neurons	20
# threshold,output	20
# threshold,perform	20
# threshold,possibly	20
# threshold,sent	10
# threshold,signal	20
# threshold,threshold	10
# threshold,times	20
# threshold,transformations	20
# threshold,travel	20
# threshold,traversing	20
# thus,1988	5
# thus,2016	10
# thus,60	5
# thus,AI...It's	2
# thus,AI...Its	7
# thus,AUC	13
# thus,Alan	10
# thus,Area	7
# thus,Can	20
# thus,Characteristic	5
# thus,Commission	5
# thus,Computing	10
# thus,Concern	9
# thus,Curve	7
# thus,Equality	5
# thus,Fei-Fei	9
# thus,George's	5
# thus,Intelligence	10
# thus,Li	9
# thus,Machine	2
# thus,Machinery	10
# thus,Medical	5
# thus,Microsoft	10
# thus,Operating	5
# thus,ROC	13
# thus,ROC's	11
# thus,ROCs	2
# thus,Racial	5
# thus,Receiver	7
# thus,Responsible	15
# thus,School	5
# thus,See	2
# thus,Similar	10
# thus,St	5
# thus,TOC	13
# thus,Theres	7
# thus,Turing's	15
# thus,Twitter	10
# thus,UK's	5
# thus,Using	5
# thus,able	10
# thus,additional	2
# thus,admissions	5
# thus,adopted	10
# thus,algorithmic	12
# thus,andmost	9
# thus,applicants	24
# thus,applications	2
# thus,area	8
# thus,artificial	18
# thus,associated	13
# thus,beginning	9
# thus,bias	21
# thus,can	10
# thus,candidates	5
# thus,challenges	10
# thus,characteristic	8
# thus,characteristics	2
# thus,chatbot	10
# thus,classism	2
# thus,collection	15
# thus,commonly	13
# thus,computer	5
# thus,constructing	2
# thus,created	9
# thus,critical	30
# thus,cultural	15
# thus,curve	6
# thus,data	32
# thus,denied	5
# thus,diagnostics	2
# thus,digitizing	15
# thus,documentation	12
# thus,domains	10
# thus,duplicating	12
# thus,effective	10
# thus,either	5
# thus,engineers	9
# thus,entities	10
# thus,ethics	2
# thus,example	12
# thus,explores	2
# thus,expressed	9
# thus,fairness	8
# thus,finding	2
# thus,firm	12
# thus,following	10
# thus,found	20
# thus,good	9
# thus,gorillas	10
# thus,hiring	24
# thus,human	9
# thus,impacts	9
# thus,implications	2
# thus,importantlyit	9
# thus,including	9
# thus,increasingly	9
# thus,information	15
# thus,inspired	9
# thus,institutional	2
# thus,intelligence	9
# thus,issues	10
# thus,job	24
# thus,just	9
# thus,language	10
# thus,lead	12
# thus,learned	10
# thus,learning	69
# thus,longer	10
# thus,machine	71
# thus,machines	20
# thus,many	10
# thus,may	22
# thus,medical	2
# thus,names	5
# thus,nearly	5
# thus,non-European	5
# thus,non-white	10
# thus,nothing	9
# thus,one	2
# thus,operating	8
# thus,paper	10
# thus,part	30
# thus,people	37
# thus,picked	10
# thus,policies	12
# thus,possessed	2
# thus,powerful	9
# thus,prejudices	15
# thus,previous	17
# thus,profound	9
# thus,program	10
# thus,propelling	9
# thus,proposal	12
# thus,provides	13
# thus,question	20
# thus,quickly	10
# thus,racism	2
# thus,racist	22
# thus,real	10
# thus,receiver	6
# thus,recognize	10
# thus,recognizing	10
# thus,reducing	9
# thus,reminds	9
# thus,replaced	10
# thus,responsibility	9
# thus,rules	12
# thus,scientists	9
# thus,scoring	12
# thus,sexist	10
# thus,similarity	12
# thus,sounding	5
# thus,staff	5
# thus,successful	12
# thus,system	24
# thus,systems	10
# thus,take	10
# thus,tested	10
# thus,think	10
# thus,thinking	12
# thus,thus	15
# thus,tool	9
# thus,trained	5
# thus,understand	9
# thus,use	19
# thus,used	25
# thus,using	12
# thus,various	4
# thus,women	5
# ties,Example	4
# ties,Loss	17
# ties,Machine	19
# ties,OCR	4
# ties,actual	17
# ties,algorithms	15
# ties,also	4
# ties,although	3
# ties,analysis	8
# ties,anomalies	4
# ties,application	8
# ties,applications	4
# ties,arises	11
# ties,artificial	1
# ties,assign	17
# ties,baseline	4
# ties,behavioral	4
# ties,can	18
# ties,character	4
# ties,classification	17
# ties,computer	4
# ties,computing	4
# ties,concerned	11
# ties,conflated	8
# ties,correctly	17
# ties,data	16
# ties,deliver	2
# ties,delivers	6
# ties,designing	4
# ties,difference	11
# ties,discrepancy	17
# ties,domains	8
# ties,employed	4
# ties,engines	4
# ties,entities	4
# ties,establish	4
# ties,example	17
# ties,examples	34
# ties,explicit	4
# ties,exploratory	8
# ties,express	17
# ties,facets	3
# ties,field	11
# ties,fields	11
# ties,filtering	4
# ties,find	4
# ties,focuses	8
# ties,formulated	17
# ties,function	17
# ties,functions	17
# ties,generalization	11
# ties,goal	11
# ties,include	4
# ties,infeasible	3
# ties,instances	34
# ties,intelligence	1
# ties,known	5
# ties,label	17
# ties,labels	17
# ties,latter	5
# ties,learn	4
# ties,learning	52
# ties,loss	39
# ties,machine	11
# ties,many	17
# ties,mathematical	7
# ties,meaningful	4
# ties,methods	8
# ties,minimization	17
# ties,minimize	11
# ties,minimizing	11
# ties,mining	8
# ties,model	17
# ties,models	17
# ties,one	17
# ties,optical	4
# ties,optimization	36
# ties,pattern	3
# ties,pre-assigned	17
# ties,predict	17
# ties,predictions	17
# ties,problem	17
# ties,problems	17
# ties,profiles	4
# ties,programming	4
# ties,range	4
# ties,recognition	7
# ties,rule-based	1
# ties,samples	11
# ties,search	4
# ties,set	45
# ties,sometimes	8
# ties,spam	4
# ties,sub-field	1
# ties,subfield	4
# ties,tasks	4
# ties,theory	8
# ties,trained	34
# ties,training	28
# ties,two	14
# ties,unfeasible	1
# ties,unseen	11
# ties,unsupervised	9
# ties,used	8
# ties,various	4
# ties,viewed	3
# ties,vii	8
# ties,vision	4
# ties,wants	17
# time,10	1
# time,1960s	1
# time,1970s	1
# time,1973	1
# time,1981	1
# time,25	18
# time,26	1
# time,4	1
# time,40	1
# time,AI/CS	18
# time,Artificial	10
# time,Duda	1
# time,Hart	1
# time,Hinton	18
# time,Hopfield	18
# time,Interest	1
# time,Learning	1
# time,Machines	1
# time,Negative	88
# time,Nilsson's	1
# time,Positive	66
# time,Rumelhart	18
# time,attention	10
# time,backpropagation	18
# time,billions	10
# time,biology	10
# time,board	10
# time,book	2
# time,came	18
# time,can	88
# time,certain	154
# time,characters	1
# time,class	66
# time,classes	88
# time,classification	1
# time,complexity	88
# time,computation	22
# time,computational	22
# time,computer	11
# time,connectionism	18
# time,considered	22
# time,continued	19
# time,dealing	1
# time,described	1
# time,deviations	10
# time,diagnosis	10
# time,digits	1
# time,disciplines	18
# time,dollars	6
# time,done	22
# time,except	6
# time,feasibility	22
# time,feasible	22
# time,field	18
# time,filtering	10
# time,functions	66
# time,games	10
# time,given	1
# time,including	28
# time,invested	6
# time,investment	4
# time,kinds	44
# time,leading	10
# time,learned	164
# time,learning	46
# time,learns	1
# time,letters	1
# time,line	18
# time,machine	12
# time,main	18
# time,medical	10
# time,mid-1980s	18
# time,missing	6
# time,mostly	1
# time,moved	10
# time,network	11
# time,networks	10
# time,neural	11
# time,outside	18
# time,part	6
# time,pattern	2
# time,perform	10
# time,performing	10
# time,period	4
# time,playing	10
# time,polynomial	176
# time,recognition	11
# time,recognize	1
# time,reinvention	18
# time,related	1
# time,report	1
# time,representative	1
# time,research	1
# time,researchers	18
# time,results	220
# time,said	10
# time,show	154
# time,social	10
# time,special	1
# time,specific	10
# time,speech	10
# time,strategies	1
# time,success	18
# time,symbols	1
# time,targets	6
# time,task	10
# time,tasks	20
# time,teaching	1
# time,terminal	1
# time,theory	22
# time,time	220
# time,translation	10
# time,two	44
# time,used	10
# time,using	1
# time,variety	10
# time,video	10
# time,vision	10
# times,X	1
# times,Y	1
# times,black	1
# times,can	1
# times,chance	1
# times,color	1
# times,exist	1
# times,families	1
# times,geographically	1
# times,nuanced	1
# times,separate	1
# times,species	1
# times,swans	1
# times,undiscovered	1
# times,variants	1
# titles,TW	1
# titles,URL	1
# titles,WP:MOS	1
# titles,address	1
# titles,current	1
# titles,differ	1
# titles,link	1
# titles,may	1
# titles,permanent	1
# titles,present	1
# titles,revision	2
# titles,see	1
# titles,significantly	1
# today,Web	10
# today,across	10
# today,application	10
# today,areas	10
# today,association	10
# today,bioinformatics	10
# today,consider	10
# today,continuous	10
# today,contrast	10
# today,detection	10
# today,either	10
# today,including	10
# today,intrusion	10
# today,items	10
# today,learning	10
# today,mining	20
# today,order	10
# today,production	10
# today,rule	10
# today,sequence	10
# today,transaction	10
# today,transactions	10
# today,typically	10
# today,usage	10
# today,within	10
# together,Web	10
# together,across	10
# together,activities	10
# together,addition	10
# together,also	10
# together,analysis	10
# together,application	10
# together,areas	10
# together,association	20
# together,basis	10
# together,basket	10
# together,bioinformatics	10
# together,buy	10
# together,can	10
# together,complex	1
# together,consider	10
# together,considering	1
# together,continuous	10
# together,contrast	10
# together,data	1
# together,decisions	10
# together,detection	10
# together,either	10
# together,employed	10
# together,examples	1
# together,generally	1
# together,hamburger	10
# together,including	10
# together,information	10
# together,inputs	1
# together,intrusion	10
# together,items	10
# together,learn	1
# together,learning	10
# together,likely	10
# together,market	10
# together,marketing	10
# together,meat	10
# together,mining	20
# together,order	10
# together,perform	1
# together,placements	10
# together,pricing	10
# together,process	1
# together,product	10
# together,production	10
# together,programmed	1
# together,promotional	10
# together,rule	10
# together,rules	11
# together,sequence	10
# together,systems	1
# together,task-specific	1
# together,tasks	1
# together,today	10
# together,transaction	10
# together,transactions	10
# together,typically	10
# together,usage	10
# together,used	10
# together,within	10
# together,without	1
# tomorrow,X	4
# tomorrow,Y	4
# tomorrow,black	4
# tomorrow,can	4
# tomorrow,chance	4
# tomorrow,color	4
# tomorrow,exist	4
# tomorrow,families	4
# tomorrow,geographically	4
# tomorrow,morning	4
# tomorrow,nuanced	4
# tomorrow,separate	4
# tomorrow,species	4
# tomorrow,swans	4
# tomorrow,times	1
# tomorrow,undiscovered	4
# tomorrow,variants	4
# tomorrow,well	4
# tool,addressed	6
# tool,beginning	9
# tool,biases	17
# tool,diagnose	11
# tool,even	6
# tool,greed	6
# tool,happen	6
# tool,just	9
# tool,medicate	11
# tool,mentioned	6
# tool,mitigated	5
# tool,paths	11
# tool,patients	11
# tool,personal	6
# tool,plan	11
# tool,previously	6
# tool,profound	9
# tool,recovery	11
# tool,requires	5
# tool,responsibility	9
# tool,understand	9
# tool,will	6
# toolbox,Data	3
# toolbox,Miner	3
# toolbox,STATISTICA	3
# toolbox,Weka	3
# toolbox,algorithms	3
# toolbox,containing	3
# toolbox,learning	3
# toolbox,machine	3
# toolbox,software	3
# toolbox,suites	3
# toolbox,variety	3
# tools,AUC	1
# tools,Data	1
# tools,Higher	1
# tools,Jordan	1
# tools,Michael	1
# tools,also	17
# tools,assessment	1
# tools,associated	1
# tools,better	1
# tools,call	18
# tools,capture	12
# tools,classification	1
# tools,complex	12
# tools,data	29
# tools,distribution	12
# tools,evaluation	10
# tools,field	18
# tools,find	12
# tools,ideas	1
# tools,inputs	12
# tools,joint	12
# tools,lack	10
# tools,learning	1
# tools,lengthy	1
# tools,long	17
# tools,machine	1
# tools,model	14
# tools,observed	12
# tools,outputs	12
# tools,overall	18
# tools,patterns	12
# tools,people	10
# tools,performing	1
# tools,placeholder	18
# tools,pre-history	18
# tools,probability	12
# tools,problems	10
# tools,relationships	12
# tools,resources	10
# tools,science	18
# tools,statistical	12
# tools,statistics	18
# tools,structure	12
# tools,suggested	18
# tools,term	17
# tools,unknown	12
# tools,used	12
# tools,usually	12
# tools,variables	12
# topic,Machine	3
# topic,Meta	3
# topic,acquire	3
# topic,active	3
# topic,algorithms	15
# topic,also	3
# topic,based	3
# topic,bias	3
# topic,can	3
# topic,computer	3
# topic,cover	3
# topic,cumulatively	3
# topic,current	6
# topic,curriculum	3
# topic,deep	6
# topic,density	6
# topic,developmental	3
# topic,dimensionality	2
# topic,documents	6
# topic,especially	6
# topic,estimation	3
# topic,experience	3
# topic,experiences	3
# topic,exploration	3
# topic,find	3
# topic,finds	3
# topic,function	3
# topic,generate	3
# topic,given	3
# topic,guidance	3
# topic,humans	3
# topic,imitation.clarification	3
# topic,inductive	3
# topic,interaction	3
# topic,known	3
# topic,language	3
# topic,learn	3
# topic,learning	26
# topic,maturation	3
# topic,mechanisms	3
# topic,meta	5
# topic,meta-learning	2
# topic,modeling	10
# topic,motor	3
# topic,natural	3
# topic,needed	3
# topic,new	3
# topic,previous	3
# topic,probability	3
# topic,problems	3
# topic,program	3
# topic,reduction	2
# topic,research	6
# topic,robot	3
# topic,robotics	3
# topic,robots	3
# topic,self-guided	3
# topic,sequences	3
# topic,set	3
# topic,similar	3
# topic,skills	3
# topic,social	3
# topic,synergies	3
# topic,topics	3
# topic,unobservable	3
# topic,use	3
# topic,used	3
# topics,Machine	3
# topics,Meta	3
# topics,acquire	3
# topics,active	3
# topics,algorithms	9
# topics,also	3
# topics,based	3
# topics,bias	3
# topics,can	3
# topics,cumulatively	3
# topics,curriculum	3
# topics,density	6
# topics,developmental	3
# topics,estimation	3
# topics,experience	3
# topics,experiences	3
# topics,exploration	3
# topics,find	3
# topics,function	3
# topics,generate	3
# topics,guidance	3
# topics,humans	3
# topics,imitation.clarification	3
# topics,inductive	3
# topics,interaction	3
# topics,known	3
# topics,learn	3
# topics,learning	15
# topics,maturation	3
# topics,mechanisms	3
# topics,motor	3
# topics,needed	3
# topics,new	3
# topics,previous	3
# topics,probability	3
# topics,problems	3
# topics,robot	3
# topics,robotics	3
# topics,robots	3
# topics,self-guided	3
# topics,sequences	3
# topics,skills	3
# topics,social	3
# topics,synergies	3
# topics,unobservable	3
# topics,use	3
# topics,used	3
# total,AUC	6
# total,ROC	6
# total,ROC's	6
# total,TOC	18
# total,ability	6
# total,area	6
# total,associated	6
# total,characteristic	12
# total,commonly	6
# total,curve	6
# t
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# **n-gram MapReduce**

# %%
# Create the mapper script
# %%writefile mapper_bigram.py

#!/usr/bin/env python
import sys,string

# Read articles
for line in sys.stdin:
  line = line.strip()  # removes whitespace either side of each line
  words = line.split()  # splitting each line into a list of words
  n = len(words)
  # Create bigram
  for i in range(n-1):
    word_i = words[i].strip(string.punctuation.replace("\'","")) # removes punctuations
    word_j = words[i+1].strip(string.punctuation.replace("\'","")) # removes punctuations
    print('%s,%s\t%s' % (word_i,word_j, 1))  # writing our results to STDOUT (this is the input for reducer.py)
# Out:
# Writing mapper_bigram.py

# %%
# Writing reducer script: 
# Reference: lab04_solution
# %%writefile combiner_bigram.py

#!/usr/bin/env python
  
import sys
from operator import itemgetter
  
current_word = None
current_count = 0
word = None
  
for line in sys.stdin:
  line = line.strip()
  word, count = line.split('\t', 1)  # splitting the data on the basis of tab (see mapper.py)
  
  try:
    count = int(count)  # convert count (currently a string) to int
  except ValueError:
    continue  # silently ignore line if count is not a number
  
  # this IF-switch only works because Hadoop sorts map output
  # by key (here: word) before it is passed to the reducer
  if current_word == word:
    current_count += count
  else:
    if current_word: # to avoid None values
      print('%s\t%s' % (current_word, current_count))
    current_count = count
    current_word = word
  
# do not forget to output the last word if needed!
if current_word == word:
  print('%s\t%s' % (current_word, current_count))
# Out:
# Writing combiner_bigram.py

# %%
# Writing reducer script: 
# Reference: lab04_solution
# %%writefile reducer_bigram.py

#!/usr/bin/env python
  
import sys
from operator import itemgetter
  
current_word = None
current_count = 0
word = None
  
for line in sys.stdin:
  line = line.strip()
  word, count = line.split('\t', 1)  # splitting the data on the basis of tab (see mapper.py)
  
  try:
    count = int(count)  # convert count (currently a string) to int
  except ValueError:
    continue  # silently ignore line if count is not a number
  
  # this IF-switch only works because Hadoop sorts map output
  # by key (here: word) before it is passed to the reducer
  if current_word == word:
    current_count += count
  else:
    if current_word: # to avoid None values
      print('%s\t%s' % (current_word, current_count))
    current_count = count
    current_word = word
  
# do not forget to output the last word if needed!
if current_word == word:
  print('%s\t%s' % (current_word, current_count))
# Out:
# Writing reducer_bigram.py

# %%
# Giving these mapper&reducer permissions:
# !chmod u+x /content/mapper_bigram.py /content/combiner_bigram.py /content/reducer_bigram.py

# %%
#Running MapReduce programs
# !$HADOOP_HOME/bin/hadoop jar $HADOOP_HOME/share/hadoop/tools/lib/hadoop-streaming-3.3.3.jar \
  -input /wikipedia-ml/article*.txt \
  -output /bigram-outputs \
  -mapper "python /content/mapper_bigram.py" \
  -combiner "python /content/combiner_bigram.py" \
  -reducer "python /content/reducer_bigram.py"
# Out:
# 2023-04-30 10:05:41,901 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2023-04-30 10:05:42,223 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2023-04-30 10:05:42,223 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2023-04-30 10:05:42,283 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2023-04-30 10:05:42,824 INFO mapred.FileInputFormat: Total input files to process : 22
# 2023-04-30 10:05:42,919 INFO mapreduce.JobSubmitter: number of splits:22
# 2023-04-30 10:05:43,507 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1540228441_0001
# 2023-04-30 10:05:43,507 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2023-04-30 10:05:44,006 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2023-04-30 10:05:44,008 INFO mapreduce.Job: Running job: job_local1540228441_0001
# 2023-04-30 10:05:44,033 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2023-04-30 10:05:44,045 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2023-04-30 10:05:44,059 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:05:44,060 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:05:44,288 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2023-04-30 10:05:44,296 INFO mapred.LocalJobRunner: Starting task: attempt_local1540228441_0001_m_000000_0
# 2023-04-30 10:05:44,375 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:05:44,376 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:05:44,442 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:05:44,457 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2023_1_1.txt:0+49228
# 2023-04-30 10:05:44,523 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:05:44,834 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:05:44,834 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:05:44,834 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:05:44,834 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:05:44,834 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:05:44,856 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:05:44,876 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_bigram.py]
# 2023-04-30 10:05:44,886 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2023-04-30 10:05:44,893 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2023-04-30 10:05:44,900 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2023-04-30 10:05:44,901 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2023-04-30 10:05:44,901 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2023-04-30 10:05:44,902 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2023-04-30 10:05:44,903 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2023-04-30 10:05:44,904 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2023-04-30 10:05:44,905 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2023-04-30 10:05:44,905 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2023-04-30 10:05:44,906 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2023-04-30 10:05:44,906 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2023-04-30 10:05:44,973 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:44,974 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:45,021 INFO mapreduce.Job: Job job_local1540228441_0001 running in uber mode : false
# 2023-04-30 10:05:45,022 INFO mapreduce.Job:  map 0% reduce 0%
# 2023-04-30 10:05:45,195 INFO streaming.PipeMapRed: Records R/W=93/1
# 2023-04-30 10:05:45,300 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:45,304 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:45,309 INFO mapred.LocalJobRunner:
# 2023-04-30 10:05:45,309 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:05:45,310 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:05:45,310 INFO mapred.MapTask: bufstart = 0; bufend = 109694; bufvoid = 104857600
# 2023-04-30 10:05:45,310 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26185360(104741440); length = 29037/6553600
# 2023-04-30 10:05:45,415 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/combiner_bigram.py]
# 2023-04-30 10:05:45,420 INFO Configuration.deprecation: mapred.skip.map.auto.incr.proc.count is deprecated. Instead, use mapreduce.map.skip.proc-count.auto-incr
# 2023-04-30 10:05:45,463 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:45,464 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:45,466 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:45,485 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:45,628 INFO streaming.PipeMapRed: Records R/W=7260/1
# 2023-04-30 10:05:45,706 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:45,714 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:45,715 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:05:45,730 INFO mapred.Task: Task:attempt_local1540228441_0001_m_000000_0 is done. And is in the process of committing
# 2023-04-30 10:05:45,745 INFO mapred.LocalJobRunner: Records R/W=7260/1
# 2023-04-30 10:05:45,747 INFO mapred.Task: Task 'attempt_local1540228441_0001_m_000000_0' done.
# 2023-04-30 10:05:45,757 INFO mapred.Task: Final Counters for attempt_local1540228441_0001_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=193950
# 		FILE: Number of bytes written=888745
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=93
# 		Map output records=7260
# 		Map output bytes=109694
# 		Map output materialized bytes=99347
# 		Input split bytes=120
# 		Combine input records=7260
# 		Combine output records=5634
# 		Spilled Records=5634
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=414187520
# 	File Input Format Counters
# 		Bytes Read=49632
# 2023-04-30 10:05:45,766 INFO mapred.LocalJobRunner: Finishing task: attempt_local1540228441_0001_m_000000_0
# 2023-04-30 10:05:45,767 INFO mapred.LocalJobRunner: Starting task: attempt_local1540228441_0001_m_000001_0
# 2023-04-30 10:05:45,781 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:05:45,781 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:05:45,782 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:05:45,783 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2023_4_29.txt:0+48519
# 2023-04-30 10:05:45,799 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:05:45,881 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:05:45,881 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:05:45,881 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:05:45,881 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:05:45,881 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:05:45,892 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:05:45,925 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_bigram.py]
# 2023-04-30 10:05:45,986 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:45,986 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:46,036 INFO mapreduce.Job:  map 100% reduce 0%
# 2023-04-30 10:05:46,163 INFO streaming.PipeMapRed: Records R/W=90/1
# 2023-04-30 10:05:46,236 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:46,237 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:46,238 INFO mapred.LocalJobRunner:
# 2023-04-30 10:05:46,238 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:05:46,238 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:05:46,238 INFO mapred.MapTask: bufstart = 0; bufend = 108105; bufvoid = 104857600
# 2023-04-30 10:05:46,238 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26185828(104743312); length = 28569/6553600
# 2023-04-30 10:05:46,273 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/combiner_bigram.py]
# 2023-04-30 10:05:46,310 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:46,310 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:46,310 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:46,311 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:46,443 INFO streaming.PipeMapRed: Records R/W=7143/1
# 2023-04-30 10:05:46,524 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:46,525 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:46,526 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:05:46,531 INFO mapred.Task: Task:attempt_local1540228441_0001_m_000001_0 is done. And is in the process of committing
# 2023-04-30 10:05:46,533 INFO mapred.LocalJobRunner: Records R/W=7143/1
# 2023-04-30 10:05:46,534 INFO mapred.Task: Task 'attempt_local1540228441_0001_m_000001_0' done.
# 2023-04-30 10:05:46,535 INFO mapred.Task: Final Counters for attempt_local1540228441_0001_m_000001_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=245554
# 		FILE: Number of bytes written=986644
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=90
# 		Map output records=7143
# 		Map output bytes=108105
# 		Map output materialized bytes=97867
# 		Input split bytes=121
# 		Combine input records=7143
# 		Combine output records=5541
# 		Spilled Records=5541
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=26
# 		Total committed heap usage (bytes)=414187520
# 	File Input Format Counters
# 		Bytes Read=48915
# 2023-04-30 10:05:46,536 INFO mapred.LocalJobRunner: Finishing task: attempt_local1540228441_0001_m_000001_0
# 2023-04-30 10:05:46,536 INFO mapred.LocalJobRunner: Starting task: attempt_local1540228441_0001_m_000002_0
# 2023-04-30 10:05:46,538 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:05:46,538 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:05:46,538 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:05:46,542 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2022_6_28.txt:0+47622
# 2023-04-30 10:05:46,548 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:05:46,631 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:05:46,631 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:05:46,631 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:05:46,631 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:05:46,631 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:05:46,633 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:05:46,648 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_bigram.py]
# 2023-04-30 10:05:46,698 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:46,698 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:46,822 INFO streaming.PipeMapRed: Records R/W=86/1
# 2023-04-30 10:05:46,853 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:46,854 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:46,855 INFO mapred.LocalJobRunner:
# 2023-04-30 10:05:46,855 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:05:46,855 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:05:46,855 INFO mapred.MapTask: bufstart = 0; bufend = 106269; bufvoid = 104857600
# 2023-04-30 10:05:46,855 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26186256(104745024); length = 28141/6553600
# 2023-04-30 10:05:46,871 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/combiner_bigram.py]
# 2023-04-30 10:05:46,895 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:46,895 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:46,896 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:46,897 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:47,010 INFO streaming.PipeMapRed: Records R/W=7036/1
# 2023-04-30 10:05:47,039 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:47,040 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:47,040 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:05:47,043 INFO mapred.Task: Task:attempt_local1540228441_0001_m_000002_0 is done. And is in the process of committing
# 2023-04-30 10:05:47,048 INFO mapred.LocalJobRunner: Records R/W=7036/1
# 2023-04-30 10:05:47,048 INFO mapred.Task: Task 'attempt_local1540228441_0001_m_000002_0' done.
# 2023-04-30 10:05:47,049 INFO mapred.Task: Final Counters for attempt_local1540228441_0001_m_000002_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=296257
# 		FILE: Number of bytes written=1083049
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=86
# 		Map output records=7036
# 		Map output bytes=106269
# 		Map output materialized bytes=96373
# 		Input split bytes=121
# 		Combine input records=7036
# 		Combine output records=5472
# 		Spilled Records=5472
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=11
# 		Total committed heap usage (bytes)=700448768
# 	File Input Format Counters
# 		Bytes Read=48014
# 2023-04-30 10:05:47,050 INFO mapred.LocalJobRunner: Finishing task: attempt_local1540228441_0001_m_000002_0
# 2023-04-30 10:05:47,050 INFO mapred.LocalJobRunner: Starting task: attempt_local1540228441_0001_m_000003_0
# 2023-04-30 10:05:47,054 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:05:47,054 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:05:47,055 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:05:47,056 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2022_1_2.txt:0+45577
# 2023-04-30 10:05:47,065 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:05:47,216 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:05:47,216 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:05:47,216 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:05:47,216 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:05:47,216 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:05:47,217 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:05:47,225 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_bigram.py]
# 2023-04-30 10:05:47,254 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:47,255 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:47,347 INFO streaming.PipeMapRed: Records R/W=83/1
# 2023-04-30 10:05:47,374 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:47,375 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:47,375 INFO mapred.LocalJobRunner:
# 2023-04-30 10:05:47,375 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:05:47,375 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:05:47,376 INFO mapred.MapTask: bufstart = 0; bufend = 101728; bufvoid = 104857600
# 2023-04-30 10:05:47,376 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26187368(104749472); length = 27029/6553600
# 2023-04-30 10:05:47,396 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/combiner_bigram.py]
# 2023-04-30 10:05:47,432 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:47,432 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:47,433 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:47,434 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:47,525 INFO streaming.PipeMapRed: Records R/W=6758/1
# 2023-04-30 10:05:47,540 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:47,541 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:47,542 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:05:47,545 INFO mapred.Task: Task:attempt_local1540228441_0001_m_000003_0 is done. And is in the process of committing
# 2023-04-30 10:05:47,548 INFO mapred.LocalJobRunner: Records R/W=6758/1
# 2023-04-30 10:05:47,548 INFO mapred.Task: Task 'attempt_local1540228441_0001_m_000003_0' done.
# 2023-04-30 10:05:47,549 INFO mapred.Task: Final Counters for attempt_local1540228441_0001_m_000003_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=344899
# 		FILE: Number of bytes written=1175111
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=83
# 		Map output records=6758
# 		Map output bytes=101728
# 		Map output materialized bytes=92030
# 		Input split bytes=120
# 		Combine input records=6758
# 		Combine output records=5242
# 		Spilled Records=5242
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=700448768
# 	File Input Format Counters
# 		Bytes Read=45953
# 2023-04-30 10:05:47,549 INFO mapred.LocalJobRunner: Finishing task: attempt_local1540228441_0001_m_000003_0
# 2023-04-30 10:05:47,549 INFO mapred.LocalJobRunner: Starting task: attempt_local1540228441_0001_m_000004_0
# 2023-04-30 10:05:47,551 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:05:47,551 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:05:47,551 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:05:47,553 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2021_6_19.txt:0+43410
# 2023-04-30 10:05:47,557 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:05:47,598 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:05:47,598 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:05:47,598 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:05:47,598 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:05:47,598 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:05:47,625 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:05:47,643 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_bigram.py]
# 2023-04-30 10:05:47,672 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:47,673 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:47,779 INFO streaming.PipeMapRed: Records R/W=78/1
# 2023-04-30 10:05:47,804 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:47,805 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:47,806 INFO mapred.LocalJobRunner:
# 2023-04-30 10:05:47,806 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:05:47,806 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:05:47,806 INFO mapred.MapTask: bufstart = 0; bufend = 96954; bufvoid = 104857600
# 2023-04-30 10:05:47,806 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26188636(104754544); length = 25761/6553600
# 2023-04-30 10:05:47,821 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/combiner_bigram.py]
# 2023-04-30 10:05:47,843 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:47,843 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:47,844 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:47,846 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:47,964 INFO streaming.PipeMapRed: Records R/W=6441/1
# 2023-04-30 10:05:47,988 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:47,989 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:47,989 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:05:47,992 INFO mapred.Task: Task:attempt_local1540228441_0001_m_000004_0 is done. And is in the process of committing
# 2023-04-30 10:05:47,997 INFO mapred.LocalJobRunner: Records R/W=6441/1
# 2023-04-30 10:05:47,998 INFO mapred.Task: Task 'attempt_local1540228441_0001_m_000004_0' done.
# 2023-04-30 10:05:48,000 INFO mapred.Task: Final Counters for attempt_local1540228441_0001_m_000004_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=391354
# 		FILE: Number of bytes written=1263257
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=78
# 		Map output records=6441
# 		Map output bytes=96954
# 		Map output materialized bytes=88114
# 		Input split bytes=121
# 		Combine input records=6441
# 		Combine output records=5024
# 		Spilled Records=5024
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=7
# 		Total committed heap usage (bytes)=700448768
# 	File Input Format Counters
# 		Bytes Read=43766
# 2023-04-30 10:05:48,001 INFO mapred.LocalJobRunner: Finishing task: attempt_local1540228441_0001_m_000004_0
# 2023-04-30 10:05:48,001 INFO mapred.LocalJobRunner: Starting task: attempt_local1540228441_0001_m_000005_0
# 2023-04-30 10:05:48,004 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:05:48,004 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:05:48,005 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:05:48,008 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2021_1_8.txt:0+42489
# 2023-04-30 10:05:48,013 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:05:48,031 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:05:48,031 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:05:48,031 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:05:48,031 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:05:48,031 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:05:48,032 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:05:48,038 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_bigram.py]
# 2023-04-30 10:05:48,078 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,078 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,176 INFO streaming.PipeMapRed: Records R/W=79/1
# 2023-04-30 10:05:48,202 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:48,204 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:48,204 INFO mapred.LocalJobRunner:
# 2023-04-30 10:05:48,205 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:05:48,205 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:05:48,205 INFO mapred.MapTask: bufstart = 0; bufend = 94833; bufvoid = 104857600
# 2023-04-30 10:05:48,205 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26189208(104756832); length = 25189/6553600
# 2023-04-30 10:05:48,221 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/combiner_bigram.py]
# 2023-04-30 10:05:48,242 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,243 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,243 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,244 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,330 INFO streaming.PipeMapRed: Records R/W=6298/1
# 2023-04-30 10:05:48,352 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:48,354 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:48,354 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:05:48,357 INFO mapred.Task: Task:attempt_local1540228441_0001_m_000005_0 is done. And is in the process of committing
# 2023-04-30 10:05:48,359 INFO mapred.LocalJobRunner: Records R/W=6298/1
# 2023-04-30 10:05:48,359 INFO mapred.Task: Task 'attempt_local1540228441_0001_m_000005_0' done.
# 2023-04-30 10:05:48,360 INFO mapred.Task: Final Counters for attempt_local1540228441_0001_m_000005_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=436368
# 		FILE: Number of bytes written=1349657
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=79
# 		Map output records=6298
# 		Map output bytes=94833
# 		Map output materialized bytes=86368
# 		Input split bytes=120
# 		Combine input records=6298
# 		Combine output records=4927
# 		Spilled Records=4927
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=700448768
# 	File Input Format Counters
# 		Bytes Read=42837
# 2023-04-30 10:05:48,360 INFO mapred.LocalJobRunner: Finishing task: attempt_local1540228441_0001_m_000005_0
# 2023-04-30 10:05:48,360 INFO mapred.LocalJobRunner: Starting task: attempt_local1540228441_0001_m_000006_0
# 2023-04-30 10:05:48,362 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:05:48,362 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:05:48,362 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:05:48,364 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2020_1_8.txt:0+41178
# 2023-04-30 10:05:48,368 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:05:48,416 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:05:48,416 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:05:48,416 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:05:48,416 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:05:48,416 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:05:48,424 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:05:48,442 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_bigram.py]
# 2023-04-30 10:05:48,476 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,476 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,545 INFO streaming.PipeMapRed: Records R/W=69/1
# 2023-04-30 10:05:48,559 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:48,560 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:48,561 INFO mapred.LocalJobRunner:
# 2023-04-30 10:05:48,561 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:05:48,561 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:05:48,561 INFO mapred.MapTask: bufstart = 0; bufend = 91951; bufvoid = 104857600
# 2023-04-30 10:05:48,561 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26190040(104760160); length = 24357/6553600
# 2023-04-30 10:05:48,574 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/combiner_bigram.py]
# 2023-04-30 10:05:48,604 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,604 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,604 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,605 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,689 INFO streaming.PipeMapRed: Records R/W=6090/1
# 2023-04-30 10:05:48,711 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:48,712 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:48,712 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:05:48,715 INFO mapred.Task: Task:attempt_local1540228441_0001_m_000006_0 is done. And is in the process of committing
# 2023-04-30 10:05:48,719 INFO mapred.LocalJobRunner: Records R/W=6090/1
# 2023-04-30 10:05:48,719 INFO mapred.Task: Task 'attempt_local1540228441_0001_m_000006_0' done.
# 2023-04-30 10:05:48,720 INFO mapred.Task: Final Counters for attempt_local1540228441_0001_m_000006_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=480063
# 		FILE: Number of bytes written=1431945
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=69
# 		Map output records=6090
# 		Map output bytes=91951
# 		Map output materialized bytes=82256
# 		Input split bytes=120
# 		Combine input records=6090
# 		Combine output records=4679
# 		Spilled Records=4679
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=13
# 		Total committed heap usage (bytes)=700448768
# 	File Input Format Counters
# 		Bytes Read=41518
# 2023-04-30 10:05:48,720 INFO mapred.LocalJobRunner: Finishing task: attempt_local1540228441_0001_m_000006_0
# 2023-04-30 10:05:48,720 INFO mapred.LocalJobRunner: Starting task: attempt_local1540228441_0001_m_000007_0
# 2023-04-30 10:05:48,722 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:05:48,722 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:05:48,722 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:05:48,725 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2020_6_30.txt:0+40438
# 2023-04-30 10:05:48,737 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:05:48,755 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:05:48,755 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:05:48,755 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:05:48,755 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:05:48,755 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:05:48,758 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:05:48,766 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_bigram.py]
# 2023-04-30 10:05:48,786 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,787 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,879 INFO streaming.PipeMapRed: Records R/W=72/1
# 2023-04-30 10:05:48,893 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:48,893 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:48,894 INFO mapred.LocalJobRunner:
# 2023-04-30 10:05:48,894 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:05:48,894 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:05:48,894 INFO mapred.MapTask: bufstart = 0; bufend = 90252; bufvoid = 104857600
# 2023-04-30 10:05:48,894 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26190480(104761920); length = 23917/6553600
# 2023-04-30 10:05:48,904 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/combiner_bigram.py]
# 2023-04-30 10:05:48,929 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,930 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,930 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:48,931 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,023 INFO streaming.PipeMapRed: Records R/W=5980/1
# 2023-04-30 10:05:49,045 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:49,046 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:49,047 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:05:49,049 INFO mapred.Task: Task:attempt_local1540228441_0001_m_000007_0 is done. And is in the process of committing
# 2023-04-30 10:05:49,051 INFO mapreduce.Job:  map 32% reduce 0%
# 2023-04-30 10:05:49,052 INFO mapred.LocalJobRunner: Records R/W=5980/1
# 2023-04-30 10:05:49,052 INFO mapred.Task: Task 'attempt_local1540228441_0001_m_000007_0' done.
# 2023-04-30 10:05:49,052 INFO mapred.Task: Final Counters for attempt_local1540228441_0001_m_000007_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=523010
# 		FILE: Number of bytes written=1514393
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=72
# 		Map output records=5980
# 		Map output bytes=90252
# 		Map output materialized bytes=82416
# 		Input split bytes=121
# 		Combine input records=5980
# 		Combine output records=4698
# 		Spilled Records=4698
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=700448768
# 	File Input Format Counters
# 		Bytes Read=40770
# 2023-04-30 10:05:49,053 INFO mapred.LocalJobRunner: Finishing task: attempt_local1540228441_0001_m_000007_0
# 2023-04-30 10:05:49,053 INFO mapred.LocalJobRunner: Starting task: attempt_local1540228441_0001_m_000008_0
# 2023-04-30 10:05:49,054 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:05:49,054 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:05:49,055 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:05:49,056 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2019_6_24.txt:0+37840
# 2023-04-30 10:05:49,060 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:05:49,082 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:05:49,082 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:05:49,082 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:05:49,082 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:05:49,082 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:05:49,083 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:05:49,096 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_bigram.py]
# 2023-04-30 10:05:49,159 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,159 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,261 INFO streaming.PipeMapRed: Records R/W=63/1
# 2023-04-30 10:05:49,283 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:49,285 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:49,285 INFO mapred.LocalJobRunner:
# 2023-04-30 10:05:49,285 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:05:49,285 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:05:49,288 INFO mapred.MapTask: bufstart = 0; bufend = 84531; bufvoid = 104857600
# 2023-04-30 10:05:49,288 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26191960(104767840); length = 22437/6553600
# 2023-04-30 10:05:49,297 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/combiner_bigram.py]
# 2023-04-30 10:05:49,306 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,306 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,306 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,307 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,371 INFO streaming.PipeMapRed: Records R/W=5610/1
# 2023-04-30 10:05:49,391 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:49,392 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:49,393 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:05:49,395 INFO mapred.Task: Task:attempt_local1540228441_0001_m_000008_0 is done. And is in the process of committing
# 2023-04-30 10:05:49,397 INFO mapred.LocalJobRunner: Records R/W=5610/1
# 2023-04-30 10:05:49,397 INFO mapred.Task: Task 'attempt_local1540228441_0001_m_000008_0' done.
# 2023-04-30 10:05:49,397 INFO mapred.Task: Final Counters for attempt_local1540228441_0001_m_000008_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=563339
# 		FILE: Number of bytes written=1590013
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=63
# 		Map output records=5610
# 		Map output bytes=84531
# 		Map output materialized bytes=75588
# 		Input split bytes=121
# 		Combine input records=5610
# 		Combine output records=4308
# 		Spilled Records=4308
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=4
# 		Total committed heap usage (bytes)=700448768
# 	File Input Format Counters
# 		Bytes Read=38152
# 2023-04-30 10:05:49,398 INFO mapred.LocalJobRunner: Finishing task: attempt_local1540228441_0001_m_000008_0
# 2023-04-30 10:05:49,398 INFO mapred.LocalJobRunner: Starting task: attempt_local1540228441_0001_m_000009_0
# 2023-04-30 10:05:49,399 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:05:49,399 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:05:49,400 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:05:49,401 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2019_1_2.txt:0+36562
# 2023-04-30 10:05:49,405 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:05:49,424 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:05:49,425 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:05:49,425 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:05:49,425 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:05:49,425 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:05:49,425 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:05:49,429 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_bigram.py]
# 2023-04-30 10:05:49,437 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,437 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,507 INFO streaming.PipeMapRed: Records R/W=60/1
# 2023-04-30 10:05:49,523 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:49,524 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:49,525 INFO mapred.LocalJobRunner:
# 2023-04-30 10:05:49,525 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:05:49,525 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:05:49,525 INFO mapred.MapTask: bufstart = 0; bufend = 81701; bufvoid = 104857600
# 2023-04-30 10:05:49,525 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26192716(104770864); length = 21681/6553600
# 2023-04-30 10:05:49,540 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/combiner_bigram.py]
# 2023-04-30 10:05:49,559 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,559 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,559 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,560 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,658 INFO streaming.PipeMapRed: Records R/W=5421/1
# 2023-04-30 10:05:49,677 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:49,678 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:49,678 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:05:49,681 INFO mapred.Task: Task:attempt_local1540228441_0001_m_000009_0 is done. And is in the process of committing
# 2023-04-30 10:05:49,682 INFO mapred.LocalJobRunner: Records R/W=5421/1
# 2023-04-30 10:05:49,683 INFO mapred.Task: Task 'attempt_local1540228441_0001_m_000009_0' done.
# 2023-04-30 10:05:49,683 INFO mapred.Task: Final Counters for attempt_local1540228441_0001_m_000009_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=601870
# 		FILE: Number of bytes written=1663108
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=60
# 		Map output records=5421
# 		Map output bytes=81701
# 		Map output materialized bytes=73063
# 		Input split bytes=120
# 		Combine input records=5421
# 		Combine output records=4165
# 		Spilled Records=4165
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=700448768
# 	File Input Format Counters
# 		Bytes Read=36866
# 2023-04-30 10:05:49,683 INFO mapred.LocalJobRunner: Finishing task: attempt_local1540228441_0001_m_000009_0
# 2023-04-30 10:05:49,683 INFO mapred.LocalJobRunner: Starting task: attempt_local1540228441_0001_m_000010_0
# 2023-04-30 10:05:49,685 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:05:49,685 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:05:49,685 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:05:49,687 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2018_6_29.txt:0+23485
# 2023-04-30 10:05:49,691 INFO mapred.MapTask: numReduceTasks: 1
# 2023-04-30 10:05:49,724 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2023-04-30 10:05:49,724 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2023-04-30 10:05:49,724 INFO mapred.MapTask: soft limit at 83886080
# 2023-04-30 10:05:49,724 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2023-04-30 10:05:49,732 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2023-04-30 10:05:49,742 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-04-30 10:05:49,749 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/mapper_bigram.py]
# 2023-04-30 10:05:49,769 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,769 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,838 INFO streaming.PipeMapRed: Records R/W=52/1
# 2023-04-30 10:05:49,848 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:49,849 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:49,849 INFO mapred.LocalJobRunner:
# 2023-04-30 10:05:49,849 INFO mapred.MapTask: Starting flush of map output
# 2023-04-30 10:05:49,849 INFO mapred.MapTask: Spilling map output
# 2023-04-30 10:05:49,849 INFO mapred.MapTask: bufstart = 0; bufend = 52263; bufvoid = 104857600
# 2023-04-30 10:05:49,849 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26200620(104802480); length = 13777/6553600
# 2023-04-30 10:05:49,860 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/combiner_bigram.py]
# 2023-04-30 10:05:49,900 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,900 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,900 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,901 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:49,957 INFO streaming.PipeMapRed: Records R/W=3445/1
# 2023-04-30 10:05:49,967 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:49,968 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:49,968 INFO mapred.MapTask: Finished spill 0
# 2023-04-30 10:05:49,970 INFO mapred.Task: Task:attempt_local1540228441_0001_m_000010_0 is done. And is in the process of committing
# 2023-04-30 10:05:49,972 INFO mapred.LocalJobRunner: Records R/W=3445/1
# 2023-04-30 10:05:49,973 INFO mapred.Task: Task 'attempt_local1540228441_0001_m_000010_0' done.
# 2023-04-30 10:05:49,974 INFO mapred.Task: Final Counters for attempt_local1540228441_0001_m_000010_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=627220
# 		FILE: Number of bytes written=1713059
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=52
# 		Map output records=3445
# 		Map output bytes=52263
# 		Map output materialized bytes=49919
# 		Input split bytes=121
# 		Combine input records=3445
# 		Combine output records=2850
# 		Spilled Records=2850
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=4
# 		Total committed heap usage (bytes)=700448768
# 	File Input Format Counters
# 		Bytes Read=23685
# 2023-04-30 10:05:49,975 INFO mapred.LocalJobRunner: Finishing task: attempt_local1540228441_0001_m_000010_0
# 2023-04-30 10:05:49,975 INFO mapred.LocalJobRunner: Starting task: attempt_local1540228441_0001_m_000011_0
# 2023-04-30 10:05:49,980 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2023-04-30 10:05:49,982 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-04-30 10:05:49,982 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2023-04-30 10:05:49,983 INFO mapred.MapTask: Processing split: file:/wikipedia-ml/article_Machine learning - Wikipedia_2018_1_5.txt:0+22407
# ...
# 2023-04-30 10:05:52,728 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2384042240, maxSingleShuffleLimit=596010560, mergeThreshold=1573467904, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-04-30 10:05:52,741 INFO reduce.EventFetcher: attempt_local1540228441_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-04-30 10:05:52,796 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000011_0 decomp: 47655 len: 47659 to MEMORY
# 2023-04-30 10:05:52,800 INFO reduce.InMemoryMapOutput: Read 47655 bytes from map-output for attempt_local1540228441_0001_m_000011_0
# 2023-04-30 10:05:52,805 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 47655, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->47655
# 2023-04-30 10:05:52,809 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000004_0 decomp: 88110 len: 88114 to MEMORY
# 2023-04-30 10:05:52,812 INFO reduce.InMemoryMapOutput: Read 88110 bytes from map-output for attempt_local1540228441_0001_m_000004_0
# 2023-04-30 10:05:52,813 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 88110, inMemoryMapOutputs.size() -> 2, commitMemory -> 47655, usedMemory ->135765
# 2023-04-30 10:05:52,815 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000017_0 decomp: 35498 len: 35502 to MEMORY
# 2023-04-30 10:05:52,818 INFO reduce.InMemoryMapOutput: Read 35498 bytes from map-output for attempt_local1540228441_0001_m_000017_0
# 2023-04-30 10:05:52,818 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 35498, inMemoryMapOutputs.size() -> 3, commitMemory -> 135765, usedMemory ->171263
# 2023-04-30 10:05:52,820 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000018_0 decomp: 26993 len: 26997 to MEMORY
# 2023-04-30 10:05:52,821 INFO reduce.InMemoryMapOutput: Read 26993 bytes from map-output for attempt_local1540228441_0001_m_000018_0
# 2023-04-30 10:05:52,821 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 26993, inMemoryMapOutputs.size() -> 4, commitMemory -> 171263, usedMemory ->198256
# 2023-04-30 10:05:52,823 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000005_0 decomp: 86364 len: 86368 to MEMORY
# 2023-04-30 10:05:52,824 INFO reduce.InMemoryMapOutput: Read 86364 bytes from map-output for attempt_local1540228441_0001_m_000005_0
# 2023-04-30 10:05:52,824 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 86364, inMemoryMapOutputs.size() -> 5, commitMemory -> 198256, usedMemory ->284620
# 2023-04-30 10:05:52,826 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000006_0 decomp: 82252 len: 82256 to MEMORY
# 2023-04-30 10:05:52,826 INFO reduce.InMemoryMapOutput: Read 82252 bytes from map-output for attempt_local1540228441_0001_m_000006_0
# 2023-04-30 10:05:52,826 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 82252, inMemoryMapOutputs.size() -> 6, commitMemory -> 284620, usedMemory ->366872
# 2023-04-30 10:05:52,828 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000019_0 decomp: 27165 len: 27169 to MEMORY
# 2023-04-30 10:05:52,829 INFO reduce.InMemoryMapOutput: Read 27165 bytes from map-output for attempt_local1540228441_0001_m_000019_0
# 2023-04-30 10:05:52,829 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 27165, inMemoryMapOutputs.size() -> 7, commitMemory -> 366872, usedMemory ->394037
# 2023-04-30 10:05:52,831 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000012_0 decomp: 47478 len: 47482 to MEMORY
# 2023-04-30 10:05:52,831 INFO reduce.InMemoryMapOutput: Read 47478 bytes from map-output for attempt_local1540228441_0001_m_000012_0
# 2023-04-30 10:05:52,831 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 47478, inMemoryMapOutputs.size() -> 8, commitMemory -> 394037, usedMemory ->441515
# 2023-04-30 10:05:52,833 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000007_0 decomp: 82412 len: 82416 to MEMORY
# 2023-04-30 10:05:52,833 INFO reduce.InMemoryMapOutput: Read 82412 bytes from map-output for attempt_local1540228441_0001_m_000007_0
# 2023-04-30 10:05:52,833 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 82412, inMemoryMapOutputs.size() -> 9, commitMemory -> 441515, usedMemory ->523927
# 2023-04-30 10:05:52,835 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000000_0 decomp: 99343 len: 99347 to MEMORY
# 2023-04-30 10:05:52,835 INFO reduce.InMemoryMapOutput: Read 99343 bytes from map-output for attempt_local1540228441_0001_m_000000_0
# 2023-04-30 10:05:52,835 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 99343, inMemoryMapOutputs.size() -> 10, commitMemory -> 523927, usedMemory ->623270
# 2023-04-30 10:05:52,837 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000013_0 decomp: 47081 len: 47085 to MEMORY
# 2023-04-30 10:05:52,837 INFO reduce.InMemoryMapOutput: Read 47081 bytes from map-output for attempt_local1540228441_0001_m_000013_0
# 2023-04-30 10:05:52,837 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 47081, inMemoryMapOutputs.size() -> 11, commitMemory -> 623270, usedMemory ->670351
# 2023-04-30 10:05:52,839 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000014_0 decomp: 41615 len: 41619 to MEMORY
# 2023-04-30 10:05:52,839 INFO reduce.InMemoryMapOutput: Read 41615 bytes from map-output for attempt_local1540228441_0001_m_000014_0
# 2023-04-30 10:05:52,840 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 41615, inMemoryMapOutputs.size() -> 12, commitMemory -> 670351, usedMemory ->711966
# 2023-04-30 10:05:52,841 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000020_0 decomp: 26781 len: 26785 to MEMORY
# 2023-04-30 10:05:52,841 INFO reduce.InMemoryMapOutput: Read 26781 bytes from map-output for attempt_local1540228441_0001_m_000020_0
# 2023-04-30 10:05:52,841 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 26781, inMemoryMapOutputs.size() -> 13, commitMemory -> 711966, usedMemory ->738747
# 2023-04-30 10:05:52,843 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000001_0 decomp: 97863 len: 97867 to MEMORY
# 2023-04-30 10:05:52,844 INFO reduce.InMemoryMapOutput: Read 97863 bytes from map-output for attempt_local1540228441_0001_m_000001_0
# 2023-04-30 10:05:52,844 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 97863, inMemoryMapOutputs.size() -> 14, commitMemory -> 738747, usedMemory ->836610
# 2023-04-30 10:05:52,845 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000002_0 decomp: 96369 len: 96373 to MEMORY
# 2023-04-30 10:05:52,846 INFO reduce.InMemoryMapOutput: Read 96369 bytes from map-output for attempt_local1540228441_0001_m_000002_0
# 2023-04-30 10:05:52,846 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 96369, inMemoryMapOutputs.size() -> 15, commitMemory -> 836610, usedMemory ->932979
# 2023-04-30 10:05:52,847 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000015_0 decomp: 38395 len: 38399 to MEMORY
# 2023-04-30 10:05:52,848 INFO reduce.InMemoryMapOutput: Read 38395 bytes from map-output for attempt_local1540228441_0001_m_000015_0
# 2023-04-30 10:05:52,848 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 38395, inMemoryMapOutputs.size() -> 16, commitMemory -> 932979, usedMemory ->971374
# 2023-04-30 10:05:52,849 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000008_0 decomp: 75584 len: 75588 to MEMORY
# 2023-04-30 10:05:52,850 INFO reduce.InMemoryMapOutput: Read 75584 bytes from map-output for attempt_local1540228441_0001_m_000008_0
# 2023-04-30 10:05:52,850 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 75584, inMemoryMapOutputs.size() -> 17, commitMemory -> 971374, usedMemory ->1046958
# 2023-04-30 10:05:52,851 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000021_0 decomp: 26354 len: 26358 to MEMORY
# 2023-04-30 10:05:52,851 INFO reduce.InMemoryMapOutput: Read 26354 bytes from map-output for attempt_local1540228441_0001_m_000021_0
# 2023-04-30 10:05:52,851 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 26354, inMemoryMapOutputs.size() -> 18, commitMemory -> 1046958, usedMemory ->1073312
# 2023-04-30 10:05:52,853 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000003_0 decomp: 92026 len: 92030 to MEMORY
# 2023-04-30 10:05:52,854 INFO reduce.InMemoryMapOutput: Read 92026 bytes from map-output for attempt_local1540228441_0001_m_000003_0
# 2023-04-30 10:05:52,854 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 92026, inMemoryMapOutputs.size() -> 19, commitMemory -> 1073312, usedMemory ->1165338
# 2023-04-30 10:05:52,855 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000009_0 decomp: 73059 len: 73063 to MEMORY
# 2023-04-30 10:05:52,856 INFO reduce.InMemoryMapOutput: Read 73059 bytes from map-output for attempt_local1540228441_0001_m_000009_0
# 2023-04-30 10:05:52,856 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 73059, inMemoryMapOutputs.size() -> 20, commitMemory -> 1165338, usedMemory ->1238397
# 2023-04-30 10:05:52,857 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000010_0 decomp: 49915 len: 49919 to MEMORY
# 2023-04-30 10:05:52,858 INFO reduce.InMemoryMapOutput: Read 49915 bytes from map-output for attempt_local1540228441_0001_m_000010_0
# 2023-04-30 10:05:52,858 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 49915, inMemoryMapOutputs.size() -> 21, commitMemory -> 1238397, usedMemory ->1288312
# 2023-04-30 10:05:52,859 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1540228441_0001_m_000016_0 decomp: 38166 len: 38170 to MEMORY
# 2023-04-30 10:05:52,860 INFO reduce.InMemoryMapOutput: Read 38166 bytes from map-output for attempt_local1540228441_0001_m_000016_0
# 2023-04-30 10:05:52,861 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 38166, inMemoryMapOutputs.size() -> 22, commitMemory -> 1288312, usedMemory ->1326478
# 2023-04-30 10:05:52,861 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2023-04-30 10:05:52,862 INFO mapred.LocalJobRunner: 22 / 22 copied.
# 2023-04-30 10:05:52,863 INFO reduce.MergeManagerImpl: finalMerge called with 22 in-memory map-outputs and 0 on-disk map-outputs
# 2023-04-30 10:05:52,873 INFO mapred.Merger: Merging 22 sorted segments
# 2023-04-30 10:05:52,874 INFO mapred.Merger: Down to the last merge-pass, with 22 segments left of total size: 1326133 bytes
# 2023-04-30 10:05:53,008 INFO reduce.MergeManagerImpl: Merged 22 segments, 1326478 bytes to disk to satisfy reduce memory limit
# 2023-04-30 10:05:53,009 INFO reduce.MergeManagerImpl: Merging 1 files, 1326440 bytes from disk
# 2023-04-30 10:05:53,010 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2023-04-30 10:05:53,010 INFO mapred.Merger: Merging 1 sorted segments
# 2023-04-30 10:05:53,011 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 1326414 bytes
# 2023-04-30 10:05:53,011 INFO mapred.LocalJobRunner: 22 / 22 copied.
# 2023-04-30 10:05:53,018 INFO streaming.PipeMapRed: PipeMapRed exec [/usr/local/bin/python, /content/reducer_bigram.py]
# 2023-04-30 10:05:53,021 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-04-30 10:05:53,025 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2023-04-30 10:05:53,053 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:53,054 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:53,055 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:53,060 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:53,195 INFO streaming.PipeMapRed: Records R/W=9013/1
# 2023-04-30 10:05:53,202 INFO streaming.PipeMapRed: R/W/S=10000/550/0 in:NA [rec/s] out:NA [rec/s]
# 2023-04-30 10:05:53,534 INFO streaming.PipeMapRed: MRErrorThread done
# 2023-04-30 10:05:53,535 INFO streaming.PipeMapRed: mapRedFinished
# 2023-04-30 10:05:53,536 INFO mapred.Task: Task:attempt_local1540228441_0001_r_000000_0 is done. And is in the process of committing
# 2023-04-30 10:05:53,537 INFO mapred.LocalJobRunner: 22 / 22 copied.
# 2023-04-30 10:05:53,537 INFO mapred.Task: Task attempt_local1540228441_0001_r_000000_0 is allowed to commit now
# 2023-04-30 10:05:53,538 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1540228441_0001_r_000000_0' to file:/bigram-outputs
# 2023-04-30 10:05:53,539 INFO mapred.LocalJobRunner: Records R/W=9013/1 > reduce
# 2023-04-30 10:05:53,539 INFO mapred.Task: Task 'attempt_local1540228441_0001_r_000000_0' done.
# 2023-04-30 10:05:53,539 INFO mapred.Task: Final Counters for attempt_local1540228441_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=3480211
# 		FILE: Number of bytes written=3574170
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=8046
# 		Reduce shuffle bytes=1326566
# 		Reduce input records=75602
# 		Reduce output records=8046
# 		Spilled Records=75602
# 		Shuffled Maps =22
# 		Failed Shuffles=0
# 		Merged Map outputs=22
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=700448768
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=131094
# 2023-04-30 10:05:53,540 INFO mapred.LocalJobRunner: Finishing task: attempt_local1540228441_0001_r_000000_0
# 2023-04-30 10:05:53,540 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2023-04-30 10:05:54,056 INFO mapreduce.Job:  map 100% reduce 100%
# 2023-04-30 10:05:54,057 INFO mapreduce.Job: Job job_local1540228441_0001 completed successfully
# 2023-04-30 10:05:54,099 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=16428192
# 		FILE: Number of bytes written=39779444
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1278
# 		Map output records=94753
# 		Map output bytes=1432563
# 		Map output materialized bytes=1326566
# 		Input split bytes=2650
# 		Combine input records=94753
# 		Combine output records=75602
# 		Reduce input groups=8046
# 		Reduce shuffle bytes=1326566
# 		Reduce input records=75602
# 		Reduce output records=8046
# 		Spilled Records=151204
# 		Shuffled Maps =22
# 		Failed Shuffles=0
# 		Merged Map outputs=22
# 		GC time elapsed (ms)=93
# 		Total committed heap usage (bytes)=15537799168
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=648242
# 	File Output Format Counters
# 		Bytes Written=131094
# 2023-04-30 10:05:54,099 INFO streaming.StreamJob: Output directory: /bigram-outputs

# %%
# Checking output:
# !$HADOOP_HOME/bin/hdfs dfs -ls /bigram-outputs
# !$HADOOP_HOME/bin/hdfs dfs -cat /bigram-outputs/part-00000
# Out:
# Streaming output truncated to the last 5000 lines.
# electrocardiograms,and	3
# eliminate,the	4
# eliminated,since	4
# elimination,or	5
# email,For	3
# email,and	10
# email,as	1
# email,filtering	13
# email,message	1
# email,messages	8
# emails,the	13
# embedded,devices	3
# embedded,systems	3
# emotion,The	8
# emotion,toward	8
# emotions,about	8
# emotions,feelings	8
# emphasis,on	18
# emphasize,the	4
# employ,the	22
# employed,especially	18
# employed,in	10
# employed,today	10
# employee,and	3
# employs,data	22
# employs,various	7
# emulate,a	4
# emulate,neurons	4
# emulate,the	4
# enables,it	20
# encoding,of	22
# encompasses,a	8
# encompasses,other	10
# encountered,in	8
# endeavor,machine	8
# endeavour,machine	10
# engine,accordingly	17
# engineering,and	10
# engineering,example	1
# engineering,teams	3
# engineers,and	5
# engineers,need	3
# engineers,that	9
# engines,and	5
# enhance,their	1
# enhancements,had	7
# enough,is	1
# enough,training	4
# ensemble,model	21
# entails,all	22
# entire,set	6
# entirely,eliminated	4
# entities,and	4
# entities,can	22
# environment,After	8
# environment,The	8
# environment,and	3
# environment,is	10
# environment,so	22
# environment,that	8
# environment,the	8
# environment,to	5
# environment,where	8
# environment,wherefrom	8
# environments,one	8
# equipped,in	1
# equipped,with	3
# error,decreases	15
# errors,can	1
# errors,in	10
# especially,for	6
# especially,in	18
# especially,true	11
# establish,baseline	4
# estimate,the	8
# estimated,density	22
# estimated,the	7
# estimation,in	10
# estimation,problems	3
# estimation,techniques	14
# ethical,challenges	11
# ethical,dilemma	11
# ethical,questions	15
# ethics,and	1
# ethics,for	3
# ethics,is	3
# evaluated,for	22
# evaluated,on	4
# evaluated,with	22
# evaluates,the	14
# evaluation,and	9
# evaluation,problems	10
# evasion,via	3
# even,after	10
# even,its	2
# even,kernel	8
# even,plan	6
# events,or	10
# every,finite	2
# every,morning	4
# every,needed	7
# everything,is	17
# evidence,related	6
# evolution,to	1
# evolutionary,algorithm-based	1
# evolutionary,algorithms	17
# evolved,from	3
# evolvement,of	1
# evolves,rules	14
# exact,mathematical	10
# exact,models	10
# examination,without	10
# example,Dr	1
# example,Gboard	9
# example,a	26
# example,applications	4
# example,belongs	10
# example,by	22
# example,falls	22
# example,for	7
# example,has	10
# example,if	3
# example,in	23
# example,inputs	2
# example,is	38
# example,of	4
# example,the	21
# example,to	7
# example,topic	7
# example,training	1
# example,used	7
# example,using	7
# example,we	1
# examples,Each	10
# examples,Inductive	19
# examples,Loss	17
# examples,The	21
# examples,after	2
# examples,are	10
# examples,background	22
# examples,come	22
# examples,each	22
# examples,generally	10
# examples,include	22
# examples,is	4
# examples,predicts	1
# examples,represented	22
# examples,that	12
# examples,the	2
# examples,using	10
# examples/tasks,after	20
# except,that	6
# exception,comes	22
# execute,all	7
# executes,the	8
# exemplar-based,learning	1
# exhibit,these	15
# exist,Unsupervised	10
# exist,one	7
# exist,that	22
# exist,to	10
# existing,Cinematch	21
# existing,Netflix	1
# existing,examples	1
# exists,in	8
# expectations,Effective	2
# expected,results	9
# expected,value	1
# experience,Developmental	8
# experience,E	44
# experience,Generalization	17
# experience,In	3
# experience,It	2
# experience,The	2
# experience,and	2
# experience.full,citation	3
# experienced,a	20
# experiences,also	6
# experimental,learning	3
# experiments,are	9
# expert,systems	18
# explain,observed	10
# explain,the	22
# explain,why	2
# explaining,data	10
# explicit,algorithms	17
# explicit,instructions	2
# explicit,rule-based	1
# explicitly,corrected	12
# explicitly,programmed	30
# explicitly,represent	10
# exploration,and	6
# exploratory,data	18
# explores,the	10
# express,a	13
# express,the	17
# expressed,as	1
# expressed,by	9
# extended,by	8
# extended,to	2
# external,links	1
# external,rewards	8
# external,teacher	8
# extract,from	2
# extraction,One	5
# extraction,and	1
# face,verification	10
# facets,of	3
# fact,that	10
# factorization,and	10
# factors,of	22
# facts,an	22
# facts,rather	10
# fail,on	10
# fail,to	26
# failed,to	20
# fairness,in	8
# faith,edits	1
# faithful,for	12
# faithful,to	10
# falls,between	8
# falls,into	22
# false,Regression	2
# false,negative	6
# false,positive	6
# families,have	4
# family,of	15
# fashion,both	8
# favor,Work	18
# feasibility,of	22
# feasible,if	22
# feature,elimination	5
# feature,engineering	10
# feature,extraction	1
# feature,learning	33
# feature,set	5
# feature,spaces	10
# feature,vector	9
# features,An	10
# features,It	22
# features,Its	8
# features,Most	5
# features,and	10
# features,are	20
# features,defined	22
# features,or	13
# features,that	10
# features,with	22
# federated,machine	9
# feedback,available	15
# feedback,in	3
# feedback,unsupervised	10
# feedback.clarification,needed	3
# feelings,about	8
# few,years	5
# field,A	12
# field,Machine	8
# field,argues	1
# field,as	18
# field,changed	18
# field,devoted	1
# field,in	12
# field,is	10
# field,of	90
# field,started	18
# field,that	37
# field,vii	3
# fields,According	9
# fields,The	1
# fields,arises	11
# fields,effective	2
# fields,in	8
# fields,machine-learning	9
# fields,such	1
# fields,which	5
# file,the	10
# filtering,and	4
# filtering,detection	5
# filtering,optical	4
# filtering,playing	10
# filtering,speech	5
# filters,emails	10
# finally,meta-learning	4
# financial,crisis	19
# find,a	34
# find,computer	1
# find,meaningful	4
# find,patterns	12
# find,structure	13
# find,the	4
# finding,applications	2
# finding,good	18
# finding,patterns	4
# finding,the	7
# findings,research	6
# finds,generalizable	8
# finds,other	3
# fine,art	18
# finite,and	22
# finite,collection	2
# firm,Rebellion	19
# firm,with	12
# first,Netflix	22
# first,implementation	10
# first,layer	10
# first,research	9
# fit,all	4
# fit,least	7
# fit,neatly	7
# fit,the	11
# fitness,landscape	1
# fits,the	4
# fitted,the	8
# fitting,in	8
# fix,display	1
# flourish,in	18
# focus,away	18
# focuses,in	2
# focuses,more	8
# focuses,on	44
# focusing,on	7
# folder,in	10
# following,	4
# following,Alan	10
# following,machine	8
# following,only	1
# following,strictly	7
# following,x	6
# follows,Alan	12
# for,1	22
# for,COVID-19	5
# for,Racial	5
# for,a	36
# for,additional	3
# for,all	10
# for,any	14
# for,artificial	18
# for,categories	3
# for,classification	23
# for,configurations	12
# for,criminal	10
# for,data	1
# for,decision	8
# for,decision-making	2
# for,decisions	10
# for,deep	6
# for,discovering	32
# for,each	12
# for,effectively	1
# for,evaluation	9
# for,example	48
# for,examples	2
# for,fairness	8
# for,further	3
# for,future	6
# for,human	13
# for,implementing	1
# for,inductive	10
# for,input	20
# for,inputs	10
# for,instances	10
# for,its	10
# for,labeling	3
# for,machine	42
# for,many	1
# for,much	7
# for,multidimensional	21
# for,patients	11
# for,pattern	8
# for,performing	2
# for,personal	5
# for,reducing	1
# for,representing	19
# for,robot	8
# for,sparse	19
# for,statistical	12
# for,stock	6
# for,the	28
# for,their	3
# for,them	6
# for,this	10
# for,training	22
# for,transferring	3
# for,trendline	8
# for,unknown	1
# for,users'	9
# for,various	4
# for,when	9
# for,which	6
# form,is	8
# form,of	10
# formal,definition	22
# formatting,The	1
# formed,by	10
# forms,of	21
# formulated,as	17
# found,a	7
# found,in	20
# found,some	8
# found,that	13
# found,to	33
# foundation,for	10
# framework,for	1
# fraud,a	10
# freedom,for	12
# frequently,misunderstood	3
# frequently,report	13
# from,AI	18
# from,ATT	21
# from,AlexNet	7
# from,HPE	1
# from,Twitter	10
# from,Uber	10
# from,a	48
# from,achieving	18
# from,an	1
# from,and	7
# from,biased	6
# from,biology	10
# from,data	48
# from,deep-rooted	1
# from,different	32
# from,example	2
# from,examples	10
# from,experience	22
# from,historical	5
# from,incomplete	3
# from,individual	9
# from,its	22
# from,machine	18
# from,methodological	17
# from,non-pattern	4
# from,observations	10
# from,one	10
# from,other	18
# from,positive	10
# from,sample	4
# from,some	22
# from,statistical	1
# from,statistics	18
# from,supervised	4
# from,tensor	21
# from,test	10
# from,the	217
# from,them	2
# fully,prepared	6
# fully,satisfactory	7
# function,Though	7
# function,in	3
# function,of	16
# function,on	17
# function,or	14
# function,r	12
# function,supervised	10
# function,that	32
# function,then	14
# function,underlying	15
# function,we've	1
# function,will	10
# functional,aspects	11
# functional,programs	19
# functions,and	22
# functions,can	22
# functions,evaluated	4
# functions,express	17
# fundamentally,operational	22
# further,processing	3
# furthering,the	3
# future,These	4
# future,is	22
# future,outcomes	6
# future,potential	6
# fuzzy,logic	3
# g,e	10
# game,against	13
# game,theory	10
# games,and	10
# gaming,and	12
# general,model	20
# general,something	2
# general,term	14
# generality,the	10
# generalizable,predictive	8
# generalization,For	1
# generalization,Representation	4
# generalization,complexity	1
# generalization,error	18
# generalization,of	6
# generalization,the	14
# generalization,while	17
# generalization,will	14
# generalize,from	22
# generalized,linear	18
# generally,the	4
# generally,unknown	22
# generally,without	10
# generate,new	18
# generate,their	6
# generated,by	10
# generates,its	8
# generates,new	1
# generating,distribution	12
# generating,lower-level	22
# generating,machines	3
# generative,models	1
# genetic,algorithm	32
# genetic,algorithms	29
# genetic,and	17
# genetic,environment	16
# genome,species	8
# genotype,in	8
# genotypes,in	10
# geographically,separate	4
# gerrymandered,to	4
# give,computers	1
# given,a	3
# given,computational	1
# given,data	8
# given,feedback	3
# given,normal	10
# given,on	8
# given,pairs	12
# given,problem	18
# gives,an	6
# gives,computers	11
# go,from	10
# go-to,models	8
# goal,assuming	1
# goal,from	18
# goal,in	8
# goal,is	10
# goal,of	27
# goal,seeking	2
# goal,statistics	8
# goal-seeking,behavior	6
# goals,on	14
# good,faith	1
# good,is	9
# good,performance	3
# good,solutions	18
# goof,button	3
# gorilla,from	2
# gorillas,and	10
# gorillas,at	10
# gorillas,from	8
# got,killed	1
# grammar,The	1
# grand,prize	1
# graph,DAG	22
# graph,connectivity	22
# graphic,processing	7
# graphical,model	44
# great,tool	6
# greed,biases	6
# green,behavior	3
# grew,out	18
# group,of	12
# group,the	3
# grouped,into	1
# grouping,or	13
# groups,that	10
# growth,of	6
# guaranteed,are	4
# guarantees,of	22
# guidance,mechanisms	14
# had,a	18
# had,been	36
# had,come	18
# had,denied	5
# had,displaced	7
# had,inherited	18
# had,non-European	5
# hamburger,meat	10
# hand,machine	22
# hand,on	7
# handwritten,digits	6
# happen,until	6
# happening,because	3
# hard,and	4
# hardware,acceleration	3
# hardware,compute	4
# hardware,computing	3
# hardware,have	7
# hardware,prices	5
# hardware,used	4
# has,a	2
# has,already	22
# has,also	22
# has,applications	10
# has,become	5
# has,been	95
# has,improved	6
# has,intimate	17
# has,many	22
# has,not	27
# has,often	7
# has,one	10
# has,strong	8
# has,the	1
# has,to	22
# has,two	6
# has,under	8
# has,underfit	6
# have,a	23
# have,adopted	18
# have,any	13
# have,been	79
# have,contributed	5
# have,demonstrated	3
# have,found	8
# have,geographically	4
# have,had	18
# have,human	1
# have,labels	2
# have,learned	10
# have,led	7
# have,revealed	18
# have,separate	22
# have,the	5
# having,experienced	20
# having,human	6
# having,machines	18
# having,to	9
# having,trained	2
# he,explores	2
# health,care	44
# healthcare,data	1
# healthcare,with	10
# hearing,Some	15
# heavily,on	6
# held,the	22
# help,a	1
# help,make	5
# help,the	7
# help,users	2
# henceforth,reducing	3
# here,refers	10
# heuristic,method	18
# heuristic,technique	10
# heuristic,that	8
# hidden,insights	5
# hidden,layers	15
# hidden,units	7
# hierarchy,of	22
# high,bias	1
# high,quantity	3
# high-dimensional,data	4
# high-dimensional,feature	10
# high-dimensional,vectors	11
# higher,dimensional	3
# higher-dimensional,data	4
# higher-dimensional,space	6
# higher-dimensional,vectors	10
# higher-level,more	22
# hiring,data	12
# hiring,policies	12
# his,paper	17
# historical,information	6
# historical,relationships	5
# history,to	10
# hold,stakes	11
# holdout,and	14
# holdout,method	6
# hope,of	18
# horses,A	4
# horses,and	4
# host,of	15
# how,an	12
# how,backdoors	3
# how,complex	4
# how,pairs	2
# how,similar	10
# how,software	10
# how,the	4
# how,they	3
# how,to	7
# how,well	4
# however,be	4
# however,these	9
# huge,potential	6
# human,and	4
# human,brain	25
# human,brains	1
# human,good	9
# human,intuition	4
# human,languages	8
# human,operator/teacher	3
# human,opponent	13
# human,programmers	7
# human,teachers	8
# human,to	7
# human,user	3
# human-being,Recently	3
# human-like,biases	10
# human-made,data	1
# humans,These	6
# humans,are	4
# humans,can	2
# humans,current	4
# hype,cycle	2
# hyperparameter,optimization	2
# hypotheses,Given	22
# hypotheses,and	19
# hypothesis,is	30
# hypothesis,proposes	4
# hypothesis,should	15
# hypothesis,that	1
# hypothesized,logic	22
# hypothetical,algorithm	6
# i,o	10
# i.e,progressively	1
# idea,is	22
# ideas,of	18
# identification,and	14
# identification,of	10
# identifies,learns	14
# identifies,spam	3
# identify,a	28
# identify,commonalities	10
# identify,strong	10
# identity,tracking	10
# if,a	10
# if,it	22
# if,its	22
# if,new	12
# if,our	1
# if,the	27
# image,can	4
# image,classifier	4
# image,classifiers	4
# image,contained	3
# image,de-noising	22
# image,dictionary	22
# image,patch	17
# image,path	5
# image,would	3
# images,and	6
# images,of	4
# images,sensor	3
# images,that	4
# images,video	10
# images,with	3
# imitation.clarification,needed	3
# immune,systems	14
# impacts,on	3
# impacts,people	9
# implausible,under	22
# implementation,Model	10
# implementation,of	2
# implementations,of	4
# implementations,the	10
# implementing,statistical	1
# implications,in	7
# implicitly,map	8
# implicitly,mapping	10
# implies,an	5
# importantly,add	1
# importantlyit,impacts	9
# imprecise,however	9
# improve,automatically	4
# improve,computer	1
# improve,learner	22
# improve,performance	3
# improve,the	47
# improve,their	1
# improved,with	6
# improvement,in	8
# improves,the	10
# improves,with	22
# improving,health	11
# in,1959	17
# in,1973	8
# in,1981	10
# in,1982	8
# in,1988	5
# in,2009	22
# in,2018	10
# in,Art	8
# in,Bayesian	2
# in,Databases	2
# in,KDD	1
# in,Knowledge	9
# in,Microsoft	8
# in,Recommendation	12
# in,T	22
# in,The	2
# in,There	4
# in,Turing's	5
# in,a	161
# in,accordance	8
# in,activity	4
# in,adversarial	4
# in,an	67
# in,application	10
# in,artificial	7
# in,automated	18
# in,autonomous	13
# in,bias	1
# in,bioinformatics	10
# in,both	7
# in,cases	3
# in,certain	1
# in,classification	17
# in,cognitive	12
# in,collaboration	21
# in,commercial	5
# in,conjunction	8
# in,constructing	7
# in,contrast	14
# in,data	16
# in,databases	22
# in,density	3
# in,detrimental	3
# in,developing	5
# in,each	18
# in,embedded	3
# in,feature	3
# in,fundamentally	10
# in,having	18
# in,health	22
# in,healthcare	10
# in,his	17
# in,image	22
# in,industrial	2
# in,k	4
# in,knowledge	12
# in,large	22
# in,large-scale	10
# in,larger	9
# in,learning	21
# in,machine	44
# in,making	1
# in,many	29
# in,medicine	5
# in,mind	8
# in,new	22
# in,nonlinear	4
# in,order	57
# in,other	10
# in,particular	20
# in,pattern	18
# in,polynomial	66
# in,prediction-making	3
# in,ranking	10
# in,references	1
# in,response	14
# in,ridge	8
# in,several	22
# in,skewed	6
# in,society	10
# in,some	11
# in,statistical	8
# in,statistics	38
# in,supermarkets	10
# in,technical	5
# in,terms	42
# in,that	12
# in,the	357
# in,their	35
# in,these	10
# in,this	26
# in,those	12
# in,two	8
# in,which	61
# inactivity,This	6
# include,Active	1
# include,K-SVD	1
# include,active	6
# include,artificial	10
# include,classification	3
# include,dictionary	10
# include,email	3
# include,images	3
# include,learning	14
# include,polynomial	8
# include,principal	22
# include,spam	5
# include,the	19
# include,topic	3
# including,Fei-Fei	9
# including,Hopfield	18
# including,Web	10
# including,computer	10
# including,hardware	3
# including,in	3
# including,machine	2
# including,white-box	3
# income,generating	3
# income-generating,machines	8
# incoming,email	10
# incomplete,training	9
# incorrect,decisions	3
# increase,in	7
# increase,profits	4
# increase,the	1
# increased,in	14
# increased,reviewer	6
# increases,efficiency	9
# increases,or	10
# increasing,availability	11
# increasing,emphasis	18
# increasing,profits	7
# increasingly,expressed	9
# independence,with	10
# independencies,via	12
# independent,component	10
# indicate,that	10
# indicators,of	17
# individual,is	1
# individual,searches	9
# individual,users	9
# induces,misclassification	1
# induces,misclassification.citation	3
# induction,proving	10
# induction,suggesting	10
# inductive,bias	11
# inductive,here	10
# inductive,logic	18
# inductive,machine	10
# inductively,inferred	10
# industrial,contexts	2
# infeasible,Example	3
# infeasible,Reinforcement	10
# infeasible,example	4
# infeasible,to	4
# inference,although	7
# inference,and	22
# inference,instead	2
# inferences,can	4
# inferences,from	8
# inferences,that	4
# inferred,logic	10
# inflated,expectations	2
# influence,diagrams	10
# influences,among	9
# influences,between	9
# inform,the	6
# information,These	6
# information,a	10
# information,and	11
# information,can	10
# information,in	22
# information,retrieval	18
# information,than	13
# information,theory	10
# information,using	12
# inherent,unbalanced	2
# inherently,unbalanced	8
# inherited,from	18
# initial,emotions	8
# initial,theoretical	10
# initially,and	8
# input,and	8
# input,available	4
# input,but	22
# input,data	22
# input,doesn't	2
# input,examples	20
# input,for	10
# input,from	8
# input,including	3
# input,layer	10
# input,may	3
# input,nor	8
# input,observations	1
# input,situation	8
# input,that	10
# input,variables	16
# input,would	10
# input/output,pairs	12
# inputoutput,examples	2
# inputs,2	1
# inputs,An	10
# inputs,Machine	4
# inputs,Signals	10
# inputs,Such	1
# inputs,The	10
# inputs,and	48
# inputs,are	1
# inputs,based	3
# inputs,coming	22
# inputs,for	3
# inputs,in	5
# inputs,into	13
# inputs,provided	22
# inputs,that	10
# inquiry,devoted	2
# insiders,working	4
# insights,through	5
# inspired,by	36
# instance,in	14
# instance,is	5
# instance,to	10
# instances,and	21
# instances,are	4
# instances,for	17
# instances,in	10
# instances,is	7
# instances,of	5
# instances,that	10
# instances,the	4
# instances,themselves	1
# instances,with	14
# instead,It	2
# instead,of	5
# institutional,racism	2
# instructions,by	4
# instructions,for	2
# instructions,relying	2
# integrated,within	3
# intellectual,properties	3
# intelligence,A	3
# intelligence,AI	3
# intelligence,Already	11
# intelligence,Also	2
# intelligence,In	7
# intelligence,Machine	9
# intelligence,The	3
# intelligence,and	1
# intelligence,coined	5
# intelligence,concerns	2
# intelligence,in	1
# intelligence,is	2
# intelligence,machine	4
# intelligence,scientists	9
# intelligence,statistics	10
# intelligence,to	24
# intelligent,machine	22
# intended,to	15
# interacting,with	5
# interaction,between	8
# interaction,with	19
# interactively,these	3
# interconnected,group	12
# interest,but	11
# interest,of	1
# interested,in	18
# interesting,objects	10
# interesting,relations	12
# interestingness,This	1
# internal,compactness	22
# intimate,ties	17
# into,K	9
# into,a	5
# into,categories	3
# into,classifying	3
# into,generative	1
# into,high-dimensional	21
# into,higher-dimensional	10
# into,k	1
# into,layers	10
# into,machine	3
# into,one	22
# into,several	3
# into,spam	4
# into,subsets	22
# into,the	7
# into,this	7
# into,three	13
# into,two	2
# into,vision	15
# introduced,association	10
# introduced,in	8
# introduces,non-linearity	8
# intruders,and	1
# intruders,or	4
# intrusion,detection	20
# intuition,cannot	4
# intuition,in	4
# investigators,frequently	13
# investigators,sometimes	13
# involves,changing	5
# involves,computers	10
# involves,creating	9
# involves,training	10
# involving,summarizing	10
# is,	1
# is,K-SVD	8
# is,a	351
# is,about	2
# is,also	13
# is,an	91
# is,answered	2
# is,applicable	4
# is,artificial	2
# is,associated	23
# is,assumed	22
# is,at	1
# is,available	8
# is,becoming	3
# is,behavioral	2
# is,best	10
# is,called	12
# is,closely	17
# is,computed	10
# is,concerned	41
# is,considered	22
# is,difficult	15
# is,drawn	8
# is,driven	8
# is,employed	8
# is,especially	11
# is,frequently	3
# is,genetic	2
# is,given	15
# is,hard	4
# is,huge	6
# is,in	24
# is,increased	14
# is,increasingly	9
# is,infeasible	6
# is,inspired	15
# is,intended	10
# is,known	30
# is,large	1
# is,learning	2
# is,less	15
# is,likely	10
# is,linear	8
# is,low-dimensional	22
# is,mathematically	10
# is,methods	3
# is,motivated	10
# is,needed	7
# is,neither	8
# is,not	1
# is,notable	10
# is,often	7
# is,oftentimes	1
# is,one	50
# is,only	10
# is,part	9
# is,particularly	10
# is,possible	7
# is,potential	5
# is,principal	4
# is,provided	3
# is,recently	3
# is,reducing	8
# is,replaced	12
# is,represented	41
# is,run	3
# is,said	32
# is,seen	8
# is,semi-supervised	6
# is,something	9
# is,sometimes	20
# is,sparse	34
# is,statistical	6
# is,strongly	18
# is,studied	10
# is,subject	14
# is,that	30
# is,the	176
# is,thus	2
# is,to	88
# is,too	15
# is,trained	9
# is,typically	10
# is,uncertain	22
# is,unfeasible	1
# is,used	24
# is,usually	22
# is,vaguely	1
# is,whether	2
# issue,such	10
# issues,The	1
# issues,with	10
# it's,best	12
# it's,created	2
# it,In	10
# it,analyzes	1
# it,and	10
# it,behaves	8
# it,can	40
# it,contained	3
# it,fits	4
# it,had	18
# it,has	28
# it,in	22
# it,initially	8
# it,is	22
# it,may	18
# it,quickly	10
# it,relies	2
# it,to	31
# it,useful	22
# it,uses	7
# it,via	4
# it,was	10
# it,will	7
# it,won	1
# item's,target	22
# item,represented	10
# item,to	12
# items,either	10
# items,events	10
# items,represent	10
# iteration,executes	8
# iterative,optimization	10
# its,application	10
# its,chance	5
# its,created	7
# its,defining	10
# its,designers	2
# its,existing	22
# its,experience	19
# its,experience.full	3
# its,generality	10
# its,goal	18
# its,goals	5
# its,input	2
# its,inputs	10
# its,outputs	10
# its,own	24
# its,peak	2
# its,performance	22
# its,use	9
# itself,is	1
# job,applicants	12
# job,hiring	12
# jobs,would	14
# joint,probability	12
# joint,team	21
# journals,ECML	22
# judgments,from	4
# just,beginning	9
# k,	1
# k,subsets	5
# k-1,instances	4
# k-fold-cross-validation,method	1
# keeping,all	5
# kernel,regression	8
# kernel,that	2
# kernel,trick	18
# key,difference	10
# key,idea	22
# key,object	4
# key,task	22
# killed,The	1
# killed,after	10
# killed,rather	1
# kind,of	19
# kinds,of	32
# knowledge,Evaluated	22
# knowledge,The	14
# knowledge,an	22
# knowledge,and	44
# knowledge,captured	14
# knowledge,discovery	24
# knowledge,in	14
# knowledge,of	10
# knowledge,while	22
# knowledge-based,approach	18
# known,as	92
# known,at	6
# known,background	22
# known,knowledge	44
# known,properties	14
# kth,instance	4
# kth,subset	1
# label,some	7
# label,the	3
# label,to	17
# labeled,as	10
# labeled,classified	10
# labeled,data	8
# labeled,input	10
# labeled,training	16
# labeling,Reinforcement	3
# labels,Decision	10
# labels,Unsupervised	2
# labels,When	3
# labels,and	10
# labels,are	18
# labels,but	2
# labels,for	3
# labels,of	17
# labels,yet	7
# lack,of	30
# laid,the	10
# landscape,determined	1
# language,Because	10
# language,contains	6
# language,corpora	14
# language,documents	3
# language,for	6
# language,processing	10
# languages,Awesome	1
# languages,contain	8
# languages,for	13
# large,and	3
# large,databases	22
# large,enough	1
# large,output	1
# large,representative	6
# large,variety	8
# large-scale,commercial	7
# large-scale,problems	2
# large-scale,transaction	10
# larger,effective	9
# larger,than	12
# largest,deep	7
# last,10,000	4
# last,few	5
# last,layer	10
# last,revision	1
# later,found	18
# latter,is	8
# latter,sub-field	1
# latter,subfield	4
# layer,By	1
# layer,possibly	10
# layer,the	20
# layer,to	10
# layers,Different	10
# layers,in	15
# layers,may	10
# layers,multiple	10
# layers,of	7
# lead,to	22
# leading,to	50
# leaks,happening	3
# learn,a	22
# learn,and	9
# learn,bias	6
# learn,from	72
# learn,i.e	1
# learn,learns	8
# learn,low-dimensional	21
# learn,relationships	4
# learn,that	1
# learn,the	10
# learn,their	3
# learn,these	8
# learn,to	15
# learn,without	11
# learned,from	34
# learned,in	44
# learned,representation	44
# learned,to	10
# learned,using	10
# learned,with	10
# learner,accuracy	22
# learner,has	22
# learner,is	26
# learners,that	4
# learning,	1
# learning,Bayesian	10
# learning,Classification	3
# learning,Data	10
# learning,Dimensionality	3
# learning,In	43
# learning,It	3
# learning,ML	16
# learning,Probabilistic	18
# learning,See	1
# learning,Some	2
# learning,The	6
# learning,They	14
# learning,Tree	10
# learning,a	4
# learning,accuracy	8
# learning,algorithm	61
# learning,algorithms	385
# learning,also	39
# learning,and	86
# learning,applications	1
# learning,approaches	31
# learning,are	16
# learning,arises	6
# learning,as	8
# learning,can	18
# learning,classification	7
# learning,classifier	14
# learning,closely	10
# learning,component	14
# learning,concerned	10
# learning,consists	10
# learning,data	22
# learning,deals	4
# learning,did	18
# learning,differs	12
# learning,during	3
# learning,e.g	2
# learning,elaborated	8
# learning,employs	7
# learning,encompasses	10
# learning,engineering	3
# learning,engineers	3
# learning,ethics	3
# learning,experiences	6
# learning,explores	7
# learning,falls	8
# learning,features	20
# learning,field	12
# learning,finds	8
# learning,focuses	14
# learning,for	8
# learning,from	29
# learning,generates	8
# learning,genetic	18
# learning,grew	18
# learning,has	72
# learning,have	1
# learning,in	47
# learning,include	17
# learning,including	9
# learning,independent	10
# learning,involves	12
# learning,is	255
# learning,it	4
# learning,leading	18
# learning,machine	35
# learning,maturation	14
# learning,may	10
# learning,means	12
# learning,medical	14
# learning,method	34
# learning,methods	50
# learning,model	24
# learning,models	41
# learning,or	37
# learning,paradigm	8
# learning,paradigms	2
# learning,performance	22
# learning,poses	12
# learning,problem	12
# learning,problems	25
# learning,proceeds	10
# learning,program	1
# learning,programs	4
# learning,projects	7
# learning,reinforcement	18
# learning,related	1
# learning,remains	3
# learning,reorganized	12
# learning,research	5
# learning,routine	8
# learning,signal	8
# learning,situations	8
# learning,software	1
# learning,sometimes	1
# learning,system	48
# learning,systems	27
# learning,tasks	33
# learning,technique	1
# learning,techniques	17
# learning,technology	10
# learning,that	15
# learning,the	29
# learning,theorists	22
# learning,theory	85
# learning,time	6
# learning,to	50
# learning,typically	10
# learning,use	4
# learning,uses	22
# learning,using	14
# learning,vii	5
# learning,was	13
# learning,where	11
# learning,which	5
# learning,with	16
# learning,without	8
# learns,a	30
# learns,and	5
# learns,its	8
# learns,or	14
# learns,to	8
# least,10	22
# least,squares	8
# least,to	10
# leaves,It	10
# leaves,represent	10
# led,to	7
# legitimate,image	4
# lend,themselves	5
# length,or	3
# lengthy,pre-history	1
# less,complex	15
# less,similar	12
# less,the	18
# lesson,A	4
# let,machines	1
# letters,10	8
# levels,of	22
# leverage,data	3
# lie,along	4
# light,and	15
# like,Random	18
# like,grouping	13
# like,speech	10
# like,the	25
# likelihood,of	10
# likely,to	28
# limited,computing	3
# limited,or	9
# limited,set	16
# limiting,the	6
# line,is	8
# line,of	18
# line,too	18
# linear,classification	10
# linear,classifier	10
# linear,combination	22
# linear,models	18
# linear,regression	8
# link,to	21
# links,Removed	1
# links,that	1
# list,The	1
# list,of	1
# literature,While	6
# logic,and	3
# logic,program	22
# logic,programming	91
# logic,programs	10
# logical,database	22
# logical,knowledge-based	18
# logical,reasoning	6
# logical,setting	10
# logistic,regression	6
# long,pre-history	17
# long-standing,ethical	7
# long-term,reward	12
# longer,to	10
# looking,as	1
# looking,for	10
# looking,like	1
# loosely,model	10
# loss,function	17
# loss,on	34
# lost,in	14
# lot,of	6
# lot,questions	1
# low-dimensional,Sparse	22
# low-dimensional,manifolds	4
# low-dimensional,representations	21
# lower-level,features	22
# machine,Human	4
# machine,and	7
# machine,citation	1
# machine,develop	7
# machine,how	7
# machine,is	34
# machine,learner	4
# machine,learners	4
# machine,learning	987
# machine,mimic	1
# machine,to	30
# machine,translation	10
# machine,with	3
# machine-learned,system	8
# machine-learning,programs	13
# machine-learning,researchers	8
# machinecitation,needed	2
# machines,SVMs	22
# machines,This	11
# machines,do	22
# machines,learn	19
# machines,think	22
# machines,trained	14
# made,by	2
# made,up	21
# main,disagreement	2
# main,success	18
# maintained,by	9
# major,exception	22
# majority,of	20
# make,a	14
# make,data-driven	3
# make,decisions	5
# make,diagnoses	5
# make,different	22
# make,judgments	4
# make,predictions	47
# make,this	4
# makes,it	22
# making,In	10
# making,data	1
# making,data-driven	3
# making,decisions	1
# making,predictions	10
# malicious,insiders	4
# man-made,data	9
# management,firm	7
# manifold,hypothesis	4
# manifold,learning	4
# manifold,regularization	4
# manifolds,and	4
# manipulate,or	14
# manipulation,and/or	3
# manner,in	14
# manual,feature	10
# manually,create	7
# many,applications	9
# many,aspects	1
# many,devices	9
# many,different	1
# many,dimensionality	4
# many,layers	7
# many,learning	17
# many,machine	22
# many,machine-learning	8
# many,more	3
# many,of	6
# many,other	30
# many,outlier	8
# many,programming	1
# many,similarities	8
# many,sources	6
# many,ways	8
# many,zeros	22
# map,input	8
# mapping,their	10
# maps,observations	12
# maps,states	12
# marked,as	22
# market,basket	10
# marketing,activities	10
# match,the	15
# material,is	8
# mathematical,criterion	8
# mathematical,induction	10
# mathematical,model	50
# mathematical,models	3
# mathematical,optimization	17
# mathematically,and	10
# mathematics,methods	6
# mathrm,burger	10
# mathrm,onions,potatoes	10
# matrix,The	10
# matrix,Through	10
# matrix,W	8
# matrix,factorization	10
# matrix,where	12
# maturation,motor	14
# maximize,its	5
# maximize,some	22
# may,be	17
# may,differ	21
# may,exhibit	15
# may,have	41
# may,inform	6
# may,lead	12
# may,not	10
# may,perform	10
# may,result	3
# may,take	10
# may,use	6
# mean,that	2
# meaning,True	13
# meaning,that	10
# meaning,they	3
# meaningful,anomalies	4
# means,more	18
# means,solving	6
# means,the	6
# measure,P	22
# measure,of	10
# measured,by	22
# measurement,errors	1
# measures,how	10
# meat,Such	10
# mechanisms,such	14
# mechanisms,will	4
# media-services,provider	8
# medical,diagnosis	28
# medical,diagnostic	14
# medical,diagnostics	2
# medical,doctors	7
# medical,doctors'	7
# medical,problems	10
# medicate,and	11
# medication,in	11
# medicine,email	5
# members,of	32
# memory,called	3
# memory,matrix	8
# memory-based,learning	1
# memristor,or	4
# mental,models	2
# mentioned,previously	6
# mentioned,rates	13
# message,example	1
# messages,After	4
# messages,into	4
# messages,to	4
# meta,learning	5
# meta-learning,e.g	4
# method,a	12
# method,for	40
# method,is	10
# method,of	20
# method,randomly	14
# method,that	14
# method,to	13
# method,used	5
# method,where	10
# method,which	14
# method,will	22
# methodological,principles	18
# methodology,inspired	1
# methods,and	40
# methods,are	22
# methods,as	40
# methods,bootstrap	14
# methods,but	30
# methods,can	1
# methods,cannot	22
# methods,for	7
# methods,from	18
# methods,in	10
# methods,may	2
# methods,of	4
# methods,on	1
# methods,starting	4
# methods,such	28
# methods,that	6
# methods,theory	18
# methods,to	16
# methods,used	22
# methods,while	22
# metric,and	22
# metric,function	12
# micro-clusters,formed	10
# microcontrollers,Running	3
# mid-1980s,with	18
# might,conclude	4
# might,not	11
# million,Shortly	17
# mimic,the	1
# mimics,the	22
# mind,On	8
# minimization,of	17
# minimize,the	17
# minimizes,theft	3
# minimizing,the	17
# minimum,training	1
# mining,KDD	12
# mining,a	10
# mining,although	3
# mining,and	10
# mining,anomaly	10
# mining,association	10
# mining,focuses	14
# mining,intrusion	10
# mining,is	10
# mining,methods	22
# mining,often	18
# mining,uses	22
# mining,where	5
# minor,prizes	1
# misclassification.citation,needed	3
# misconceptions,XAI	2
# missing,Transduction	6
# missing,the	2
# missing,training	9
# misunderstood,ML	3
# mitigate,overfitting	8
# mloss,is	1
# mlpy,MCMLL	3
# mobile,phones	9
# model',means	6
# model's,diagnostic	11
# model,Because	3
# model,In	16
# model,Trained	6
# model,about	20
# model,accuracy	14
# model,and	18
# model,assessment	2
# model,based	20
# model,being	17
# model,complex	12
# model,each	10
# model,from	11
# model,has	24
# model,in	3
# model,is	53
# model,machine	3
# model,means	12
# model,of	23
# model,on	14
# model,one	6
# model,representing	10
# model,sequences	10
# model,that	58
# model,the	25
# model,to	31
# model,trained	1
# model,wherein	18
# model,which	21
# model,while	5
# model,without	5
# modeling,approaches	10
# modeling,dimensionality	2
# modeling,meta	3
# modeling,meta-learning	2
# modeling,paradigms	9
# modeling,tools	12
# modeling,where	3
# modelling,paradigms	9
# models,A	6
# models,allow	5
# models,and	9
# models,are	30
# models,borrowed	18
# models,can	14
# models,derived	6
# models,diagnostic	2
# models,from	3
# models,have	9
# models,how	2
# models,in	2
# models,include	8
# models,learned	10
# models,may	3
# models,of	20
# models,on	9
# models,require	9
# models,that	30
# models,to	3
# models,where	10
# models,which	9
# modes,of	1
# moles,A	3
# moles,Where	3
# moles,coupled	6
# money,management	7
# morality,AI	1
# more,abstract	22
# more,advanced	7
# more,data	1
# more,effective	7
# more,effectively	2
# more,efficient	7
# more,formal	22
# more,general	2
# more,importantly	1
# more,information	13
# more,inputs	10
# more,nuanced	1
# more,on	8
# more,or	18
# more,predesignated	10
# more,seen	6
# more,statistical	18
# more,than	7
# more,types	1
# morning,as	4
# morning,for	4
# most,common	8
# mostly,perceptrons	18
# mostly,unsupervised	12
# mostly,with	8
# motivated,by	10
# motor,synergies	14
# moved,to	10
# movements,The	4
# movements,the	3
# movie,company	14
# movie,recommendation	22
# much,ongoing	7
# multi-agent,systems	10
# multidimensional,data	21
# multilayer,perceptrons	10
# multiple,hidden	15
# multiple,levels	22
# multiple,times	10
# multitude,of	4
# multivariate,normal	2
# must,specify	4
# mutation,and	18
# n,by	1
# n,i	10
# n,instances	14
# n,is	12
# n,matrix	11
# n,s	10
# name,machine	4
# name,of	10
# named,Crossbar	2
# named,crossbar	6
# named,for	3
# names,Using	5
# narrow,subdomain	7
# natural,language	13
# natural,selection	18
# nature,It	18
# nature,of	23
# nearly,60	5
# neatly,into	7
# necessarily,also	14
# necessarily,faithful	22
# necessary,sensitivity	6
# need,for	7
# need,to	3
# needed,For	7
# needed,Generalization	3
# needed,Machine	3
# needed,Probabilistic	1
# needed,Semi-supervised	3
# needed,algorithms	7
# needed,step	7
# needed,tasks	7
# needing,to	9
# needs,of	10
# needs,to	18
# negative,examples	32
# negative,impacts	3
# negative,rate	6
# negative,reinforcement	3
# neither,a	8
# network,ANN	12
# network,NN	12
# network,This	15
# network,belief	22
# network,can	22
# network,capable	8
# network,could	22
# network,filtering	10
# network,in	4
# network,intruders	5
# network,intrusion	10
# network,is	4
# network,itself	1
# network,learns	8
# network,or	26
# networks,ANNs	10
# networks,Computations	12
# networks,Generalizations	10
# networks,Statistical	2
# networks,a	7
# networks,are	22
# networks,have	10
# networks,in	8
# networks,mostly	1
# networks,multilayer	10
# networks,research	18
# networks,that	30
# networks,these	17
# neural,network	68
# neural,networks	99
# neural,synapse	8
# neuron,is	10
# neuron,that	10
# neuron,to	10
# neurons,and	10
# neurons,are	20
# neurons,as	4
# neurons,connected	10
# neurons,in	10
# neurons,is	10
# neurons,may	10
# neurons,processing	12
# neurons,which	10
# never,presented	12
# nevertheless,be	2
# new,approach	2
# new,cases	22
# new,customer	10
# new,datum	12
# new,email	4
# new,example	22
# new,genotype	8
# new,genotypes	10
# new,inputs	10
# new,objects	12
# new,piece	10
# new,point	2
# new,rules	1
# new,skills	6
# new,training	10
# new,unobserved	2
# new,unseen	22
# next,two	14
# no,desired	3
# no,external	16
# no,fully	7
# no,learning	7
# no,negative	18
# no,of	1
# nodes,called	10
# noise,cannot	22
# noise,deviations	10
# noisy,limited	9
# non-European,sounding	5
# non-evaluated,data	3
# non-linear,classification	10
# non-linear,function	10
# non-linear,hidden	7
# non-linear,problems	8
# non-linear,statistical	12
# non-linearity,by	8
# non-pattern,perturbations	4
# non-probabilistic,binary	10
# non-spam,folders	4
# non-spam,messages	4
# non-white,people	10
# none,of	4
# nonlinear,systems	4
# nor,an	8
# nor,sub-optimal	12
# normal,and	10
# normal,behavior	10
# normal,by	10
# normal,distribution	2
# normal,training	10
# not,a	10
# not,able	10
# not,adhere	10
# not,all	11
# not,an	1
# not,assume	10
# not,be	21
# not,been	11
# not,being	25
# not,consider	10
# not,enough	4
# not,fit	1
# not,fully	3
# not,happen	6
# not,needing	9
# not,only	19
# not,primarily	1
# not,rare	10
# not,related	11
# not,represented	10
# not,spam	6
# not,the	17
# not,well	10
# not,yet	6
# not,yield	22
# not,yielded	10
# notable,for	10
# notably,be	3
# nothing,artificial	9
# notion,of	22
# novel,skills	8
# novelties,noise	10
# now,outside	18
# nuanced,such	4
# number,and	10
# number,of	12
# numbers,are	10
# numbers,of	7
# numerators,and	26
# numerical,value	10
# numerous,lack	10
# o,e	10
# o,n	20
# o,t	10
# object,In	3
# object,Many	2
# object,and	8
# object,of	4
# object,the	6
# objective,function	10
# objective,of	22
# objectives,Algorithmic	3
# objectives,one	6
# objectivity,and	6
# objects,It	12
# objects,Modifying	4
# objects,are	32
# objects,but	10
# oblivious,to	4
# observations,about	22
# observations,drawn	22
# observations,in	1
# observations,into	22
# observations,whereas	5
# observations,which	10
# observations,within	22
# observed,data	22
# observed,facts	10
# observed,points	4
# observed,variables	12
# obtain,resulting	9
# obtaining,a	5
# obvious,such	4
# occurrences,and	20
# of,2016	2
# of,2016update	1
# of,2019	1
# of,2020	10
# of,2022	2
# of,3.4	7
# of,3D	5
# of,AI	52
# of,AI-powered	2
# of,Azure	1
# of,Bayesian	10
# of,D	12
# of,Deep	2
# of,Distributed	1
# of,Duda	1
# of,English	1
# of,GPUs	5
# of,Knowledge	2
# of,ML	9
# of,Machine	2
# of,Sun	14
# of,Why	2
# of,a	211
# of,abuse	10
# of,access	10
# of,algorithmic	12
# of,algorithms	34
# of,all	4
# of,an	47
# of,anomaly	10
# of,any	3
# of,applications	9
# of,art	10
# of,artificial	29
# of,backpropagation	18
# of,basis	22
# of,biological	11
# of,biomedical	6
# of,brown	4
# of,certain	4
# of,clustering	10
# of,computational	4
# of,compute	7
# of,computer	25
# of,computers	5
# of,computing	8
# of,connected	10
# of,context-dependent	14
# of,cumulative	10
# of,current	6
# of,data	125
# of,data/software	3
# of,deep	20
# of,density	10
# of,digital	7
# of,digitized	11
# of,dimensionality	5
# of,disordered	2
# of,distributed	6
# of,dollars	6
# of,each	10
# of,either	3
# of,email	1
# of,ethical	26
# of,ethics	1
# of,examples	64
# of,facts	22
# of,families	4
# of,favor	18
# of,features	40
# of,finding	18
# of,functions	22
# of,future	6
# of,generalization	31
# of,genetic	18
# of,handwritten	6
# of,human-being	3
# of,images	9
# of,improving	11
# of,inactivity	6
# of,inflated	2
# of,input	5
# of,inputs	6
# of,inquiry	2
# of,intellectual	3
# of,interestingness	10
# of,investment	4
# of,items	10
# of,its	28
# of,knowledge	12
# of,labeled	8
# of,learning	37
# of,less	12
# of,long-term	12
# of,machine	207
# of,manifold	4
# of,mathematical	10
# of,medical	16
# of,methods	8
# of,model	1
# of,models	9
# of,moles	6
# of,multiple	15
# of,natural	21
# of,network	5
# of,new	10
# of,non-linear	7
# of,novel	8
# of,observations	22
# of,observed	2
# of,occurrences	20
# of,open-source	1
# of,or	22
# of,our	1
# of,outlier	10
# of,packages	1
# of,pattern	7
# of,points	2
# of,positive	3
# of,posts	3
# of,potential	7
# of,previous	5
# of,previously	36
# of,principal	5
# of,problem	6
# of,programming	19
# of,random	27
# of,rare	10
# of,real	4
# of,reducing	13
# of,related	22
# of,relational	14
# of,reliable	3
# of,representation	22
# of,research	18
# of,researchers	21
# of,resources	10
# of,responding	10
# of,rule-based	14
# of,sample	1
# of,self-learning	8
# of,semi-supervised	3
# of,some	17
# of,specific	2
# of,statistical	8
# of,statistics	17
# of,statistics.clarification	1
# of,strong	10
# of,study	25
# of,successfully	5
# of,such	20
# of,suitable	10
# of,supervised	17
# of,supervised-learning	3
# of,systems	4
# of,task	5
# of,tasks	35
# of,text	9
# of,the	566
# of,their	17
# of,theoretical	22
# of,this	27
# of,time	32
# of,training	61
# of,transferring	3
# of,transformations	10
# of,travelers	2
# of,two	22
# of,unsupervised	22
# of,users	2
# of,values	23
# of,variables	10
# of,variation	22
# of,various	28
# of,your	1
# offer,additional	1
# offers,a	12
# often,as	22
# often,attempt	22
# often,been	7
# often,cheaper	9
# often,defined	22
# often,developed	3
# often,do	1
# often,don't	3
# often,employ	22
# often,extended	7
# often,fail	13
# often,have	22
# often,many	6
# often,not	14
# often,overlaps	6
# often,require	10
# often,result	1
# often,tag	10
# often,used	8
# often,uses	1
# often,vulnerable	3
# often,with	15
# oftentimes,extended	1
# old,revision	21
# on,Learning	8
# on,a	71
# on,cloud	3
# on,computers	1
# on,current	9
# on,data	13
# on,datasets	15
# on,email	4
# on,embedded	3
# on,estimated	22
# on,explicit	10
# on,exploratory	18
# on,human-made	1
# on,inputs	1
# on,its	15
# on,known	14
# on,language	14
# on,machine	1
# on,making	10
# on,man-made	9
# on,models	6
# on,new	22
# on,objectivity	3
# on,passive	5
# on,patterns	2
# on,physical	4
# on,pictures	4
# on,prediction	14
# on,prediction-making	3
# on,previous	15
# on,research	3
# on,sample	9
# on,society	3
# on,some	12
# on,such	10
# on,symbolic/knowledge-based	18
# on,the	160
# on,their	12
# on,these	10
# on,unseen	21
# on,users'	9
# on,using	8
# on,whether	2
# on,your	1
# on-line,movie	1
# once,receives	8
# one,and	1
# one,approach	7
# one,are	5
# one,artificial	10
# one,category	22
# one,considers	8
# one,input	8
# one,is	21
# one,needs	6
# one,of	32
# one,or	21
# one,output	8
# one,that	22
# one,wants	17
# one,way	18
# ongoing,work	7
# onions,and	10
# onions,potatoes,Rightarrow	10
# online,movie	13
# only,an	5
# only,explicitly	1
# only,inputs	13
# only,just	9
# only,logic	19
# only,may	5
# only,on	4
# only,once	8
# only,one	16
# only,partially	3
# only,sent	10
# open-source,machine	1
# open-source,softwareanchorOpen-sourcesoftware	1
# operate,by	4
# operating,characteristic	15
# operating,in	1
# operational,definition	12
# operational,rather	10
# operations,research	10
# operator/teacher,to	3
# opponent,3	3
# opposed,to	4
# optical,character	8
# optimal,function	10
# optimise,smartphone's	4
# optimization,algorithms	17
# optimization,and	6
# optimization,delivers	10
# optimization,many	17
# optimization,multi-agent	10
# optimization,of	13
# optimization,used	2
# optimization,which	8
# optimize,a	1
# optimize,smartphone's	1
# optimize,the	3
# or,Explainable	2
# or,Interpretable	2
# or,Neuromorphic	4
# or,a	34
# or,absence	10
# or,across	10
# or,apply	14
# or,as	22
# or,behavior	8
# or,categorized	10
# or,clustering	13
# or,connectionist	10
# or,criteria	12
# or,decisions	18
# or,decreases	10
# or,directed	22
# or,errors	10
# or,even	8
# or,evolves	14
# or,exemplar-based	1
# or,extraction	5
# or,feedback	15
# or,from	4
# or,generating	22
# or,had	5
# or,imprecise	9
# or,in	13
# or,infeasible	5
# or,inputoutput	2
# or,inputs	3
# or,kernel	2
# or,less	18
# or,malicious	4
# or,medication	11
# or,meta	2
# or,more	21
# or,negative	3
# or,nodes	10
# or,non-evaluated	3
# or,not	3
# or,objectives	3
# or,observations	10
# or,other	4
# or,predictions	34
# or,predictive	2
# or,price	3
# or,problem	5
# or,product	10
# or,products	1
# or,protein	10
# or,related	10
# or,representations	10
# or,restricted	3
# or,the	34
# or,to	12
# or,undesired	6
# or,unfeasible	6
# or,unsupervised	24
# or,vector	10
# order,Generalization	1
# order,for	9
# order,of	10
# order,to	48
# ordinary,least	8
# organized,into	4
# original,goal	10
# original,variables	5
# other,An	8
# other,artificial	4
# other,categories	8
# other,depending	2
# other,disciplines	28
# other,documents	3
# other,domains	20
# other,electrically	4
# other,fields	1
# other,hand	22
# other,is	8
# other,machine	14
# other,models	18
# other,purpose	6
# other,statistical	10
# other,supervised	14
# other,systems	10
# other,teams	1
# other,words	5
# others,adopt	4
# ought,to	34
# our,hypothesis	1
# our,lives	1
# out,certain	7
# out,for	9
# out,of	36
# out,several	1
# out,to	7
# outcome,of	4
# outcomes,based	6
# outcomes,thereby	3
# outlier,as	10
# outlier,detection	30
# outliers,novelties	10
# outperformed,by	22
# output,In	1
# output,action	8
# output,also	10
# output,and	5
# output,associated	10
# output,designating	3
# output,for	11
# output,labels	2
# output,layer	11
# output,of	20
# output,would	13
# outputs,2	1
# outputs,For	3
# outputs,The	10
# outputs,Unsupervised	1
# outputs,are	13
# outputs,may	10
# outputs,meaning	3
# outputs,missing	6
# outputs,or	10
# outputs,to	12
# outputs,training	3
# outside,the	36
# over,time	20
# overall,accuracy	13
# overall,field	18
# overcome,following	4
# overfitted,After	1
# overfitting,Many	4
# overfitting,and	22
# overfitting,by	4
# overlap,in	8
# overlap,significantly	22
# overlaps,with	6
# overly,complex	4
# own,algorithm	7
# own,field	1
# own,inductive	11
# own,sequences	14
# owners,hold	11
# p,o	10
# packages,in	1
# page,as	21
# paintings,and	18
# pairs,are	12
# pairs,of	26
# paper,Computing	22
# paradigm,was	8
# paradigms,data	18
# paradigms,depending	2
# part,no	7
# part,of	48
# partially,available	3
# particular,can	10
# particular,in	10
# particular,narrow	7
# particular,unsupervised	10
# particularly,useful	10
# parties,Parties	3
# partitions,the	9
# passive,observations	5
# past,are	4
# past,training	4
# patch,can	17
# patches,are	4
# path,can	5
# paths,for	11
# patients,but	11
# patients,with	11
# pattern,classification	8
# pattern,does	10
# pattern,recognition	36
# patterns,According	8
# patterns,and	5
# patterns,everything	17
# patterns,in	15
# patterns,is	4
# patterns,on	4
# patterns,using	3
# peak,of	2
# pedestrian,who	10
# penalizing,the	4
# people,In	10
# people,It	9
# people,andmost	9
# people,as	10
# people,have	10
# people,it's	2
# people,its	7
# people,lack	10
# per,WP:LINKSPAM	1
# perceptrons,and	28
# perform,a	24
# perform,accurate	3
# perform,accurately	22
# perform,different	10
# perform,inference	22
# perform,more	2
# perform,tasks	17
# perform,that	10
# perform,the	10
# perform,well	10
# performance,and	5
# performance,are	22
# performance,at	22
# performance,bounds	22
# performance,in	14
# performance,is	47
# performance,measure	22
# performance,of	53
# performance,on	5
# performed,each	9
# performing,classification	22
# performing,either	14
# performing,linear	10
# performing,model	1
# performing,specific	10
# performing,the	3
# period,A	1
# period,with	1
# permanent,link	21
# perpetual,ethical	4
# personal,biases	17
# personal,data	3
# personal,use	5
# perturbations,Some	4
# philosophical,induction	10
# phones,without	9
# photos,would	10
# physical,hardware	4
# physical,neural	4
# physics,is	2
# physics,of	2
# pick,up	10
# picked,up	10
# picture,and	4
# pictures,of	4
# piece,of	10
# piecewise,manner	14
# pioneer,in	12
# pixel,predictably	4
# pixels,that	4
# placed,undetectably	3
# placeholder,to	18
# placements,In	10
# plagued,by	18
# plan,recovery	11
# play,a	13
# playing,board	10
# point,as	2
# point-of-sale,POS	10
# points,The	10
# points,Unsupervised	3
# points,and	4
# points,or	2
# points,relate	2
# policies,may	12
# policy,that	12
# polynomial,regression	8
# polynomial,time	66
# popular,heuristic	18
# popular,method	1
# popular,methods	4
# popular,surrogate	2
# population,inferences	8
# population,of	1
# portion,of	3
# poses,a	15
# positive,and	32
# positive,or	3
# positive,rate	6
# possessed,by	7
# possibility,to	7
# possible,to	7
# possibly,after	10
# possibly,including	3
# posts,machine	3
# potatoes,together	10
# potential,answers	7
# potential,for	11
# potential,predictions	6
# potential,result	6
# powerful,tool	9
# practical,nature	18
# practical,problems	18
# practice,it	7
# practitioners,for	1
# pre-assigned,labels	17
# pre-defined,covariance	2
# pre-history,in	18
# pre-processing,step	22
# predesignated,criteria	10
# predesignated,criterion	12
# predict,economic	7
# predict,if	12
# predict,the	54
# predict,user	22
# predictably,induces	4
# predicted,that	14
# prediction,	1
# prediction,Rule-based	14
# prediction,based	14
# prediction,in	4
# prediction,models	9
# prediction,of	10
# prediction-making,It	1
# prediction-making,through	5
# predictions,Algorithmic	3
# predictions,Bias	3
# predictions,This	10
# predictions,Various	9
# predictions,When	3
# predictions,allowing	12
# predictions,for	6
# predictions,in	22
# predictions,made	2
# predictions,of	17
# predictions,on	7
# predictions,or	18
# predictions,over	10
# predictions,using	10
# predictive,ability	5
# predictive,analytics	17
# predictive,model	22
# predictive,modeling	10
# predictive,modelling	2
# predictive,patterns	8
# predicts,based	5
# predicts,the	1
# predicts,whether	22
# preferences,and	22
# prejudices,For	12
# prejudices,Responsible	1
# prejudices,such	2
# prepared,for	6
# preprocessing,step	22
# presence,of	22
# presence,or	10
# present,address	21
# present,in	10
# presented,nor	12
# presented,to	3
# preserve,the	22
# previous,admissions	5
# previous,examples	4
# previous,experience	11
# previous,successful	12
# previously,and	6
# previously,mentioned	13
# previously,unknown	36
# previously,unrecognized	18
# previously,unseen	22
# price,of	3
# prices,and	5
# pricing,or	10
# primarily,make	4
# principal,component	7
# principal,components	20
# principal,goal	8
# principal,variables	5
# principle,where	6
# principles,to	18
# printed,characters	4
# privacy,leaks	3
# privacy,problems	10
# privacy,to	9
# prize,competition	1
# prize,was	17
# prizes,it	1
# pro-environmental,behavior	2
# probabilistic,bounds	22
# probabilistic,classification	10
# probabilistic,graphical	22
# probabilistic,relationships	22
# probabilities,of	22
# probability,density	10
# probability,distribution	34
# probability,theory	18
# probably,rise	4
# problem,In	18
# problem,at	7
# problem,in	12
# problem,instances	23
# problem,is	22
# problem,that	5
# problem,the	12
# problem,with	18
# problems,Meta	3
# problems,are	17
# problems,badly	10
# problems,go-to	8
# problems,in	10
# problems,including	2
# problems,is	10
# problems,learning	8
# problems,machine	10
# problems,of	36
# problems,or	10
# problems,under	10
# proceeds,The	10
# process,However	10
# process,MDP	6
# process,additional	9
# process,allowing	9
# process,complex	1
# process,has	2
# process,in	2
# process,is	2
# process,it	10
# process,of	31
# process,to	9
# processes,are	2
# processes,light	15
# processes,techniques	1
# processing,Gordon	10
# processing,henceforth	3
# processing,information	12
# processing,units	7
# produce,a	8
# produce,reliable	5
# produce,sufficiently	20
# produce,useful	2
# product,placements	10
# production,and	10
# products,in	10
# products,per	1
# professionals,a	6
# professionals,an	5
# professionals,that	11
# profiles,for	4
# profits,For	11
# profound,responsibility	9
# program's,ability	1
# program,It	1
# program,Pragmatic	1
# program,algorithms	7
# program,had	5
# program,instructions	7
# program,is	25
# program,that	28
# program,to	22
# program,trained	5
# program,which	4
# programmed,Arthur	1
# programmed,Evolved	1
# programmed,Machine	1
# programmed,instructions	1
# programmed,to	17
# programmed,with	10
# programmers,specify	7
# programming,708710	1
# programming,GP	1
# programming,ILP	22
# programming,The	1
# programming,as	22
# programming,but	17
# programming,explicit	8
# programming,is	29
# programming,language	6
# programming,languages	14
# programming,such	19
# programming,techniques	10
# programs,according	1
# programs,can	4
# programs,from	10
# programs,often	13
# programs,that	1
# progressively,improve	2
# projects,from	7
# promises,to	2
# promoted,websites	1
# promotional,pricing	10
# propelling,its	9
# proper,in	18
# properties,in	14
# properties,learned	14
# properties,personal	3
# property,for	10
# property,that	4
# proposal,he	2
# proposal,in	22
# proposal,the	5
# proposes,that	4
# proprietary,owners	11
# protein,sequences	10
# provide,modes	1
# provide,patients	11
# provide,professionals	11
# provided,a	22
# provided,during	22
# provided,possibly	3
# provided,so	7
# provider,Netflix	8
# provides,more	13
# proving,a	10
# public's,interest	11
# published,the	9
# punched,tape	3
# purpose,is	6
# quality,of	2
# quantify,generalization	18
# quantity,of	3
# query,prediction	9
# quest,for	18
# question,Can	44
# question,to	2
# questions,Systems	15
# questions,in	1
# quickly,picked	10
# quite,common	22
# quoted,more	22
# r,displaystyle	22
# r,g	10
# r,is	24
# r,where	4
# racism,and	2
# ...
# the,growth	6
# the,hardware	7
# the,holdout	20
# the,hope	18
# the,human	16
# the,hypothesis	45
# the,ideas	17
# the,identification	24
# the,increasing	11
# the,information	22
# the,inherent	2
# the,inherently	8
# the,initial	10
# the,input	26
# the,inputs	60
# the,instances	10
# the,interaction	8
# the,interesting	10
# the,internet	3
# the,item's	22
# the,k	1
# the,k-1	4
# the,k-fold-cross-validation	1
# the,kernel	18
# the,key	32
# the,knowledge	14
# the,known	22
# the,kth	5
# the,largest	7
# the,last	19
# the,latter	5
# the,layers	10
# the,learned	44
# the,learner	22
# the,learning	25
# the,least	3
# the,leaves	10
# the,likelihood	10
# the,list	1
# the,logical	18
# the,loss	34
# the,machine	54
# the,machinecitation	2
# the,majority	20
# the,mathematical	20
# the,media-services	8
# the,mental	2
# the,micro-clusters	10
# the,mid-1980s	18
# the,minimum	1
# the,model	88
# the,models	3
# the,more	18
# the,name	10
# the,nature	13
# the,necessary	6
# the,need	7
# the,needed	14
# the,needs	10
# the,negative	7
# the,network	22
# the,neurons	10
# the,new	2
# the,next	14
# the,noise	22
# the,number	10
# the,numerators	13
# the,object	3
# the,objectivity	3
# the,observed	24
# the,on-line	1
# the,online	13
# the,order	10
# the,other	56
# the,output	57
# the,outputs	23
# the,overall	18
# the,past	8
# the,performance	75
# the,personal	6
# the,phone	5
# the,picture	4
# the,popular	5
# the,positive	4
# the,possibility	7
# the,pre-assigned	17
# the,prediction	3
# the,predictions	17
# the,predictive	15
# the,presence	32
# the,previously	13
# the,prize	17
# the,pro-environmental	2
# the,probabilistic	22
# the,probabilities	22
# the,probability	7
# the,problem	47
# the,process	23
# the,property	4
# the,proposal	2
# the,public's	11
# the,quality	2
# the,quest	18
# the,question	44
# the,random	2
# the,realm	1
# the,reinvention	18
# the,relationship	8
# the,reliance	4
# the,remainder	10
# the,remaining	9
# the,resulting	10
# the,rule	10
# the,sales	10
# the,same	109
# the,sample	3
# the,scientific	3
# the,set	1
# the,signal	37
# the,similarity	10
# the,social	2
# the,space	20
# the,spatial	4
# the,statistical	12
# the,strength	10
# the,structure	33
# the,study	17
# the,subfield	6
# the,sum	10
# the,sun	4
# the,supervised	12
# the,symbolic	18
# the,synapses	10
# the,synonym	2
# the,system	22
# the,system's	4
# the,target	26
# the,targets	6
# the,task	16
# the,tasks	12
# the,teacher	6
# the,teams	21
# the,temperature	3
# the,term	26
# the,test	14
# the,theory	8
# the,time	22
# the,trader	6
# the,training	137
# the,two	11
# the,type	14
# the,unavailability	22
# the,underlying	22
# the,unknown	22
# the,unobservable	3
# the,unobserved	2
# the,use	7
# the,user's	5
# the,various	14
# the,view	5
# the,way	15
# the,weight	2
# the,word	1
# the,workaround	10
# the,working	4
# the,workload	6
# the,world	12
# the,wrong	4
# theft,of	3
# their,approach	5
# their,associated	8
# their,conditional	22
# their,continuous	3
# their,data	9
# their,first	10
# their,input	22
# their,inputs	20
# their,locations	2
# their,machine	1
# their,misconceptions	2
# their,numerators	13
# their,own	9
# their,performance	24
# their,principal	8
# their,recommendation	17
# their,use	12
# their,viewing	17
# them,into	21
# them,something	2
# them,to	16
# themselves,to	6
# then,K	9
# then,be	11
# then,can	9
# then,needs	12
# then,signal	10
# then,termed	18
# then,test	10
# then,the	42
# then,used	4
# then,we	1
# theoretical,and	18
# theoretical,computer	22
# theoretical,foundation	10
# theoretical,tools	18
# theorists,study	22
# theory,As	1
# theory,Because	19
# theory,It	11
# theory,a	22
# theory,and	26
# theory,control	10
# theory,gerrymandered	4
# theory,in	15
# theory,is	4
# theory,operations	10
# theory,simulation-based	10
# theory,to	10
# theory,usually	22
# theory,via	3
# there,is	17
# thereby,furthering	3
# therefore,learn	10
# thermal,behavior	1
# thermal,behaviour	4
# these,biases	28
# these,can	3
# these,greed	6
# these,instances	4
# these,labels	9
# these,models	6
# these,patterns	14
# these,rates	13
# these,systems	11
# these,tree	10
# these,two	22
# these,were	17
# they,are	17
# they,call	18
# they,can	6
# they,carry	7
# they,changed	17
# they,input	5
# they,learn	4
# they,may	3
# they,often	4
# they,use	8
# they,work	22
# think,be	10
# think,is	12
# thinking,entities	22
# thinking,machine	7
# third,parties	3
# this,are	10
# this,assumption	4
# this,can	4
# this,context	22
# this,curated	1
# this,is	19
# this,method	12
# this,page	21
# this,principle	6
# this,problem	12
# this,program	5
# this,requires	5
# this,revision	21
# this,space	20
# this,still	10
# this,three-fold	7
# this,time	4
# this,will	6
# this,would	2
# thorough,examination	1
# those,class	10
# those,points	2
# those,states	12
# though,unsupervised	3
# three,broad	13
# three-fold,categorisation	5
# three-fold,categorization	2
# threshold,Typically	10
# threshold,such	10
# through,autonomous	8
# through,building	4
# through,examination	9
# through,experience	4
# through,learning	5
# through,self-guided	6
# through,several	3
# through,the	5
# through,unsupervised	10
# thus,TOC	13
# thus,digitizing	15
# thus,finding	2
# thus,following	10
# thus,is	15
# thus,was	10
# ties,to	25
# time,Negative	22
# time,There	22
# time,This	18
# time,and	10
# time,attention	10
# time,complexity	44
# time,except	6
# time,is	10
# time,period	4
# times,they	1
# titles,see	1
# to,3	1
# to,AlphaZero	7
# to,Arthur	1
# to,Google	9
# to,Michael	17
# to,Suppose	12
# to,a	98
# to,accomplish	7
# to,accuracy	1
# to,algorithmically	10
# to,allow	12
# to,also	10
# to,analyze	5
# to,and	6
# to,another	10
# to,any	14
# to,approach	18
# to,artificial	1
# to,as	22
# to,assert	6
# to,assess	14
# to,assign	17
# to,attempts	7
# to,automated	14
# to,be	124
# to,best	8
# to,better	22
# to,both	10
# to,build	20
# to,but	4
# to,call	18
# to,capture	12
# to,cause	3
# to,classify	16
# to,classifying	6
# to,collect	6
# to,computation	12
# to,computational	11
# to,compute	22
# to,computers	7
# to,conclusions	22
# to,configurations	10
# to,contain	10
# to,continue	4
# to,correctly	27
# to,cumulatively	14
# to,deliver	23
# to,detect	20
# to,determine	29
# to,develop	10
# to,deviations	10
# to,devise	5
# to,diagnose	11
# to,discover	10
# to,distinguish	4
# to,distribute	11
# to,do	60
# to,dominate	18
# to,each	2
# to,eliminate	4
# to,emphasize	4
# to,emulate	12
# to,enhance	1
# to,estimate	8
# to,execute	7
# to,explain	10
# to,explanation	2
# to,express	13
# to,extract	2
# to,feedback	10
# to,file	10
# to,find	57
# to,fit	14
# to,fix	1
# to,flourish	18
# to,generalize	22
# to,generate	18
# to,give	1
# to,go	10
# to,have	10
# to,help	15
# to,higher	2
# to,higher-dimensional	6
# to,identify	24
# to,implicitly	8
# to,improve	51
# to,inductive	18
# to,instances	17
# to,it	10
# to,its	10
# to,known	22
# to,label	7
# to,large-scale	2
# to,last	1
# to,learn	98
# to,learning	2
# to,make	62
# to,manipulation	3
# to,manually	7
# to,many	19
# to,market	10
# to,mathematical	7
# to,maximize	22
# to,mitigate	8
# to,model	27
# to,more	7
# to,obtain	9
# to,one	33
# to,optimise	4
# to,optimization	17
# to,optimize	2
# to,other	19
# to,overall	13
# to,overfitting	14
# to,pattern	8
# to,perform	74
# to,performance	22
# to,performing	20
# to,personal	11
# to,philosophical	10
# to,pick	10
# to,play	13
# to,predict	44
# to,prediction	5
# to,preserve	22
# to,previous	12
# to,process	10
# to,produce	27
# to,program	7
# to,progressively	1
# to,provide	22
# to,quantify	18
# to,rank	3
# to,re-evaluate	3
# to,recognize	21
# to,reconstruct	9
# to,reduce	10
# to,regression	10
# to,remove	10
# to,represent	13
# to,reproduce	22
# to,reveal	13
# to,rule	14
# to,rule-learning	8
# to,search	4
# to,send	18
# to,software-based	4
# to,solve	40
# to,some	34
# to,special	3
# to,store	14
# to,study	18
# to,systematic	3
# to,tackling	18
# to,take	34
# to,target	3
# to,teach	7
# to,test	5
# to,the	152
# to,theoretical	18
# to,this	21
# to,those	10
# to,train	27
# to,training	9
# to,understand	9
# to,understanding	3
# to,update	6
# to,use	20
# to,visually	10
# to,watch	9
# to,what	2
# to,which	10
# to,win	21
# to,work	1
# today,in	10
# together,and	1
# together,they	10
# tomorrow,morning	4
# too,complex	15
# too,was	18
# tool,to	11
# tool,we	9
# toolbox,STATISTICA	3
# tools,They	12
# tools,and	10
# tools,for	1
# tools,have	17
# tools,ideas	1
# topic,modeling	10
# topic,of	6
# topics,Machine	3
# total,operating	6
# toward,methods	18
# toward,the	8
# towards,a	4
# toy,example	4
# tracking,face	10
# trader,of	6
# trading,may	6
# traditionally,divided	7
# train,a	7
# train,it	6
# train,search	9
# train,the	5
# trained,and	17
# trained,by	6
# trained,from	5
# trained,on	59
# trained,only	4
# trained,specifically	5
# trained,to	17
# trained,with	1
# training,Classic	10
# training,Classical	12
# training,Machine	3
# training,a	28
# training,algorithm	32
# training,and	14
# training,data	152
# training,deep	7
# training,error	16
# training,example	50
# training,examples	64
# training,labels	24
# training,large-scale	7
# training,machine	9
# training,model	19
# training,process	18
# training,set	70
# training,sets	37
# training,signal	6
# training,the	13
# transaction,data	10
# transaction,or	10
# transferring,and	3
# transferring,data	3
# transform,it	22
# transformations,on	10
# transformative,in	11
# translation,social	10
# transmit,information	10
# transparency,is	3
# travel,from	10
# travelers,Recently	2
# traversing,the	10
# tree,as	22
# tree,can	20
# tree,describes	10
# tree,learning	22
# tree,structures	10
# trees,In	10
# trees,in	10
# trees,where	10
# trendline,fitting	8
# trendline,of	7
# trends,in	5
# trick,implicitly	10
# trick,to	8
# tries,to	15
# true,and	2
# true,in	11
# turn,out	7
# two,areas	8
# two,broad	2
# two,categories	22
# two,decades	14
# two,environments	8
# two,facets	3
# two,fields	11
# two,kinds	22
# two,objectives	6
# two,objects	10
# two,research	22
# two,statistical	18
# two,terms	3
# type,of	21
# types,of	22
# typical,KDD	22
# typically,a	14
# typically,classified	8
# typically,does	10
# typically,have	10
# typically,real	10
# typically,represented	10
# typo,The	1
# u,r	10
# ultimate,goal	1
# unavailability,of	22
# unbalanced,nature	10
# uncertain,learning	22
# uncertainty,are	10
# unconscious,biases	10
# uncover,hidden	5
# under,consideration	4
# under,fitted	8
# under,that	22
# under,the	61
# under,uncertainty	10
# under,which	4
# underfit,the	6
# underfitted,Then	1
# underlying,factors	22
# underlying,the	15
# understand,and	9
# understand,the	2
# understanding,and	3
# undesirable,situations	8
# undesired,predictions	6
# undetectably,into	3
# undiscovered,black	4
# unexpected,bursts	10
# unfeasible,Example	1
# unfeasible,to	6
# uniform,representation	22
# uninformed,unsupervised	22
# units,By	6
# units,GPUs	7
# units,and	1
# units,or	10
# universally,applied	14
# unknown,data	12
# unknown,data-generating	10
# unknown,instances	1
# unknown,joint	12
# unknown,knowledge	22
# unknown,probability	22
# unknown,properties	14
# unlabeled,data	8
# unlabeled,input	10
# unlabeled,test	10
# unless,aggregated	2
# unless,it	8
# unlike,humans	4
# unnecessary,tests	11
# unobservable,probability	3
# unobserved,output	2
# unobserved,point	2
# unrecognized,influences	18
# unseen,data	4
# unseen,datum	12
# unseen,examples	2
# unseen,examples/tasks	20
# unseen,samples	17
# unseen,training	10
# unsupervised,In	10
# unsupervised,algorithms	10
# unsupervised,and	4
# unsupervised,feature	10
# unsupervised,learning	122
# unsupervised,method	22
# until,the	6
# up,of	21
# up,racist	10
# up,the	10
# update,the	6
# updates,a	8
# upon,use	15
# usage,mining	10
# use,SVM	10
# use,algorithmic	12
# use,computer	6
# use,data	4
# use,different	8
# use,dynamic	10
# use,for	9
# use,guidance	6
# use,in	6
# use,instances	1
# use,machine	10
# use,of	36
# use,them	10
# use,this	5
# use,thus	3
# use,to	2
# used,Receiver	7
# used,and	9
# used,as	23
# used,by	19
# used,due	22
# used,for	40
# used,in	82
# used,interactively	3
# used,on	10
# used,receiver	6
# used,to	148
# used,when	33
# useful,in	10
# useful,often	22
# useful,predictions	2
# user's,interaction	5
# user,for	3
# user,preferences	22
# user-defined,task	1
# users',mobile	9
# users',privacy	9
# users,of	11
# users,perform	2
# uses,a	22
# uses,federated	9
# uses,in	8
# uses,many	22
# uses,methods	8
# uses,statistical	1
# uses,to	7
# using,AI	2
# using,D	12
# using,ML	2
# using,a	27
# using,approximate	3
# using,computers	10
# using,explicit	2
# using,guidance	8
# using,job	7
# using,labeled	10
# using,logic	22
# using,machine	9
# using,methods	10
# using,rudimentary	3
# using,some	10
# using,teaching	8
# using,that	1
# using,the	10
# using,what	10
# usually,called	12
# usually,does	22
# usually,evaluated	22
# usually,used	12
# utilization,of	14
# vaguely,inspired	11
# valid,This	7
# validated,by	14
# value,Reasons	1
# value,are	3
# value,represented	10
# value,secondary	8
# value,within	13
# values,For	3
# values,and	10
# values,are	10
# values,one	1
# values,true	2
# values,typically	10
# variable,can	20
# variables,In	5
# variables,and	30
# variables,in	29
# variables,like	10
# variables,to	8
# variables,under	5
# variants,so	4
# variation,that	22
# varied,as	9
# variety,and	1
# variety,of	53
# various,approaches	7
# various,characteristics	7
# various,diseases	22
# various,entities	4
# various,forms	10
# various,implications	7
# various,learning	6
# various,symbolic	18
# vast,numbers	7
# vector,and	10
# vector,from	8
# vector,machines	17
# vector,networks	5
# vector,sometimes	9
# vectors,Deep	21
# vehicles,or	13
# verification,and	10
# versa,machine	5
# very,large	1
# very,transformative	1
# via,a	12
# via,adversarial	3
# via,the	14
# video,and	10
# video,games	10
# view,that	5
# viewed,as	3
# viewers',ratings	17
# viewing,patterns	17
# vii,Machine	4
# vision,Machine	4
# vision,and	30
# vision,of	6
# vision,speech	10
# vision,where	10
# visual,identity	10
# visually,and	10
# vulnerabilities,can	4
# vulnerable,to	3
# wa,s,such	8
# wants,to	17
# was,Nilsson's	3
# was,a	1
# was,also	22
# was,awarded	17
# was,coined	11
# was,continued	18
# was,given	8
# was,introduced	8
# was,killed	11
# was,not	20
# was,now	18
# was,out	18
# was,recently	2
# was,repetitively	3
# was,reported	10
# was,still	10
# was,the	5
# was,then	5
# was,to	10
# was,used	6
# wasnt,correct	1
# watch,out	9
# way,that	36
# way,the	15
# way,to	18
# ways,data	8
# we've,overfitted	1
# we've,underfitted	1
# we,are	9
# we,as	22
# we,can	1
# we,increase	1
# we,should	1
# weakly,supervised	9
# wearable,computers	3
# websites,or	1
# weight,increases	10
# weight,space	2
# weight,that	10
# well,Other	1
# well,They	3
# well,Usually	6
# well,a	1
# well,as	32
# well,equipped	1
# well,in	8
# well,it	4
# well,on	4
# well,resolved	10
# well-equipped,to	5
# well-ordered,set	10
# well-visible,not	3
# were,determining	3
# were,found	5
# were,interested	18
# were,later	18
# were,mostly	17
# were,not	27
# were,plagued	18
# were,then	13
# were,used	11
# what,is	12
# what,mechanisms	4
# what,was	5
# what,we	22
# what,were	13
# when,exact	10
# when,one	8
# when,the	23
# when,training	15
# when,used	8
# where,a	21
# where,designing	8
# where,each	23
# where,even	2
# where,it	18
# where,no	7
# where,only	2
# where,r	12
# where,the	48
# where,there	11
# where,vast	7
# whereas,AI	5
# wherefrom,it	8
# wherein,'algorithmic	6
# wherein,algorithmic	12
# whether,a	22
# whether,all	2
# whether,an	3
# whether,it	3
# whether,there	2
# which,a	15
# which,also	5
# which,an	4
# which,are	16
# which,classes	14
# which,consists	5
# which,contains	2
# which,correspond	2
# which,deliver	2
# which,delivers	6
# which,do	23
# which,don't	6
# which,entails	4
# which,every	2
# which,focuses	10
# which,have	6
# which,humans	2
# which,introduces	8
# which,is	9
# which,it	3
# which,loosely	10
# which,machine	12
# which,maps	12
# which,may	21
# which,printed	4
# which,raise	10
# which,rely	6
# which,samples	14
# which,splits	14
# which,the	23
# which,this	4
# which,to	10
# while,at	5
# while,in	44
# while,keeping	5
# while,machine	22
# while,not	22
# while,observations	22
# while,optimization	17
# while,others	4
# while,the	5
# white-box,access	3
# who,both	1
# who,reminds	9
# who,was	11
# who,were	5
# why,an	2
# wide,variety	13
# widely,quoted	22
# will,acquire	3
# will,allow	10
# will,be	18
# will,derive	22
# will,easily	22
# will,fail	10
# will,necessarily	14
# will,not	6
# will,perform	4
# will,probably	4
# win,the	21
# winning,several	1
# with,AI-specific	7
# with,a	60
# with,and	3
# with,any	10
# with,biases	15
# with,color	4
# with,completely	8
# with,computational	6
# with,data	9
# with,different	14
# with,existing	1
# with,experience	22
# with,good	3
# with,higher-level	22
# with,how	30
# with,human	8
# with,humans	6
# with,images	4
# with,in	22
# with,limited	3
# with,machine	8
# with,minimizing	17
# with,new	10
# with,no	8
# with,non-linear	8
# with,only	8
# with,punched	3
# with,racist	12
# with,recognizing	10
# with,replacement	14
# with,representation	4
# with,respect	66
# with,sequence	10
# with,some	6
# with,sparse	8
# with,supervised	6
# with,the	106
# with,their	1
# with,training	6
# with,unlabeled	10
# with,unnecessary	11
# with,various	18
# within,AI	18
# within,a	23
# within,machine	6
# within,the	22
# without,any	8
# without,being	39
# without,changing	5
# without,having	9
# without,limiting	6
# without,relying	10
# without,reshaping	21
# without,that	3
# without,using	2
# women,or	5
# won,the	1
# word,order	1
# words,by	1
# words,it	5
# work,in	7
# work,on	4
# work,together	1
# work,with	22
# workaround,to	10
# worked,well	4
# working,of	4
# working,towards	4
# working,well	4
# workload,burden	6
# world,to	12
# would,However	10
# would,be	37
# would,have	3
# would,include	3
# would,indicate	10
# would,mean	2
# would,often	10
# wrong,lesson	4
# wrong,tools	10
# wrote,about	19
# x,D	12
# x,be	12
# x,using	12
# xapprox,Dr	8
# xapprox,Dtimes	4
# years,have	5
# years,of	10
# yet,developed	6
# yet,many	7
# yield,guarantees	22
# yielded,attempts	3
# yielded,to	7
# your,current	1
# your,feature	1
# zero,Regression	1
# zeros,Deep	1
# zeros,Multilinear	21
